# %%
import json
from pprint import pprint

import gensim
import gensim.corpora as corpora
from gensim.models import CoherenceModel

#Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
input_file ='result_spark_2.json'
with open(input_file) as f:
    data = json.load(f)
print(f'repos nums: {len(data)}')

need_to_remove = []
for k,v in data.items():
    if 'No dependency' in v:
        need_to_remove.append(k)
print(f'repos which have no dependency files: {len(need_to_remove)}')


for k in need_to_remove:
    del data[k]
print(f'repos with dependency files: {len(data)}')
# Out:
# repos nums: 13796
# repos which have no dependency files: 12297
# repos with dependency files: 1499

# %%
rep_list,dep_list = [],[]
for k,v in data.items():
    rep_list.append(k)
    dep_list.append(v)

# %%
dep_dict = {}
for deps in data.values():
    for i in deps:
        dep_dict[i] = dep_dict.get(i,0)+1

print(f'distinct dependency file name: {len(dep_dict)}')
        
sort_dep = sorted(dep_dict.items(),key=lambda x: x[-1], reverse=True)
print(f'frequent dependency files:  {sort_dep[:20]}')
# Out:
# distinct dependency file name: 11238
# frequent dependency files:  [('numpy', 764), ('scipy', 494), ('matplotlib', 453), ('pandas', 416), ('pytest', 271), ('requests', 218), ('sphinx', 203), ('six', 167), ('scikit-learn', 159), ('pyyaml', 158), ('tqdm', 147), ('pytest-cov', 123), ('python-dateutil', 112), ('ipython', 111), ('sphinx-rtd-theme', 107), ('pytz', 101), ('pillow', 101), ('seaborn', 101), ('coverage', 100), ('h5py', 100)]

# %%
# based on dep file names , build dep name dictionary
id2word  = corpora.Dictionary(list(data.values()))   # {0: 'emd-signal',1: 'numpy', 2: 'SQLAlchemy', 3: 'aiofiles' ....}

# based on dep name dict and dep names, build corpus
corpus = [id2word.doc2bow(text) for text in list(data.values())] # [[(0, 1), (1, 1)],.....]

# Human readable format of corpus (term-frequency)
# [[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
corpus[0],[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# ([(0, 1), (1, 1)], [[('emd-signal', 1), ('numpy', 1)]])

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.061*"junit:junit" + '
#   '0.044*"org.apache.maven.plugins:maven-compiler-plugin" + '
#   '0.027*"org.apache.maven.plugins:maven-jar-plugin" + '
#   '0.023*"org.apache.maven.plugins:maven-surefire-plugin" + '
#   '0.021*"org.apache.maven.plugins:maven-javadoc-plugin" + '
#   '0.020*"org.apache.maven.plugins:maven-source-plugin" + '
#   '0.019*"org.slf4j:slf4j-api" + 0.018*"com.google.guava:guava" + '
#   '0.017*"commons-io:commons-io" + 0.016*"ch.qos.logback:logback-classic"'),
#  (1,
#   '0.061*"nose" + 0.035*"netcdf4" + 0.009*"babel-plugin-transform-strict-mode" '
#   '+ 0.009*"babel-plugin-transform-es2015-modules-commonjs" + '
#   '0.009*"babel-plugin-transform-es2015-modules-amd" + '
#   '0.009*"babel-preset-env" + 0.008*"babel-register" + '
#   '0.008*"babel-plugin-transform-es2015-classes" + '
#   '0.008*"babel-plugin-transform-es2015-block-scoping" + '
#   '0.008*"babel-plugin-transform-es2015-block-scoped-functions"'),
#  (2,
#   '0.013*"obspy" + 0.011*"System.ValueTuple" + 0.000*"MSTest.TestFramework" + '
#   '0.000*"MSTest.TestAdapter" + 0.000*"System.Collections" + '
#   '0.000*"Microsoft.NETCore.Platforms" + 0.000*"sciBASIC" + '
#   '0.000*"System.Threading.Tasks.Extensions" + '
#   '0.000*"System.IO.FileSystem.Primitives" + 0.000*"System.IO.Compression"'),
#  (3,
#   '0.011*"fs.realpath" + 0.011*"has-flag" + 0.011*"glob" + 0.010*"graceful-fs" '
#   '+ 0.010*"inflight" + 0.010*"inherits" + 0.009*"find-up" + 0.008*"mocha" + '
#   '0.008*"glob-parent" + 0.008*"minimatch"'),
#  (4,
#   '0.009*"@babel/preset-env" + 0.009*"react" + 0.009*"@babel/core" + '
#   '0.008*"react-dom" + 0.008*"@babel/plugin-transform-modules-commonjs" + '
#   '0.008*"@babel/helpers" + 0.008*"@babel/helper-annotate-as-pure" + '
#   '0.008*"@babel/helper-module-imports" + '
#   '0.008*"@babel/plugin-proposal-async-generator-functions" + '
#   '0.008*"@babel/plugin-syntax-async-generators"'),
#  (5,
#   '0.046*"future" + 0.027*"pyproj" + 0.024*"sqlalchemy" + 0.020*"nltk" + '
#   '0.017*"django" + 0.016*"simplejson" + 0.015*"msgpack" + 0.014*"lmfit" + '
#   '0.014*"shapely" + 0.013*"beautifulsoup4"'),
#  (6,
#   '0.031*"pyqt5" + 0.025*"jekyll" + 0.019*"log-symbols" + 0.017*"nibabel" + '
#   '0.016*"p-try" + 0.016*"pyqtgraph" + 0.013*"readdirp" + 0.013*"p-locate" + '
#   '0.013*"p-limit" + 0.012*"set-blocking"'),
#  (7,
#   '0.117*"numpy" + 0.073*"scipy" + 0.066*"matplotlib" + 0.060*"pandas" + '
#   '0.036*"pytest" + 0.030*"requests" + 0.025*"sphinx" + 0.023*"pyyaml" + '
#   '0.022*"scikit-learn" + 0.017*"pytest-cov"'),
#  (8,
#   '0.009*"ansi-regex" + 0.008*"argparse" + 0.008*"ansi-styles" + '
#   '0.007*"anymatch" + 0.007*"chalk" + 0.007*"ajv" + 0.007*"camelcase" + '
#   '0.007*"braces" + 0.007*"color-name" + 0.007*"color-convert"'),
#  (9,
#   '0.028*"sphinxcontrib-napoleon" + 0.018*"pytest-xdist" + '
#   '0.014*"sphinx-bootstrap-theme" + 0.009*"coloredlogs" + '
#   '0.006*"requests-mock" + 0.003*"uproot" + 0.002*"lalsuite" + '
#   '0.002*"lscsoft-glue" + 0.002*"ligo-segments" + 0.002*"dqsegdb2"'),
#  (10,
#   '0.024*"urllib3" + 0.023*"certifi" + 0.023*"joblib" + 0.022*"decorator" + '
#   '0.021*"chardet" + 0.020*"markupsafe" + 0.020*"idna" + 0.019*"pytz" + '
#   '0.019*"tornado" + 0.019*"jinja2"'),
#  (11,
#   '0.029*"protobuf" + 0.018*"tensorboard" + 0.015*"gast" + 0.012*"absl-py" + '
#   '0.012*"astor" + 0.012*"rdflib" + 0.012*"log4j:log4j" + '
#   '0.010*"org.apache.maven.plugins:maven-checkstyle-plugin" + '
#   '0.010*"commons-collections:commons-collections" + '
#   '0.009*"org.springframework:spring-webmvc"'),
#  (12,
#   '0.021*"org.apache.commons:commons-math3" + '
#   '0.021*"org.apache.maven.plugins:maven-release-plugin" + '
#   '0.013*"org.eclipse.m2e:lifecycle-mapping" + 0.013*"org.jdom:jdom" + '
#   '0.009*"pybind11" + 0.006*"pyopencl" + 0.004*"pyfai" + '
#   '0.003*"org.knowm.xchart:xchart" + 0.000*"org.apache.jena:jena-arq" + '
#   '0.000*"org.apache.jena:jena-core"'),
#  (13,
#   '0.016*"supports-color" + 0.016*"semver" + 0.014*"strip-ansi" + '
#   '0.013*"path-exists" + 0.012*"string-width" + 0.012*"object-assign" + '
#   '0.012*"jshint" + 0.011*"path-key" + 0.011*"safer-buffer" + '
#   '0.010*"sprintf-js"'),
#  (14,
#   '0.049*"pillow" + 0.048*"xarray" + 0.046*"numba" + 0.037*"coveralls" + '
#   '0.031*"wheel" + 0.030*"bokeh" + 0.028*"pylint" + 0.027*"sympy" + '
#   '0.024*"twine" + 0.020*"xlrd"'),
#  (15,
#   '0.050*"flask" + 0.046*"biopython" + 0.035*"werkzeug" + 0.026*"docopt" + '
#   '0.017*"itsdangerous" + 0.017*"gunicorn" + 0.014*"google-api-python-client" '
#   '+ 0.013*"redis" + 0.013*"httplib2" + 0.013*"psycopg2"'),
#  (16,
#   '0.045*"codecov" + 0.043*"tensorflow" + 0.028*"boto3" + '
#   '0.028*"sphinx-gallery" + 0.018*"flask-cors" + 0.017*"pytest-flake8" + '
#   '0.015*"wheel" + 0.014*"humanize" + 0.013*"pytest-runner" + 0.012*"gdal"'),
#  (17,
#   '0.036*"rake" + 0.029*"faraday" + 0.028*"nokogiri" + 0.028*"multipart-post" '
#   '+ 0.025*"bundler" + 0.022*"json" + 0.019*"rdoc" + 0.014*"rack" + '
#   '0.011*"http_parser.rb" + 0.011*"pg"'),
#  (18,
#   '0.031*"org.codehaus.mojo:build-helper-maven-plugin" + '
#   '0.018*"mysql:mysql-connector-java" + '
#   '0.007*"org.eluder.coveralls:coveralls-maven-plugin" + '
#   '0.006*"org.apache.maven.plugins:maven-scm-publish-plugin" + '
#   '0.005*"org.easymock:easymock" + 0.003*"com.google.inject:guice" + '
#   '0.001*"org.codehaus.mojo:taglist-maven-plugin" + '
#   '0.000*"org.eclipse.tycho:target-platform-configuration" + '
#   '0.000*"org.eclipse.tycho:tycho-surefire-plugin" + '
#   '0.000*"org.eclipse.tycho:tycho-maven-plugin"'),
#  (19,
#   '0.027*"grunt" + 0.024*"grunt-contrib-uglify" + 0.021*"grunt-contrib-jshint" '
#   '+ 0.019*"grunt-contrib-watch" + 0.019*"grunt-contrib-connect" + '
#   '0.019*"github-pages" + 0.015*"grunt-contrib-cssmin" + 0.013*"socket.io" + '
#   '0.012*"grunt-contrib-concat" + 0.012*"grunt-cli"')]

# %%
# Compute Perplexity
print('Perplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=list(data.values()), dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Perplexity:  -14.8664302118617
# Coherence Score:  0.6390475117702155

# %%
# Show the top 5 words of each topic
for topic in lda_model.print_topics(num_words=5):
    print(topic)
# Out:
# (0, '0.061*"junit:junit" + 0.044*"org.apache.maven.plugins:maven-compiler-plugin" + 0.027*"org.apache.maven.plugins:maven-jar-plugin" + 0.023*"org.apache.maven.plugins:maven-surefire-plugin" + 0.021*"org.apache.maven.plugins:maven-javadoc-plugin"')
# (1, '0.061*"nose" + 0.035*"netcdf4" + 0.009*"babel-plugin-transform-strict-mode" + 0.009*"babel-plugin-transform-es2015-modules-commonjs" + 0.009*"babel-plugin-transform-es2015-modules-amd"')
# (2, '0.013*"obspy" + 0.011*"System.ValueTuple" + 0.000*"MSTest.TestAdapter" + 0.000*"MSTest.TestFramework" + 0.000*"System.Collections"')
# (3, '0.011*"fs.realpath" + 0.011*"has-flag" + 0.011*"glob" + 0.010*"graceful-fs" + 0.010*"inflight"')
# (4, '0.009*"@babel/preset-env" + 0.009*"react" + 0.009*"@babel/core" + 0.008*"react-dom" + 0.008*"@babel/plugin-transform-modules-commonjs"')
# (5, '0.046*"future" + 0.027*"pyproj" + 0.024*"sqlalchemy" + 0.020*"nltk" + 0.017*"django"')
# (6, '0.031*"pyqt5" + 0.025*"jekyll" + 0.019*"log-symbols" + 0.017*"nibabel" + 0.016*"p-try"')
# (7, '0.117*"numpy" + 0.073*"scipy" + 0.066*"matplotlib" + 0.060*"pandas" + 0.036*"pytest"')
# (8, '0.009*"ansi-regex" + 0.008*"argparse" + 0.008*"ansi-styles" + 0.007*"anymatch" + 0.007*"chalk"')
# (9, '0.028*"sphinxcontrib-napoleon" + 0.018*"pytest-xdist" + 0.014*"sphinx-bootstrap-theme" + 0.009*"coloredlogs" + 0.006*"requests-mock"')
# (10, '0.024*"urllib3" + 0.023*"certifi" + 0.023*"joblib" + 0.022*"decorator" + 0.021*"chardet"')
# (11, '0.029*"protobuf" + 0.018*"tensorboard" + 0.015*"gast" + 0.012*"absl-py" + 0.012*"astor"')
# (12, '0.021*"org.apache.commons:commons-math3" + 0.021*"org.apache.maven.plugins:maven-release-plugin" + 0.013*"org.eclipse.m2e:lifecycle-mapping" + 0.013*"org.jdom:jdom" + 0.009*"pybind11"')
# (13, '0.016*"supports-color" + 0.016*"semver" + 0.014*"strip-ansi" + 0.013*"path-exists" + 0.012*"string-width"')
# (14, '0.049*"pillow" + 0.048*"xarray" + 0.046*"numba" + 0.037*"coveralls" + 0.031*"wheel"')
# (15, '0.050*"flask" + 0.046*"biopython" + 0.035*"werkzeug" + 0.026*"docopt" + 0.017*"itsdangerous"')
# (16, '0.045*"codecov" + 0.043*"tensorflow" + 0.028*"boto3" + 0.028*"sphinx-gallery" + 0.018*"flask-cors"')
# (17, '0.036*"rake" + 0.029*"faraday" + 0.028*"nokogiri" + 0.028*"multipart-post" + 0.025*"bundler"')
# (18, '0.031*"org.codehaus.mojo:build-helper-maven-plugin" + 0.018*"mysql:mysql-connector-java" + 0.007*"org.eluder.coveralls:coveralls-maven-plugin" + 0.006*"org.apache.maven.plugins:maven-scm-publish-plugin" + 0.005*"org.easymock:easymock"')
# (19, '0.027*"grunt" + 0.024*"grunt-contrib-uglify" + 0.021*"grunt-contrib-jshint" + 0.019*"grunt-contrib-watch" + 0.019*"grunt-contrib-connect"')

# %%
# make inference (cluster) for each repo
print('inference ：')
for e, values in enumerate(lda_model.inference(corpus)[0]):
    topic_val = 0
    topic_id = 0
    for tid, val in enumerate(values):
        if val > topic_val:
            topic_val = val
            topic_id = tid
    print(topic_id, '--->', rep_list[e])
# Out:
# inference ：
# 7 ---> https://github.com/LRydin/MFDFA
# 5 ---> https://github.com/Flowminder/FlowKit
# 7 ---> https://github.com/linhd-postdata/desir
# 4 ---> https://github.com/DLR-SC/gitlab2prov
# 7 ---> https://github.com/openearth/aeolis-python
# 8 ---> https://github.com/Lonero-Team/Decentralized-Internet
# 5 ---> https://github.com/LegoStormtroopr/django-spaghetti-and-meatballs
# 7 ---> https://github.com/smarie/python-azureml-client
# 7 ---> https://github.com/NREL/floris
# 7 ---> https://github.com/ADicksonLab/wepy
# 7 ---> https://github.com/M4I-nanoscopy/tpx3-event-localisation
# 17 ---> https://github.com/myGrid/ruby-ucf
# 7 ---> https://github.com/andsor/pyfssa
# 7 ---> https://github.com/arkottke/pykoom
# 10 ---> https://github.com/tardis-sn/tardis
# 7 ---> https://github.com/IaPCS/gmsh-exodus-converter
# 7 ---> https://github.com/atait/lytest
# 7 ---> https://github.com/ocsmit/rindcalc
# 5 ---> https://github.com/mpostol/TP
# 8 ---> https://github.com/ElektraInitiative/libelektra
# 7 ---> https://github.com/will-rowe/groot
# 5 ---> https://github.com/bexis/Module_LUI
# 7 ---> https://github.com/benjaminrose/MC-Age
# 7 ---> https://github.com/SSW-DataLab/randomizer
# 7 ---> https://github.com/FowlerLab/Enrich2
# 19 ---> https://github.com/Andros-Spica/PhD-defense
# 7 ---> https://github.com/SirSharpest/NarrowEscapeSimulator
# 7 ---> https://github.com/annotation/tutorials
# 7 ---> https://github.com/RDFLib/OWL-RL
# 7 ---> https://github.com/RPGroup-PBoC/vdj_recombination
# 10 ---> https://github.com/carpyncho/carpyncho
# 7 ---> https://github.com/jpvantassel/sigpropy
# 7 ---> https://github.com/camelot-project/frontend
# 7 ---> https://github.com/cggh/scikit-allel
# 7 ---> https://github.com/kundajelab/seqdataloader
# 19 ---> https://github.com/ubccr/xdmod
# 7 ---> https://github.com/TomasBeuzen/pybeach
# 4 ---> https://github.com/prevwong/craft.js
# 7 ---> https://github.com/CovingtonResearchGroup/olm
# 7 ---> https://github.com/zykls/whynot
# 14 ---> https://github.com/DLR-RM/RAFCON
# 7 ---> https://github.com/hpparvi/PyTransit
# 7 ---> https://github.com/BigDataBiology/GMGC-mapper
# 7 ---> https://github.com/andycasey/ads
# 19 ---> https://github.com/darribas/wmn
# 15 ---> https://github.com/caltechlibrary/holdit
# 7 ---> https://github.com/AMReX-Astro/Castro
# 7 ---> https://github.com/greglucas/bezpy
# 7 ---> https://github.com/RCHG/FunFAN
# 7 ---> https://github.com/geek-yang/META
# 17 ---> https://github.com/Sentimentron/Nebraska-public
# 7 ---> https://github.com/jkibele/OpticalRS
# 3 ---> https://github.com/jupiterbak/FAPSDemoOPCUAServer2
# 10 ---> https://github.com/seandavi/ngCGH
# 7 ---> https://github.com/fraserw/trippy
# 6 ---> https://github.com/SainsburyWellcomeCentre/lasagna
# 8 ---> https://github.com/ufz/ogs
# 7 ---> https://github.com/libsemigroups/libsemigroups
# 5 ---> https://github.com/IDEES-Rouen/Flight-Scrapping
# 7 ---> https://github.com/AshKelly/pyquad
# 7 ---> https://github.com/jolespin/soothsayer
# 7 ---> https://github.com/kklmn/xrt
# 7 ---> https://github.com/beringresearch/ivis
# 7 ---> https://github.com/mdolab/pyspline
# 7 ---> https://github.com/thieunguyen5991/opfunu
# 19 ---> https://github.com/fmannhardt/pddp
# 7 ---> https://github.com/gwpy/gwpy
# 7 ---> https://github.com/pyvista/pyvista
# 5 ---> https://github.com/arcolife/scholarec
# 3 ---> https://github.com/NUStreaming/acm-mmsys-2020-grand-challenge
# 7 ---> https://github.com/adamewing/tebreak
# 10 ---> https://github.com/papis/papis
# 7 ---> https://github.com/wlad111/small_probs
# 7 ---> https://github.com/slimgroup/ServerlessImagingAWS
# 7 ---> https://github.com/danielbmmatos/Reduced-Model-of-Shear-Building
# 7 ---> https://github.com/biocore/qiime
# 7 ---> https://github.com/aretha-hep/mprtect
# 14 ---> https://github.com/bionode/bionode-template
# 16 ---> https://github.com/SebastianEggert/OpenWorkstation
# 7 ---> https://github.com/pyscf/pyscf
# 7 ---> https://github.com/GijsMulders/epos
# 7 ---> https://github.com/castelao/PyAVISO
# 0 ---> https://github.com/korpling/ANNIS
# 11 ---> https://github.com/sayounara/Green_training
# 8 ---> https://github.com/WikiWatershed/model-my-watershed
# 7 ---> https://github.com/aymara/lima
# 2 ---> https://github.com/xieguigang/ManhattanPlot
# 0 ---> https://github.com/thorstenwagner/TraJ
# 8 ---> https://github.com/sealuzh/lightweight-effectiveness
# 8 ---> https://github.com/phiresky/backchannel-prediction
# 7 ---> https://github.com/labexp/LibreScan
# 7 ---> https://github.com/jdmoorman/laptools
# 7 ---> https://github.com/krassowski/drug-disease-profile-matching
# 19 ---> https://github.com/allucas/allucas.github.io
# 7 ---> https://github.com/BradMcDanel/term-revealing
# 10 ---> https://github.com/silx-kit/pyFAI
# 7 ---> https://github.com/scipy-lectures/scipy-lecture-notes
# 7 ---> https://github.com/ornlneutronimaging/NEUIT
# 7 ---> https://github.com/kgullikson88/General
# 7 ---> https://github.com/BristolTopGroup/DailyPythonScripts
# 7 ---> https://github.com/redcap-tools/PyCap
# 0 ---> https://github.com/dgarijo/Widoco
# 17 ---> https://github.com/PecanProject/bety
# 8 ---> https://github.com/AABoyles/MicrobeTrace
# 3 ---> https://github.com/supercollider/supercollider
# 7 ---> https://github.com/linsalrob/PhiSpy
# 7 ---> https://github.com/Koushikphy/Interactive_Data_Editor
# 7 ---> https://github.com/keichi/mpEDM
# 10 ---> https://github.com/cldf-clts/pyclts
# 7 ---> https://github.com/TEB-model/teb
# 7 ---> https://github.com/comic/evalutils
# 7 ---> https://github.com/suryabaiarava/liferay-examples
# 7 ---> https://github.com/opencobra/cobratoolbox
# 7 ---> https://github.com/dtscalibration/python-dts-calibration
# 7 ---> https://github.com/eqcorrscan/EQcorrscan
# 7 ---> https://github.com/scikit-hep/decaylanguage
# 8 ---> https://github.com/OpenGeoscience/geojs
# 7 ---> https://github.com/PyThaiNLP/pythainlp
# 7 ---> https://github.com/TUW-GEO/ascat
# 0 ---> https://github.com/rvanheest/feedback4s
# 7 ---> https://github.com/screensinthewild/screenbase_instantiated_slideshow
# 7 ---> https://github.com/AMReX-Astro/MAESTROeX
# 7 ---> https://github.com/christianjauregui/famafrench
# 19 ---> https://github.com/TBroTeam/TBro
# 7 ---> https://github.com/mattbit/active-network-er
# 7 ---> https://github.com/timetag/ETA
# 7 ---> https://github.com/stephankramer/assess
# 0 ---> https://github.com/DataFusion4NetBio/Paper16-SCODE
# 4 ---> https://github.com/CDAT/jupyter-vcdat
# 7 ---> https://github.com/jorvlan/open-visualizations
# 7 ---> https://github.com/lsa-pucrs/acerta-abide
# 7 ---> https://github.com/particle-physics-playground/playground
# 2 ---> https://github.com/krischer/hypoDDpy
# 7 ---> https://github.com/jankrepl/deepdow
# 7 ---> https://github.com/weijias-opensource/acc
# 7 ---> https://github.com/sam-nayak/SynthNet
# 7 ---> https://github.com/laserkelvin/PySpecTools
# 7 ---> https://github.com/nithyanandan/AstroUtils
# 7 ---> https://github.com/tactcomplabs/xbgas-llvm
# 7 ---> https://github.com/mdolab/pyoptsparse
# 7 ---> https://github.com/tholoien/empiriciSN
# 7 ---> https://github.com/FUSED-Wind/fusedwind
# 7 ---> https://github.com/sam-greenwood/taco_vis
# 0 ---> https://github.com/lifs-tools/jmzTab-m
# 7 ---> https://github.com/JannisHoch/pcrglobwb_utils
# 7 ---> https://github.com/hep-lbdl/CaloGAN
# 1 ---> https://github.com/epiviz/Metaviz
# 7 ---> https://github.com/bbfrederick/rapidtide
# 7 ---> https://github.com/pnlbwh/conversion
# 3 ---> https://github.com/butcer0/SequenceOne
# 7 ---> https://github.com/LinkedEarth/Pyleoclim_util
# 7 ---> https://github.com/IMAGINE-Consortium/imagine
# 7 ---> https://github.com/glm-tools/pyglmnet
# 7 ---> https://github.com/aburrell/aacgmv2
# 7 ---> https://github.com/sncosmo/sncosmo
# 8 ---> https://github.com/InsightSoftwareConsortium/itkwidgets
# 7 ---> https://github.com/ICB-DCM/pyPESTO
# 7 ---> https://github.com/lballabio/QuantLib-SWIG
# 7 ---> https://github.com/SoftwareDevEngResearch/RigidFoilSimulator
# 7 ---> https://github.com/samuelstjean/dpr
# 7 ---> https://github.com/interrogator/corpkit
# 5 ---> https://github.com/gwu-libraries/sfm-ui
# 5 ---> https://github.com/tyson-swetnam/porder
# 19 ---> https://github.com/sabgaby/sabgaby
# 7 ---> https://github.com/panisson/pymobility
# 3 ---> https://github.com/ryanpeek/mapping-in-R-workshop
# 7 ---> https://github.com/lewisacidic/scikit-chem
# 3 ---> https://github.com/GerardBalaoro/jQuery-Tourer
# 0 ---> https://github.com/KnowledgeCaptureAndDiscovery/DISK
# 7 ---> https://github.com/RTIInternational/gobbli
# 7 ---> https://github.com/fabriziocosta/GraphLearn
# 7 ---> https://github.com/solvebio/veppy
# 7 ---> https://github.com/diku-dk/futhark
# 19 ---> https://github.com/kks32-slides/2016-berkeley
# 0 ---> https://github.com/SeqWare/oozie-sge
# 7 ---> https://github.com/kristianfoerster/melodist
# 14 ---> https://github.com/midas-isg/epicasemap
# 19 ---> https://github.com/BristolTopGroup/NTupleProduction
# 7 ---> https://github.com/kuchaale/X-regression
# 8 ---> https://github.com/dockstore/dockstore-ui2
# 7 ---> https://github.com/abhi1693/yii2-sms
# 0 ---> https://github.com/NLeSC/eEcology-Classification
# 7 ---> https://github.com/jdidion/atropos
# 7 ---> https://github.com/KBRI-Neuroinformatics/WGAN-for-RNASeq-analysis
# 7 ---> https://github.com/PinkShnack/TEMUL
# 3 ---> https://github.com/rOpenGov/eurostat
# 7 ---> https://github.com/rock-learning/pytransform3d
# 10 ---> https://github.com/matthiaskoenig/sbmlutils
# 10 ---> https://github.com/PennLINC/aslprep
# 7 ---> https://github.com/tamacgregor/structure_factor_tools
# 7 ---> https://github.com/kgullikson88/gullikson-scripts
# 7 ---> https://github.com/jacirrone/OutPredict
# 7 ---> https://github.com/shiyy123/FCDetector
# 0 ---> https://github.com/fmi-faim/fmi-trackmate-addons
# 10 ---> https://github.com/biocaddie/WG3-MetadataSpecifications
# 7 ---> https://github.com/habi/Zebra-Fish-Gills
# 7 ---> https://github.com/ga4gh/tool-registry-validator
# 7 ---> https://github.com/sagemath/sage
# 7 ---> https://github.com/4DNucleome/PartSeg
# 10 ---> https://github.com/priestoferis/animal-behaviour-analysis-2020
# 0 ---> https://github.com/mayconbordin/streaminer
# 19 ---> https://github.com/ctsit/redcap_external_module_development_guide
# 19 ---> https://github.com/joshje/drawpath
# 10 ---> https://github.com/BeckResearchLab/USP-inhibition
# 8 ---> https://github.com/bio-ontology-research-group/DDIEM
# 10 ---> https://github.com/fvalka/atc-reinforcement-learning
# 7 ---> https://github.com/kb-press/ndsplines
# 7 ---> https://github.com/agnsal/BlocksBot
# 7 ---> https://github.com/benmaier/COVID19CaseNumberModel
# 7 ---> https://github.com/uweschmitt/emzed2
# 19 ---> https://github.com/prajankya/Lidar-Robot
# 7 ---> https://github.com/AAROC/DevOps
# 7 ---> https://github.com/ybayle/Scyland3D
# 7 ---> https://github.com/jswhit/pygrib
# 7 ---> https://github.com/PTC-CMC/McCabeGroup
# 7 ---> https://github.com/bdw/GridKit
# 7 ---> https://github.com/feelpp/feelpp
# 7 ---> https://github.com/seclab-ucr/UBITect
# 7 ---> https://github.com/SuLab/scheduled-bots
# 7 ---> https://github.com/mjlaine/eppes
# 7 ---> https://github.com/alpha-xone/xbbg
# 7 ---> https://github.com/IA-Cardiologia-husa/VHD_NLP
# 10 ---> https://github.com/ahamilton144/hamilton-2020-managing-financial-risk-tradeoffs-for-hydropower
# 8 ---> https://github.com/MonashBioinformaticsPlatform/laxy
# 7 ---> https://github.com/Ptrskay3/PySprint
# 7 ---> https://github.com/gaojun0816/code_access_finder
# 8 ---> https://github.com/LinkedDataFragments/Server.js
# 8 ---> https://github.com/lgsvl/simulator
# 7 ---> https://github.com/foerstner-lab/GRADitude
# 14 ---> https://github.com/BritishMuseumDH/britishMuseumFacesDetection
# 7 ---> https://github.com/mattpitkin/psrqpy
# 7 ---> https://github.com/cbirdferrer/collatrix
# 7 ---> https://github.com/spacetelescope/pysiaf
# 7 ---> https://github.com/jag1g13/pycgtool
# 4 ---> https://github.com/jtmccr1/figtreejs-react
# 7 ---> https://github.com/vedantchandra/wdtools
# 7 ---> https://github.com/ericleasemorgan/reader
# 1 ---> https://github.com/AbhinavMir/Decentralized-Journalism-Using-Ethereum
# 15 ---> https://github.com/juliolugo96/ula-lang
# 7 ---> https://github.com/CountESS-Project/fqfa
# 17 ---> https://github.com/reflectivity/reflectivity.github.io
# 7 ---> https://github.com/vuw-sim-stia/TICJ
# 7 ---> https://github.com/tudelft3d/bag3d
# 0 ---> https://github.com/cyverse-gis/suas-metadata
# 7 ---> https://github.com/mwcraig/msumastro
# 7 ---> https://github.com/ctsit/qipr_approver
# 10 ---> https://github.com/Caltech-IPAC/Montage
# 7 ---> https://github.com/emtpb/pyfds
# 0 ---> https://github.com/DennisRippinger/spade
# 7 ---> https://github.com/Chilipp/psyplot_old
# 8 ---> https://github.com/UNCG-DAISY/Coastal-Image-Labeler
# 8 ---> https://github.com/jiemakel/aether
# 7 ---> https://github.com/chrisdjscott/Atoman
# 8 ---> https://github.com/cosmo-epfl/chemiscope
# 7 ---> https://github.com/spcl/dace
# 7 ---> https://github.com/CardiacModelling/nonlinear-time-dependent-leak
# 7 ---> https://github.com/templateflow/python-client
# 7 ---> https://github.com/redmod-team/profit
# 7 ---> https://github.com/pavolgaj/ObsPlanner
# 7 ---> https://github.com/nick-youngblut/MGSIM
# 0 ---> https://github.com/fcproj/agrotagger
# 1 ---> https://github.com/epiviz/epiviz
# 4 ---> https://github.com/filips123/EthAvatar.JS
# 0 ---> https://github.com/quadrama/DramaNLP
# 8 ---> https://github.com/Kitware/itk-vtk-viewer
# 19 ---> https://github.com/academic/thesaurus-manager
# 0 ---> https://github.com/milaboratory/mixcr
# 19 ---> https://github.com/Fu-PusH/statement-finder
# 7 ---> https://github.com/openmc-dev/openmc
# 7 ---> https://github.com/brelsford/topology
# 7 ---> https://github.com/thela/django_log_to_telegram
# 19 ---> https://github.com/cigroup-ol/metaopt
# 7 ---> https://github.com/lucananni93/CTCF_Spatial_Patterns
# 7 ---> https://github.com/stfbnc/fathon
# 7 ---> https://github.com/prisms-center/CASMcode
# 7 ---> https://github.com/ccd-utexas/binstarsolver
# 7 ---> https://github.com/wallissoncarvalho/HidroData
# 7 ---> https://github.com/XPRESSyourself/XPRESSplot
# 7 ---> https://github.com/airr-community/airr-standards
# 7 ---> https://github.com/joaomcteixeira/taurenmd
# 7 ---> https://github.com/jyhmiinlin/pynufft
# 7 ---> https://github.com/atrisovic/econ-data-policy
# 7 ---> https://github.com/DPBayes/DP-cross-silo-federated-learning
# 7 ---> https://github.com/statsmodels/statsmodels
# 0 ---> https://github.com/SciGraph/SciGraph
# 7 ---> https://github.com/giannisdoukas/ipython2cwl
# 7 ---> https://github.com/Neurita/pypes
# 7 ---> https://github.com/pesummary/pesummary
# 0 ---> https://github.com/nilsreiter/CorefAnnotator
# 19 ---> https://github.com/tripal/tripal_galaxy
# 7 ---> https://github.com/hipster-philology/protogenie
# 7 ---> https://github.com/PGijsbers/gama
# 10 ---> https://github.com/collab-uniba/personality
# 7 ---> https://github.com/sertansenturk/makammusicbrainz
# 7 ---> https://github.com/biowdl/germline-DNA
# 7 ---> https://github.com/CLARIAH/grlc
# 7 ---> https://github.com/openvax/isovar
# 19 ---> https://github.com/iimog/wikidata-game-flower-color
# 7 ---> https://github.com/seawander/nmf_imaging
# 7 ---> https://github.com/GiulioRossetti/cdlib
# 7 ---> https://github.com/neuhofmo/RecBlast
# 7 ---> https://github.com/cyverse-vice/jupyterlab-scipy
# 19 ---> https://github.com/UWDIRECT/UWDIRECT.github.io
# 7 ---> https://github.com/CoffeaTeam/coffea
# 0 ---> https://github.com/Rothamsted/knetminer
# 7 ---> https://github.com/multipaths/DiffuPath
# 7 ---> https://github.com/matplotlib/mpl-probscale
# 7 ---> https://github.com/richardjgowers/GCMCbenchmarks
# 7 ---> https://github.com/daft-dev/daft
# 8 ---> https://github.com/arose/ngl
# 7 ---> https://github.com/fa-me/spotlob
# 7 ---> https://github.com/thompsonsed/pycoalescence
# 19 ---> https://github.com/sdss/marvin
# 7 ---> https://github.com/brmather/pycurious
# 7 ---> https://github.com/MHKiT-Software/MHKiT-MATLAB
# 8 ---> https://github.com/sigsep/sigsep-mus-2018-website
# 7 ---> https://github.com/amusecode/amuse
# 8 ---> https://github.com/bwbohl/introduction-to-mei
# 8 ---> https://github.com/JaneliaSciComp/SharkViewer
# 7 ---> https://github.com/KeplerGO/lightkurve
# 7 ---> https://github.com/transientlunatic/gravpy
# 7 ---> https://github.com/astroufsc/chimera
# 8 ---> https://github.com/cogan-shimizu-wsu/ExperimentAnnotationTracker
# 7 ---> https://github.com/jenojp/extractacy
# 4 ---> https://github.com/aaronSig/rainforest-rhythms
# 7 ---> https://github.com/valentina-s/time-series-nmf
# 7 ---> https://github.com/Nikronic/Optimized-MDVRP
# 7 ---> https://github.com/pr-omethe-us/PyTeCK
# 7 ---> https://github.com/bumps/bumps
# 7 ---> https://github.com/jtempkin/enhanced_sampling_toolkit
# 10 ---> https://github.com/automatedskip/homerent.io
# 7 ---> https://github.com/a-slide/NanoCount
# 7 ---> https://github.com/NLeSC/dask-cassandra-loader
# 7 ---> https://github.com/explosion/spaCy
# 8 ---> https://github.com/mjuez/TFM2016_Analisis-Visual-Revisiones-Codigo
# 0 ---> https://github.com/owlcollab/owltools
# 0 ---> https://github.com/mmhss/sstrong-import
# 7 ---> https://github.com/I2Cvb/retinopathy
# 3 ---> https://github.com/sgsaenger/vipster
# 12 ---> https://github.com/SHDShim/PeakPo
# 7 ---> https://github.com/rangeetpan/decomposeDNNintoModules
# 4 ---> https://github.com/InsightSoftwareConsortium/ITKColorNormalization
# 7 ---> https://github.com/coin-or/Dip
# 0 ---> https://github.com/Thales1330/PSP
# 7 ---> https://github.com/fepegar/torchio
# 7 ---> https://github.com/phenoscape/phenoscape-owl-tools
# 5 ---> https://github.com/htcondor/htcondor-ce
# 7 ---> https://github.com/hugadams/pyparty
# 7 ---> https://github.com/NLeSC/baklava
# 7 ---> https://github.com/howardyclo/grammar-pattern
# 19 ---> https://github.com/ufbmi/mdc_search
# 7 ---> https://github.com/aplowman/first-principles-zr-grain-boundaries
# 10 ---> https://github.com/dlozeve/tda-networks
# 7 ---> https://github.com/mustakcsecuet/COIN-Attacks
# 7 ---> https://github.com/LargerPanda/ceph
# 7 ---> https://github.com/glukicov/ML_GPU
# 7 ---> https://github.com/devitocodes/devito
# 7 ---> https://github.com/pnlbwh/TBSS
# 7 ---> https://github.com/scipy/scipy
# 7 ---> https://github.com/DiamondLightSource/SuRVoS
# 7 ---> https://github.com/wri/restoration-mapper
# 7 ---> https://github.com/ICB-DCM/tumor2d
# 7 ---> https://github.com/sertansenturk/symbtrdataextractor
# 7 ---> https://github.com/chrisma/ScrumLint
# 7 ---> https://github.com/TheoryInPractice/BEAVr
# 7 ---> https://github.com/jloveric/high-order-layers
# 7 ---> https://github.com/jcreinhold/selfsupervised3d
# 7 ---> https://github.com/mlp6/fem
# 7 ---> https://github.com/Eden-Kramer-Lab/replay_trajectory_classification
# 7 ---> https://github.com/nschloe/colorio
# 7 ---> https://github.com/tsalo/convert-eprime
# 7 ---> https://github.com/projectglow/glow
# 7 ---> https://github.com/FRidh/scintillations
# 7 ---> https://github.com/pitt-rnel/perceptmapper
# 7 ---> https://github.com/carnisj/bcdi
# 7 ---> https://github.com/pysal/esda
# 7 ---> https://github.com/pedropro/TACO
# 7 ---> https://github.com/nkratzke/twista
# 7 ---> https://github.com/MicroPasts/egyptExplorationSocietyBuhen
# 7 ---> https://github.com/Lasagne/Lasagne
# 19 ---> https://github.com/Andros-Spica/EMAC-Angourakis-et-al-2019
# 3 ---> https://github.com/fg-inet/DASH-streaming-setup
# 7 ---> https://github.com/JiaweiZhuang/xESMF
# 7 ---> https://github.com/astrorama/SourceXtractorPlusPlus
# 7 ---> https://github.com/ssec/sift
# 7 ---> https://github.com/IMMM-SFA/proxymod
# 7 ---> https://github.com/bgruening/docker-galaxy-stable
# 7 ---> https://github.com/reflectometry/refl1d
# 7 ---> https://github.com/napari/napari
# 7 ---> https://github.com/sgrieve/spatial_efd
# 7 ---> https://github.com/genn-team/genn
# 7 ---> https://github.com/AxFoundation/strax
# 7 ---> https://github.com/pofatu/pypofatu
# 7 ---> https://github.com/bsc-mem/UEPREDICT
# 0 ---> https://github.com/Smart-Contract-Modelling-uOttawa/Symboleo-Compliance-Checker
# 7 ---> https://github.com/smarie/python-spawny
# 7 ---> https://github.com/usnistgov/jarvis
# 7 ---> https://github.com/diana-hep/carl
# 7 ---> https://github.com/PTB-PSt1/PyDynamic
# 7 ---> https://github.com/mne-tools/mne-python
# 7 ---> https://github.com/mlbernauer/drugstandards
# 7 ---> https://github.com/kundajelab/kerasAC
# 10 ---> https://github.com/felicitia/TestAnalyzer
# 10 ---> https://github.com/sshilpika/error-log-analysis
# 7 ---> https://github.com/dhermes/bezier
# 7 ---> https://github.com/sphinx-gallery/sphinx-gallery
# 7 ---> https://github.com/pysal/pysal
# 7 ---> https://github.com/numericalalgorithmsgroup/pybobyqa
# 7 ---> https://github.com/PyNIPT/pynipt
# 7 ---> https://github.com/jesford/cluster-lensing
# 7 ---> https://github.com/cosanlab/nltools
# 8 ---> https://github.com/plantinformatics/pretzel
# 7 ---> https://github.com/ryanpdwyer/1605-phasekick
# 19 ---> https://github.com/NatLibFi/Skosmos
# 7 ---> https://github.com/jcchiba/GANSta
# 10 ---> https://github.com/chembience/chembience
# 7 ---> https://github.com/Quantum-TII/qprime
# 8 ---> https://github.com/OpenKnowledgeMaps/Headstart
# 7 ---> https://github.com/radnut/amc
# 7 ---> https://github.com/omuse-geoscience/omuse
# 0 ---> https://github.com/klugem/watchdog
# 7 ---> https://github.com/nils-wisiol/pypuf
# 7 ---> https://github.com/ladisk/pyDIC
# 7 ---> https://github.com/easyDiffraction/easyDiffraction
# 7 ---> https://github.com/pauleve/pint
# 7 ---> https://github.com/e5k/TephraProb
# 7 ---> https://github.com/fmalmeida/bacannot
# 7 ---> https://github.com/delph-in/pydmrs
# 7 ---> https://github.com/GenericMappingTools/pygmt
# 3 ---> https://github.com/pymedphys/pymedphys
# 7 ---> https://github.com/anuprulez/galaxy_tool_recommendation
# 7 ---> https://github.com/BMKEG/sciDT-pipeline
# 19 ---> https://github.com/Irstea/otolithe
# 7 ---> https://github.com/hugovk/pypistats
# 7 ---> https://github.com/single-cell-genetics/vireo
# 3 ---> https://github.com/bionode/bionode
# 7 ---> https://github.com/Edric-Matwiejew/QuOp_MPI
# 13 ---> https://github.com/evanodell/parlitools
# 7 ---> https://github.com/steven-murray/hankel
# 7 ---> https://github.com/guillochon/MOSFiT
# 7 ---> https://github.com/lascivaroma/priapeia
# 7 ---> https://github.com/vahtras/loprop
# 7 ---> https://github.com/pv8/noipy
# 7 ---> https://github.com/MAfarrag/Hapi
# 7 ---> https://github.com/monteirotorres/ProtCHOIR
# 7 ---> https://github.com/dejac001/adsorption_isotherm_fitting
# 7 ---> https://github.com/GilesStrong/lumin
# 13 ---> https://github.com/worldsensing/xyz-iot-monitoring
# 0 ---> https://github.com/rcsb/ciftools-java
# 1 ---> https://github.com/cgre-aachen/pynoddy
# 7 ---> https://github.com/bashtage/linearmodels
# 7 ---> https://github.com/pygae/galgebra
# 10 ---> https://github.com/SandstoneHPC/sandstone-ide
# 7 ---> https://github.com/darothen/pyrcel
# 7 ---> https://github.com/DD-DeCaF/id-mapper
# 5 ---> https://github.com/Colectica/curation
# 7 ---> https://github.com/harnesscloud/harness-resource-manager
# 10 ---> https://github.com/huggingface/transformers
# 7 ---> https://github.com/stadelmanma/netl-ap-map-flow
# 7 ---> https://github.com/jl-wynen/isle
# 4 ---> https://github.com/rodighiero/DH2020
# 0 ---> https://github.com/scalaris-team/scalaris
# 16 ---> https://github.com/FEEprojects/plantower
# 14 ---> https://github.com/aibasel/pyperplan
# 7 ---> https://github.com/theboocock/NGaDNAP
# 0 ---> https://github.com/DeathStar3/symfinder
# 7 ---> https://github.com/AdmiralenOla/Scoary
# 7 ---> https://github.com/NickleDave/visual-search-nets
# 7 ---> https://github.com/dhondta/AppmemDumper
# 7 ---> https://github.com/scikit-hep/boost-histogram
# 7 ---> https://github.com/vsoch/askci
# 7 ---> https://github.com/boutiques/boutiques
# 10 ---> https://github.com/nansencenter/nansat
# 7 ---> https://github.com/cdanielmachado/reframed
# 7 ---> https://github.com/LightForm-group/matflow
# 5 ---> https://github.com/Capitains/Hook
# 7 ---> https://github.com/arokem/ISBI2015
# 7 ---> https://github.com/a-slide/NanoSnake
# 19 ---> https://github.com/laplizard/infoplot
# 7 ---> https://github.com/hugadams/PAME
# 7 ---> https://github.com/torressa/cspy
# 7 ---> https://github.com/ConservationInternational/trends.earth
# 14 ---> https://github.com/OpenChemistry/avogadrolibs
# 7 ---> https://github.com/ondrolexa/pywerami
# 4 ---> https://github.com/Sulstice/datacity
# 10 ---> https://github.com/bootphon/phonemizer
# 7 ---> https://github.com/chrisgorgo/alleninf
# 17 ---> https://github.com/opentox/lazar-rest
# 0 ---> https://github.com/SeqWare/seqware
# 7 ---> https://github.com/msmbuilder/osprey
# 5 ---> https://github.com/urschrei/CDP
# 1 ---> https://github.com/comic/grand-challenge.org
# 7 ---> https://github.com/roland-wallner/dss2020-ex1
# 7 ---> https://github.com/tasoc/corrections
# 8 ---> https://github.com/lucasberent/mapleDocs
# 7 ---> https://github.com/bakirtzisg/cybok-cli
# 7 ---> https://github.com/SuperElastix/SimpleElastix
# 7 ---> https://github.com/fsherry/bilevelmri
# 7 ---> https://github.com/USEPA/standardizedinventories
# 7 ---> https://github.com/ilogue/niprov
# 7 ---> https://github.com/kundajelab/atac_dnase_pipelines
# 7 ---> https://github.com/ktmeaton/NCBImeta
# 8 ---> https://github.com/University-of-Potsdam-MM/Reflect.UP
# 7 ---> https://github.com/mdolab/OpenAeroStruct
# 7 ---> https://github.com/amcpherson/remixt
# 7 ---> https://github.com/fbpic/fbpic
# 0 ---> https://github.com/sjcross/MIA
# 7 ---> https://github.com/RiceMunk/omnifit
# 8 ---> https://github.com/cronelab/bci2000web
# 7 ---> https://github.com/epigen/crop-seq
# 7 ---> https://github.com/rholson1/peyecoder
# 7 ---> https://github.com/dmnfarrell/pandastable
# 7 ---> https://github.com/YeoLab/flotilla
# 7 ---> https://github.com/amisr/flipchem
# 17 ---> https://github.com/TGAC/brassica
# 7 ---> https://github.com/silx-kit/fabio
# 7 ---> https://github.com/numericalalgorithmsgroup/dfols
# 5 ---> https://github.com/zeeguu-ecosystem/Zeeguu-API
# 10 ---> https://github.com/AVAuco/ssd_head_keras
# 7 ---> https://github.com/PRIMAVERA-H2020/primavera-dmt
# 7 ---> https://github.com/MartinMalyMM/pairef
# 7 ---> https://github.com/ImperialCollegeLondon/covid19model
# 7 ---> https://github.com/BrkRaw/bruker
# 0 ---> https://github.com/oicr-gsi/shesmu
# 7 ---> https://github.com/coderdj/emo
# 7 ---> https://github.com/ladisk/DyS
# 7 ---> https://github.com/Quasars/orange-spectroscopy
# 10 ---> https://github.com/WorldVistA/VistA
# 7 ---> https://github.com/faroit/CountNet
# 7 ---> https://github.com/HHTpy/HHTpywrapper
# 0 ---> https://github.com/constantinpape/z5
# 7 ---> https://github.com/samapriya/hdxpop
# 7 ---> https://github.com/pik-copan/pycopancore
# 7 ---> https://github.com/MARLEY-MC/marley
# 7 ---> https://github.com/garrettwrong/cuTWED
# 10 ---> https://github.com/greenape/mknotebooks
# 8 ---> https://github.com/bbglab/muts-needle-plot
# 7 ---> https://github.com/NickleDave/crowsetta
# 0 ---> https://github.com/ISA-tools/stato
# 7 ---> https://github.com/LJMUAstroecology/flirpy
# 7 ---> https://github.com/OntoElect/Code
# 0 ---> https://github.com/diging/giles-eco-cepheus
# 7 ---> https://github.com/scikit-hep/mplhep
# 7 ---> https://github.com/alimanfoo/vcfnp
# 7 ---> https://github.com/bjodah/finitediff
# 7 ---> https://github.com/pysit/pysit
# 7 ---> https://github.com/observingClouds/eurec4a_snd
# 7 ---> https://github.com/colloidlab/ccc-calculator
# 7 ---> https://github.com/elihuihms/itcsimlib
# 17 ---> https://github.com/tigefa4u/tigefa4u.github.io
# 7 ---> https://github.com/dvolgyes/zenodo_get
# 7 ---> https://github.com/alexander-rossner/dh-researchtool-landscape
# 10 ---> https://github.com/pylayers/pylayers
# 0 ---> https://github.com/alexrashed/eval_rest
# 7 ---> https://github.com/jovo/PyGraphStat
# 17 ---> https://github.com/dannyboscan/angular-and-rails
# 8 ---> https://github.com/Aletechdev/ava
# 7 ---> https://github.com/annotation/text-fabric
# 7 ---> https://github.com/ksmet1977/luxpy
# 0 ---> https://github.com/thorstenwagner/spie-photonics-europe-2016
# 7 ---> https://github.com/root-project/root
# 0 ---> https://github.com/slimsuite/SLiMScape
# 7 ---> https://github.com/AlanLoh/nenupy
# 7 ---> https://github.com/waterlandlab/CluBCpG
# 0 ---> https://github.com/diging/citesphere-importer
# 7 ---> https://github.com/OpenDroneMap/ODM
# 7 ---> https://github.com/openrsp/openrsp
# 8 ---> https://github.com/AliTVTeam/AliTV
# 7 ---> https://github.com/Finn-Lab/EukCC
# 7 ---> https://github.com/amlalejini/ALife-2020--SignalGP-Genetic-Regulation
# 0 ---> https://github.com/rinde/RinECJ
# 7 ---> https://github.com/spacetelescope/drizzlepac
# 7 ---> https://github.com/smoh/gaia-comoving-stars
# 7 ---> https://github.com/ckrapu/sprcom
# 0 ---> https://github.com/Terradue/rOpenSearch
# 1 ---> https://github.com/essepuntato/rash
# 7 ---> https://github.com/pygridtools/gridmap
# 7 ---> https://github.com/dftlibs/numgrid
# 17 ---> https://github.com/sckott/serrano
# 10 ---> https://github.com/snewhouse/exotic-dna-ngs
# 12 ---> https://github.com/numenta/gridcodingrange
# 1 ---> https://github.com/KWB-R/fakin
# 7 ---> https://github.com/fpavogt/fcmaker
# 8 ---> https://github.com/falafeljan/recogito-user-testing
# 7 ---> https://github.com/CalebBell/fluids
# 7 ---> https://github.com/ImperialCollegeLondon/acoustics-db
# 19 ---> https://github.com/mfroeling/QMRITools
# 7 ---> https://github.com/tqbl/ood_audio
# 4 ---> https://github.com/delphi-hub/delphi-webapp
# 7 ---> https://github.com/taishi-i/nagisa
# 7 ---> https://github.com/slimgroup/Azure2019
# 8 ---> https://github.com/afilipanog/afilipanog.github.io
# 7 ---> https://github.com/samapriya/Sat-Pipeline-CLI
# 0 ---> https://github.com/shah314/graphcoloring
# 7 ---> https://github.com/YeoLab/gscripts
# 17 ---> https://github.com/FitzwilliamMuseum/ahrc-linking-islands
# 7 ---> https://github.com/cern-fts/webfts
# 10 ---> https://github.com/brinkmanlab/feature_merge
# 19 ---> https://github.com/dohalloran/phylo-node
# 7 ---> https://github.com/IMTtugraz/PyQMRI
# 7 ---> https://github.com/openearth/aeolis
# 10 ---> https://github.com/obreitwi/py-veer
# 14 ---> https://github.com/InsightSoftwareConsortium/ITKElastix
# 3 ---> https://github.com/meijer-jeroen/contingent-evolution-2020
# 7 ---> https://github.com/pandera-dev/pandera
# 7 ---> https://github.com/cheshire3/cheshire3
# 7 ---> https://github.com/ludwig-burtscher/invenio-with-provenance
# 0 ---> https://github.com/CeON/CERMINE
# 7 ---> https://github.com/mjiUST/VasNet
# 17 ---> https://github.com/scleveland/NADV
# 0 ---> https://github.com/nextcloud/android
# 7 ---> https://github.com/neurodata/mvlearn
# 7 ---> https://github.com/TUM-CPN/CropTypes
# 0 ---> https://github.com/BMKEG/UimaBioC
# 3 ---> https://github.com/jbathmann/pyMANGA
# 7 ---> https://github.com/THzbiophotonics/Fit-TDS
# 0 ---> https://github.com/ICGC-TCGA-PanCancer/OxoGWrapperWorkflow
# 7 ---> https://github.com/franknu/cgmodsel
# 7 ---> https://github.com/openpathsampling/openpathsampling
# 7 ---> https://github.com/Teichlab/cellphonedb
# 19 ---> https://github.com/pear2/Net_Transmitter
# 7 ---> https://github.com/oslocyclotronlab/ompy
# 7 ---> https://github.com/GooglingTheCancerGenome/sv-gen
# 7 ---> https://github.com/benmontet/f3
# 7 ---> https://github.com/rubbs14/CSP-Analyzer
# 6 ---> https://github.com/hugomilan/tlmbht
# 19 ---> https://github.com/GRIFFINCollaboration/beamCompanionExplorer
# 17 ---> https://github.com/arnikz/PIQMIe
# 7 ---> https://github.com/SuperDARN/pydarn
# 0 ---> https://github.com/CharafeddineMechalikh/PureEdgeSim
# 19 ---> https://github.com/Andros-Spica/Postdocs-Angourakis-2019
# 19 ---> https://github.com/austindrenski/AD.PartialEquilibriumApi
# 7 ---> https://github.com/LightForm-group/xrdfit
# 7 ---> https://github.com/spcl/stencilflow
# 7 ---> https://github.com/kdmurray91/libqcpp
# 7 ---> https://github.com/nipy/nibabel
# 7 ---> https://github.com/openearth/flamingo
# 8 ---> https://github.com/ARGOeu/poem-2
# 7 ---> https://github.com/HelioML/HelioML
# 7 ---> https://github.com/SwissTPH/TBRU_serialTB
# 4 ---> https://github.com/liminoid/liminoid-react
# 7 ---> https://github.com/HaroldMills/Vesper
# 7 ---> https://github.com/iterative/dvc
# 7 ---> https://github.com/ultralytics/yolov5
# 7 ---> https://github.com/spa-networks/hpa
# 7 ---> https://github.com/PX4/Firmware
# 2 ---> https://github.com/speckleworks/SpeckleRhino
# 7 ---> https://github.com/alan-turing-institute/sktime
# 7 ---> https://github.com/Phlya/coolpuppy
# 8 ---> https://github.com/sigsep/website
# 7 ---> https://github.com/dejac001/distillation
# 7 ---> https://github.com/simeonreusch/ztffps
# 7 ---> https://github.com/django-salesforce/django-salesforce
# 10 ---> https://github.com/jellis18/PAL2
# 19 ---> https://github.com/rsa-tools/rsat-code
# 19 ---> https://github.com/tompollard/phd_thesis_markdown
# 7 ---> https://github.com/fpavogt/pyqz
# 5 ---> https://github.com/fnl/medic
# 7 ---> https://github.com/SciTools/iris
# 7 ---> https://github.com/neglectos/dockerhub_analysis
# 7 ---> https://github.com/mosdef-hub/foyer
# 19 ---> https://github.com/calipho-sib/feature-viewer
# 19 ---> https://github.com/academic/vipa
# 7 ---> https://github.com/IndexedConv/IndexedConv
# 7 ---> https://github.com/VlachosGroup/openmkm
# 7 ---> https://github.com/nipype/pydra
# 19 ---> https://github.com/sherlock-clustering/Sherlock_DiVE
# 14 ---> https://github.com/datalad/datalad
# 7 ---> https://github.com/asreview/asreview-covid19
# 5 ---> https://github.com/mikahama/akusanat
# 1 ---> https://github.com/laderast/ready_for_r_site
# 17 ---> https://github.com/GlobalNamesArchitecture/taxamatch_rb
# 7 ---> https://github.com/adbar/htmldate
# 7 ---> https://github.com/jonescompneurolab/hnn
# 7 ---> https://github.com/iross/km_indexer
# 7 ---> https://github.com/jameslyons/python_speech_features
# 7 ---> https://github.com/biolink/biolink-model
# 7 ---> https://github.com/x10-lang/x10
# 7 ---> https://github.com/MicroPasts/projectAndvariLOD
# 7 ---> https://github.com/griffin-h/lightcurve_fitting
# 7 ---> https://github.com/lanl/VizAly-Foresight
# 8 ---> https://github.com/cytoscape/cytoscape.js-cxtmenu
# 10 ---> https://github.com/BrennerG/DS1
# 4 ---> https://github.com/KitwareMedical/HASI
# 0 ---> https://github.com/SELAB-AA/arvue-platform
# 7 ---> https://github.com/rjfarmer/gfort2py
# 7 ---> https://github.com/danhey/maelstrom
# 19 ---> https://github.com/lewisacidic/synergy-maps
# 7 ---> https://github.com/KamilSJaron/smudgeplot
# 7 ---> https://github.com/zfit/zfit
# 7 ---> https://github.com/arkottke/pykooh
# 7 ---> https://github.com/gvoysey/corti
# 8 ---> https://github.com/bongadi/ARV-Predictor-OngadiB
# 17 ---> https://github.com/aquariumbio/aquarium
# 7 ---> https://github.com/appukuttan-shailesh/morphounit
# 0 ---> https://github.com/mbari-media-management/vars-avfoundation
# 0 ---> https://github.com/phon-ca/phon
# 19 ---> https://github.com/kbroman/AdvData
# 7 ---> https://github.com/insilichem/gaudiview
# 7 ---> https://github.com/bdhammel/least-squares-ellipse-fitting
# 7 ---> https://github.com/matthiaskoenig/pkdb
# 0 ---> https://github.com/manoelcampos/cloudsim-plus
# 7 ---> https://github.com/pystruct/pystruct
# 7 ---> https://github.com/mozillazg/phrase-pinyin-data
# 3 ---> https://github.com/pabloaaf/Factor-TranscriptionCaseStudy
# 7 ---> https://github.com/PonteIneptique/archives_org_latin_toolkit
# 7 ---> https://github.com/GeoStat-Framework/welltestpy
# 7 ---> https://github.com/guaix-ucm/numina
# 7 ---> https://github.com/mariogeiger/se3cnn
# 19 ---> https://github.com/craws/OpenAtlas
# 7 ---> https://github.com/sjvrijn/mf2
# 3 ---> https://github.com/docable/docable
# 0 ---> https://github.com/qbicsoftware/projectwizard-portlet
# 7 ---> https://github.com/DuttonLab/kvasir
# 7 ---> https://github.com/SolarArbiter/solarforecastarbiter-core
# 7 ---> https://github.com/duecredit/duecredit
# 7 ---> https://github.com/epiviz/epivizFileParser
# 7 ---> https://github.com/Accenture/AmpliGraph
# 0 ---> https://github.com/dockstore/dockstore
# 1 ---> https://github.com/jacobwindsor/kaavio-showdown
# 10 ---> https://github.com/julemai/EEE-DA
# 7 ---> https://github.com/materialsproject/custodian
# 7 ---> https://github.com/Samreay/Pippin
# 7 ---> https://github.com/DeepRank/deeprank
# 14 ---> https://github.com/bionode/bionode-ncbi
# 7 ---> https://github.com/leonardo-calcagno/covid19model_latam
# 7 ---> https://github.com/openvax/varcode
# 0 ---> https://github.com/nilsreiter/uima-util
# 7 ---> https://github.com/pybel/pybel
# 7 ---> https://github.com/hitliaomq/ELASTIC3rd
# 7 ---> https://github.com/portugueslab/stytra
# 7 ---> https://github.com/abhi1693/yii2-app-advanced-startup-kit
# 7 ---> https://github.com/steelelab-delft/stlabutils
# 7 ---> https://github.com/aouinizied/nfstream
# 7 ---> https://github.com/holgern/pyedflib
# 7 ---> https://github.com/pysal/mapclassify
# 7 ---> https://github.com/bastibe/MAPS-Scripts
# 7 ---> https://github.com/ICB-DCM/parPE
# 7 ---> https://github.com/newville/wxmplot
# 7 ---> https://github.com/jirikuncar/eelap
# 7 ---> https://github.com/giganticode/codeprep
# 7 ---> https://github.com/raphaelvallat/yasa
# 0 ---> https://github.com/JonnyDaenen/Gumbo
# 7 ---> https://github.com/BENR0/textory
# 7 ---> https://github.com/architecture-building-systems/CityEnergyAnalyst
# 7 ---> https://github.com/quexiang/STWR
# 7 ---> https://github.com/underworldcode/underworld2
# 7 ---> https://github.com/TerrainBento/umami
# 7 ---> https://github.com/FedericoGarza/covidmx
# 7 ---> https://github.com/SimonGreenhill/phylogemetric
# 7 ---> https://github.com/earthlab/matplotcheck
# 7 ---> https://github.com/landlab/landlab
# 7 ---> https://github.com/saltastro/pyhrs
# 7 ---> https://github.com/MRCIEU/MELODI-Presto
# 7 ---> https://github.com/kundajelab/tfmodisco
# 3 ---> https://github.com/jupiterbak/FAPSDemoOPCUAServer0
# 7 ---> https://github.com/hugadams/scikit-spectra
# 7 ---> https://github.com/YeoLab/clipper
# 7 ---> https://github.com/Confareneoclassico/Irrigation_Model
# 7 ---> https://github.com/mmaelicke/soil-moisture-dynamics-companion-code
# 7 ---> https://github.com/rscottweekly/processPKPD
# 7 ---> https://github.com/empymod/emg3d
# 7 ---> https://github.com/coin-or/rbfopt
# 5 ---> https://github.com/VForWaTer/metacatalog
# 0 ---> https://github.com/piyush82/iot-simulator
# 7 ---> https://github.com/rabroughton/QUAD
# 7 ---> https://github.com/biocore/qurro
# 7 ---> https://github.com/streamreasoning/rsplib
# 4 ---> https://github.com/NLeSC/nlesc-serverless-boilerplate
# 7 ---> https://github.com/lanl/CLAMR
# 7 ---> https://github.com/matiscke/lcps
# 7 ---> https://github.com/jdavidrcamacho/tedi
# 3 ---> https://github.com/jupiterbak/FAPSDemoOPCUAServer
# 7 ---> https://github.com/Fraternalilab/POPScomp
# 7 ---> https://github.com/DeepLearnPhysics/larcv3
# 7 ---> https://github.com/wangz10/text-classification
# 8 ---> https://github.com/NLeSC/docker-couch-admin
# 13 ---> https://github.com/cs-education/sysbuild
# 7 ---> https://github.com/nkeim/philatracks
# 7 ---> https://github.com/Qiskit/qiskit-terra
# 7 ---> https://github.com/mdolab/dafoam
# 19 ---> https://github.com/mikel-egana-aranguren/SADI-Galaxy-Docker
# 7 ---> https://github.com/JakeBlackmore/Diatomic-Py
# 7 ---> https://github.com/arXiv/arxiv-search
# 8 ---> https://github.com/Princeton-CDH/mep-django
# 7 ---> https://github.com/thesketh/pygen-structures
# 7 ---> https://github.com/paudetseis/RfPy
# 7 ---> https://github.com/maxibor/sourcepredict
# 7 ---> https://github.com/SNLComputation/compadre
# 8 ---> https://github.com/SmartAPI/smartAPI-editor
# 7 ---> https://github.com/felixriese/hyperspectral-processing
# 7 ---> https://github.com/briandconnelly/hankshaweffect
# 7 ---> https://github.com/Starlink/starlink
# 10 ---> https://github.com/acdh-oeaw/apis-core
# 8 ---> https://github.com/chaoss/augur
# 0 ---> https://github.com/thiagotts/CloudReports
# 7 ---> https://github.com/gijzelaerr/kliko
# 7 ---> https://github.com/chrisjsewell/ipymd
# 7 ---> https://github.com/evolaemp/svmcc
# 8 ---> https://github.com/njss/SpaceTimeCube3D
# 17 ---> https://github.com/lagotto/lagotto
# 0 ---> https://github.com/CloudBindle/youxia
# 7 ---> https://github.com/AA-ALERT/psrdada-python
# 7 ---> https://github.com/joyeuxnoel8/GAME
# 7 ---> https://github.com/refnx/refnx
# 8 ---> https://github.com/plertvilai/IPAX
# 14 ---> https://github.com/ikkebr/PyBozoCrack
# 14 ---> https://github.com/MicroPasts/MicroPasts-pybossa-theme
# 7 ---> https://github.com/chkoar/vfi
# 7 ---> https://github.com/evalf/nutils
# 7 ---> https://github.com/ESCOMP/CTSM
# 7 ---> https://github.com/daler/erythroid-genes
# 17 ---> https://github.com/hdcaicyt/La-Argentina-Manuscrita
# 7 ---> https://github.com/peterpeterp/atlantic_ace_seasonal_forecast
# 7 ---> https://github.com/USNavalResearchLaboratory/zernike
# 7 ---> https://github.com/MarouaJaoua/life-expectancy-analysis-and-prediction
# 0 ---> https://github.com/hcadavid/TimeWarpScheduleLibrary
# 5 ---> https://github.com/bihealth/sodar_core
# 7 ---> https://github.com/cmbant/CAMB
# 7 ---> https://github.com/SolarArbiter/solarforecastarbiter-dashboard
# 7 ---> https://github.com/ilent2/ott
# 7 ---> https://github.com/Phlya/adjustText
# 7 ---> https://github.com/UmbertoGostoli/Simulation-for-Scottish-Gov
# 8 ---> https://github.com/fzyukio/koe
# 7 ---> https://github.com/ewels/MultiQC
# 0 ---> https://github.com/gbif/registry
# 10 ---> https://github.com/quicklizard99/cheddar
# 7 ---> https://github.com/ggventurini/python-deltasigma
# 7 ---> https://github.com/moonso/stranger
# 7 ---> https://github.com/qcscine/sparrow
# 19 ---> https://github.com/smart-facility/petajakarta-web
# 7 ---> https://github.com/sakoho81/miplib
# 7 ---> https://github.com/nstarman/starkplot
# 7 ---> https://github.com/passaH2O/GeoFlood
# 7 ---> https://github.com/thompsonsed/pycoalescence_examples
# 5 ---> https://github.com/horizon-institute/artmaps-azure
# 7 ---> https://github.com/Unidata/MetPy
# 0 ---> https://github.com/miso-lims/miso-lims
# 7 ---> https://github.com/theosysbio/gene-expression-models
# 6 ---> https://github.com/TuringLang/Turing.jl
# 7 ---> https://github.com/sertansenturk/alignedpitchfilter
# 8 ---> https://github.com/cytoscape/cytoscape.js-euler
# 7 ---> https://github.com/sbonaretti/cart_segm_liter_map
# 6 ---> https://github.com/gchure/phd
# 0 ---> https://github.com/korpling/pepper
# 7 ---> https://github.com/sdomanskyi/DigitalCellSorter
# 7 ---> https://github.com/PaulHancock/Aegean
# 7 ---> https://github.com/casperdcl/brainweb
# 7 ---> https://github.com/deeptools/deepTools
# 7 ---> https://github.com/ofionnad/radiowinds
# 7 ---> https://github.com/hail-is/hail
# 7 ---> https://github.com/coin-or/python-mip
# 7 ---> https://github.com/FRidh/auraliser
# 7 ---> https://github.com/Amber-MD/pytraj
# 7 ---> https://github.com/glukicov/alignTrack
# 10 ---> https://github.com/starschema/COVID-19-data
# 7 ---> https://github.com/clcr/pyeo
# 7 ---> https://github.com/TUW-GEO/yeoda
# 7 ---> https://github.com/spacetx/starfish
# 1 ---> https://github.com/dapperstats/salvage
# 7 ---> https://github.com/matplotlib/matplotlib
# 4 ---> https://github.com/DLR-SC/prov-db-connector
# 7 ---> https://github.com/MicroPasts/egyptExplorationSociety
# 7 ---> https://github.com/badlands-model/badlands
# 17 ---> https://github.com/AAROC/CODE-RADE
# 7 ---> https://github.com/BBN-Q/macrospin_gpu
# 7 ---> https://github.com/SciTools/cf-units
# 8 ---> https://github.com/macarthur-lab/seqr
# 7 ---> https://github.com/gwastro/pycbc
# 7 ---> https://github.com/sahilm89/lhsmdu
# 7 ---> https://github.com/nfsi-canada/OrientPy
# 7 ---> https://github.com/ai-se/perfect-repo
# 7 ---> https://github.com/cojacoo/rootwater
# 7 ---> https://github.com/multiscale/muscle3
# 7 ---> https://github.com/proycon/gecco
# 7 ---> https://github.com/USGS-Astrogeology/autocnet
# 7 ---> https://github.com/oemof/tespy
# 7 ---> https://github.com/pdfo/pdfo
# 7 ---> https://github.com/louisabraham/fastnode2vec
# 7 ---> https://github.com/poliastro/poliastro
# 7 ---> https://github.com/stabix/stabix
# 19 ---> https://github.com/TonyKaravasilev/CryptoManana
# 7 ---> https://github.com/EpistasisLab/tpot
# 7 ---> https://github.com/bird-house/finch
# 17 ---> https://github.com/PCMDI/cmor3_documentation
# 7 ---> https://github.com/epiasini/pymuvr
# 7 ---> https://github.com/jkguiang/tuda
# 10 ---> https://github.com/TiKeil/perturbations-for-2d-data
# 7 ---> https://github.com/MJOLNIRPackage/MJOLNIR
# 7 ---> https://github.com/EducationalTestingService/rsmtool
# 7 ---> https://github.com/mpschr/mutex
# 19 ---> https://github.com/openearth/wpsbuilder
# 7 ---> https://github.com/preprocessed-connectomes-project/quality-assessment-protocol
# 7 ---> https://github.com/LucMarechal/Soft-Robotics-Materials-Database
# 8 ---> https://github.com/ufbmi/mdc_api
# 19 ---> https://github.com/Andros-Spica/CDAL-Angourakis-2019
# 7 ---> https://github.com/sappelhoff/eeg_positions
# 7 ---> https://github.com/CERNatschool/LUCIDITY
# 7 ---> https://github.com/glubbdubdrib/lazygrid
# 7 ---> https://github.com/KnowledgeCaptureAndDiscovery/somef
# 7 ---> https://github.com/ESMValGroup/ESMValCore
# 7 ---> https://github.com/castelao/pyrings
# 17 ---> https://github.com/myGrid/t2-server-gem
# 7 ---> https://github.com/casperdcl/git-fame
# 17 ---> https://github.com/gge-ucd/wRangling-Ecology
# 7 ---> https://github.com/SysBioChalmers/yeast-GEM
# 7 ---> https://github.com/by256/rdfpy
# 5 ---> https://github.com/FNNDSC/ChRIS_ultron_backEnd
# 0 ---> https://github.com/cmorty/realsim
# 19 ---> https://github.com/Andros-Spica/TIPC2-Angourakis-Graham-2018
# 7 ---> https://github.com/rigetti/pyquil
# 0 ---> https://github.com/antlr/codebuff
# 0 ---> https://github.com/vdenotaris/spring-boot-security-saml-sample
# 3 ---> https://github.com/ci-for-research/zenodo
# 4 ---> https://github.com/laduplessis/SARS-CoV-2_Guangdong_genomic_epidemiology
# 7 ---> https://github.com/sealuzh/cd-linter-artifacts
# 0 ---> https://github.com/clij/clij-ops
# 7 ---> https://github.com/bmcage/odes
# 7 ---> https://github.com/ryanvarley/ExoData
# 7 ---> https://github.com/poppy-project/pypot
# 7 ---> https://github.com/NLeSC/cptm
# 19 ---> https://github.com/ivanhercaz/research
# 7 ---> https://github.com/dib-lab/sourmash
# 5 ---> https://github.com/PecanProject/pecan
# 7 ---> https://github.com/thorstenwagner/ij-particlesizer
# 5 ---> https://github.com/ctsit/redi-dropper-client
# 7 ---> https://github.com/juseg/absplots
# 14 ---> https://github.com/tolliob/PhasePortrait
# 7 ---> https://github.com/gtaylor/python-colormath
# 7 ---> https://github.com/SoftwareDevEngResearch/PyFAT
# 7 ---> https://github.com/ComputationalRadiationPhysics/mallocMC
# 7 ---> https://github.com/Arabidopsis-Information-Portal/adama
# 10 ---> https://github.com/biowdl/RNA-seq
# 7 ---> https://github.com/RPGroup-PBoC/RNAseq_SortSeq
# 7 ---> https://github.com/mensBash/DataStewardship
# 7 ---> https://github.com/thetisproject/thetis
# 8 ---> https://github.com/nismod/smif
# 8 ---> https://github.com/mgndolan/phagesdb
# 7 ---> https://github.com/rajeshrinet/pystokes
# 7 ---> https://github.com/alan-turing-institute/azure_usage_v1
# 4 ---> https://github.com/rdfjs/N3.js
# 7 ---> https://github.com/s-utkarsh/convex
# 7 ---> https://github.com/docmanny/RecSearch
# 10 ---> https://github.com/BenediktKleppmann/TreeOfKnowledge
# 7 ---> https://github.com/fanatichuman/ZOOMIEv1.0
# 7 ---> https://github.com/subangstrom/usetemServers
# 0 ---> https://github.com/bio-guoda/preston
# 8 ---> https://github.com/molstar/molstar
# 7 ---> https://github.com/philrosenfield/core_overshoot_clusters
# 7 ---> https://github.com/a-slide/pycoQC
# 7 ---> https://github.com/Epistimio/orion
# 7 ---> https://github.com/tholoien/XDGMM
# 7 ---> https://github.com/PyTorchLightning/pytorch-lightning
# 0 ---> https://github.com/fusion-jena/CoMerger
# 7 ---> https://github.com/collectionslab/Omniscribe
# 7 ---> https://github.com/cohenlabUNC/clpipe
# 7 ---> https://github.com/harpolea/r3d2
# 0 ---> https://github.com/peterbanda/coel
# 7 ---> https://github.com/Xilinx/brevitas
# 5 ---> https://github.com/aulasoftwarelibre/taller-de-git
# 7 ---> https://github.com/ornlneutronimaging/iBeatles
# 10 ---> https://github.com/dennissergeev/arke
# 7 ---> https://github.com/awickert/GRLP
# 4 ---> https://github.com/na399/VAST-Challenge-2019-MC1
# 7 ---> https://github.com/schmelling/reciprocal_BLAST
# 7 ---> https://github.com/diana-hep/madminer
# 7 ---> https://github.com/fmorenopino/HeterogeneousHMM
# 7 ---> https://github.com/dslfaithdev/SocialCrawler
# 3 ---> https://github.com/AndrewIOM/global-pollen-project
# 7 ---> https://github.com/PySCeS/pysces
# 7 ---> https://github.com/DamCB/tyssue
# 7 ---> https://github.com/lsmo-epfl/discover-curated-cofs
# 7 ---> https://github.com/caltechlibrary/eprints2bags
# 7 ---> https://github.com/proycon/foliapy
# 7 ---> https://github.com/bird-house/twitcher
# 7 ---> https://github.com/ganga-devs/ganga
# 0 ---> https://github.com/kotik-coder/PULsE
# 7 ---> https://github.com/mozillazg/pinyin-data
# 7 ---> https://github.com/MicroPasts/EgyptExplorationSocBuhenPottery
# 7 ---> https://github.com/luispedro/imread
# 7 ---> https://github.com/PCMSolver/pcmsolver
# 0 ---> https://github.com/klout/brickhouse
# 8 ---> https://github.com/Dash-Industry-Forum/dash.js
# 7 ---> https://github.com/ProjectDrawdown/spatial-aez
# 8 ---> https://github.com/cytoscape/cytoscape.js-popper
# 5 ---> https://github.com/ecohealthalliance/pubcrawler
# 7 ---> https://github.com/underworldcode/stripy
# 7 ---> https://github.com/pycroscopy/pyUSID
# 7 ---> https://github.com/jjnp/dss20-ue1
# 7 ---> https://github.com/pytroll/satpy
# ...
# 3 ---> https://github.com/rw251/covid-health-impact
# 7 ---> https://github.com/danhey/echelle
# 3 ---> https://github.com/smart-facility/cognicity-rem-server
# 7 ---> https://github.com/cldf/pyigt
# 7 ---> https://github.com/marcomusy/vedo
# 7 ---> https://github.com/wjlei1990/pycmt3d
# 7 ---> https://github.com/SuLab/WikidataIntegrator
# 7 ---> https://github.com/g8a9/l3wrapper
# 17 ---> https://github.com/mic-umcg/samit
# 7 ---> https://github.com/BlueBrain/BluePyEfe
# 8 ---> https://github.com/mwittig/node-milight-promise
# 19 ---> https://github.com/jgcasta/CitiesAtNightPythonMadrid
# 7 ---> https://github.com/BenjaminIsaac0111/daedalus
# 7 ---> https://github.com/CiwPython/Ciw
# 7 ---> https://github.com/abhi1693/yii2-installer
# 0 ---> https://github.com/eclipse/golo-lang
# 0 ---> https://github.com/RMLio/RMLStreamer
# 5 ---> https://github.com/manodeep/Corrfunc
# 7 ---> https://github.com/jupiterbak/OPCUA2Vec
# 7 ---> https://github.com/luispedro/jug
# 7 ---> https://github.com/glukicov/EDMTracking
# 7 ---> https://github.com/GooFit/GooFit
# 7 ---> https://github.com/cghoffmann/mjoindices
# 19 ---> https://github.com/smart-facility/cognicity-rem-web
# 8 ---> https://github.com/higlass/higlass
# 10 ---> https://github.com/albert-torres/airfleet-scraper
# 7 ---> https://github.com/pysal/libpysal
# 7 ---> https://github.com/JoerivanEngelen/delta_aquifer
# 5 ---> https://github.com/xs-admin/Excess
# 7 ---> https://github.com/sustain-lab/Curcic-Haus-2020
# 7 ---> https://github.com/bjodah/pyodesys
# 7 ---> https://github.com/jmbr/diffusion-maps
# 10 ---> https://github.com/Yasin-VU/simple-python-bibliometrics
# 7 ---> https://github.com/sbaltes/github-retriever
# 7 ---> https://github.com/hibernator11/notebook-iiif-images
# 7 ---> https://github.com/Mellechowicz/JorG
# 7 ---> https://github.com/SRainGit/CAE-LO
# 7 ---> https://github.com/ahkab/ahkab
# 7 ---> https://github.com/kklmn/XAFSmass
# 7 ---> https://github.com/psyplot/psyplot
# 7 ---> https://github.com/jdmoorman/uclasm
# 7 ---> https://github.com/HBClab/NiBetaSeries
# 7 ---> https://github.com/rilma/pyHWM14
# 7 ---> https://github.com/pyxem/diffsims
# 7 ---> https://github.com/gboeing/pynamical
# 0 ---> https://github.com/rinde/evo4mas
# 0 ---> https://github.com/sing-group/strep_service
# 7 ---> https://github.com/obspy/obspy
# 7 ---> https://github.com/blobtoolkit/blobtools2
# 10 ---> https://github.com/saltastro/polsalt
# 6 ---> https://github.com/PyNIPT/pynipt-plugins
# 7 ---> https://github.com/andres-patrignani/pynotes
# 19 ---> https://github.com/atruskie/index-file-perf-test
# 8 ---> https://github.com/SoftwareDevEngResearch/lecture-open-science
# 7 ---> https://github.com/jmfrancklab/pyspecdata
# 7 ---> https://github.com/babelomics/SMAca
# 7 ---> https://github.com/firedrakeproject/tsfc
# 7 ---> https://github.com/saullocastro/composites
# 7 ---> https://github.com/qpv-research-group/solcore5
# 7 ---> https://github.com/pdkit/pdkit
# 7 ---> https://github.com/TUW-GEO/pytesmo
# 19 ---> https://github.com/Hypercubed/connectome
# 7 ---> https://github.com/cicwi/PyCorrectedEmissionCT
# 7 ---> https://github.com/crowelab/PyIR
# 4 ---> https://github.com/perseids-publications/treebank-template
# 7 ---> https://github.com/DeepRank/PSSMGen
# 0 ---> https://github.com/omaraa/ImageSURF
# 7 ---> https://github.com/ideasrule/platon
# 3 ---> https://github.com/RubenVerborgh/SPARQL.js
# 4 ---> https://github.com/eWaterCycle/jupyterlab_thredds
# 3 ---> https://github.com/smart-facility/cognicity-reports-detik
# 7 ---> https://github.com/BlueBrain/NeuroM
# 7 ---> https://github.com/ESA-VirES/VirES-Python-Client
# 7 ---> https://github.com/pyxem/pyxem
# 7 ---> https://github.com/diehlpk/paperBCBBPD
# 17 ---> https://github.com/kjgarza/frame_experiment
# 8 ---> https://github.com/JoKra1/GENTLE
# 3 ---> https://github.com/digitallinguistics/javascript
# 7 ---> https://github.com/ericbarnhill/JVCL
# 7 ---> https://github.com/Sulstice/molpdf
# 7 ---> https://github.com/wordsworthgroup/orthopoly
# 15 ---> https://github.com/DessimozLab/f1000_PhylogeneticTree
# 7 ---> https://github.com/lingpy/lingrex
# 7 ---> https://github.com/migueldvb/cine
# 7 ---> https://github.com/junzis/openap
# 7 ---> https://github.com/ECSIM/opem
# 7 ---> https://github.com/rdhyee/diversity-census-calc
# 2 ---> https://github.com/genetics-potato/OMIM_CLI
# 7 ---> https://github.com/biofloat/biofloat
# 7 ---> https://github.com/kLabUM/rrcf
# 7 ---> https://github.com/MHKiT-Software/MHKiT-Python
# 7 ---> https://github.com/andim/noisyopt
# 7 ---> https://github.com/zooniverse/aggregation-for-caesar
# 7 ---> https://github.com/mvdh7/PyCO2SYS
# 7 ---> https://github.com/discos/basie
# 7 ---> https://github.com/datalad/datalad-webapp
# 7 ---> https://github.com/collab-uniba/pySOreputation
# 7 ---> https://github.com/mutterer/ActionBar
# 7 ---> https://github.com/tudelft3d/geo1101.2020.ahn3
# 7 ---> https://github.com/yaoyongxin/CyGutz
# 7 ---> https://github.com/ufo-kit/concert
# 7 ---> https://github.com/Neurosim-lab/netpyne
# 7 ---> https://github.com/KeplerGO/k2mosaic
# 0 ---> https://github.com/saalfeldlab/paintera
# 7 ---> https://github.com/zakandrewking/hindsight
# 7 ---> https://github.com/dfm/corner.py
# 14 ---> https://github.com/KarrLab/paper_cell_sys__guidelines_4_repro_models_2020
# 7 ---> https://github.com/ihmeuw/covid-shared
# 7 ---> https://github.com/saullocastro/cubature
# 10 ---> https://github.com/bjpop/svfilter
# 7 ---> https://github.com/RISE-MPIWG/hylg
# 7 ---> https://github.com/casmlab/purpletag
# 7 ---> https://github.com/alimanfoo/anhima
# 10 ---> https://github.com/50417/DeepFuzzSL
# 0 ---> https://github.com/JULIELab/gene-name-mapping
# 7 ---> https://github.com/PPPI/Flexeme
# 7 ---> https://github.com/cfe-lab/MiCall
# 0 ---> https://github.com/ponder-lab/Logging-Level-Evolution-Plugin
# 10 ---> https://github.com/blekhmanlab/panlingua
# 7 ---> https://github.com/saullocastro/tudaesasII
# 7 ---> https://github.com/joergdietrich/NFW
# 10 ---> https://github.com/sandyherho/tutorial_xarray
# 7 ---> https://github.com/deniederhut/PyTeX
# 7 ---> https://github.com/interaction-lab/MoveToCode
# 7 ---> https://github.com/FilipeMaia/afnumpy
# 7 ---> https://github.com/nextgenusfs/amptk
# 7 ---> https://github.com/Qiskit/qiskit
# 7 ---> https://github.com/CU-Denver-UQ/LUQ
# 7 ---> https://github.com/casimp/lightct
# 7 ---> https://github.com/joostjor/random-graphs
# 7 ---> https://github.com/sbonaretti/pyKNEEr
# 7 ---> https://github.com/DataMedSci/pymchelper
# 7 ---> https://github.com/simonvh/pita
# 7 ---> https://github.com/Socrats/EGTTools
# 5 ---> https://github.com/ihmwg/python-ihm
# 7 ---> https://github.com/AlessioZanga/PyEEGLab
# 7 ---> https://github.com/samuelstjean/autodmri
# 4 ---> https://github.com/filips123/ZeroFrameJS
# 0 ---> https://github.com/Tyler-Yates/AestheticFractals
# 7 ---> https://github.com/jakevdp/supersmoother
# 7 ---> https://github.com/fmalmeida/ngs-preprocess
# 7 ---> https://github.com/junhyeokahn/tf_rbdl
# 7 ---> https://github.com/Samreay/ChainConsumer
# 7 ---> https://github.com/JoshuaE1/supervised-classification-SSH-publications
# 7 ---> https://github.com/syhw/DTW_Cython
# 7 ---> https://github.com/cerebunit/cerebunit
# 7 ---> https://github.com/clebsonpy/HidroComp
# 0 ---> https://github.com/Terradue/dcs-insar-roipac
# 7 ---> https://github.com/drcassar/viscosity-graybox-nn
# 7 ---> https://github.com/MAVENSDC/PyTplot
# 10 ---> https://github.com/EricAlcaide/MiniFold
# 7 ---> https://github.com/CognitiveComputationLab/ccobra
# 7 ---> https://github.com/holoviz/colorcet
# 7 ---> https://github.com/jpvantassel/hvsrpy
# 19 ---> https://github.com/georgeOsdDev/longo
# 16 ---> https://github.com/unicus-skmk/test
# 7 ---> https://github.com/DTUComputeStatisticsAndDataAnalysis/MBPLS
# 7 ---> https://github.com/hyungjun/gtool
# 19 ---> https://github.com/UofS-Pulse-Binfo/nd_genotypes
# 7 ---> https://github.com/michaelaye/pyciss
# 7 ---> https://github.com/genomematt/pylazybam
# 7 ---> https://github.com/arkottke/pygmm
# 3 ---> https://github.com/evanodell/ukpolice
# 7 ---> https://github.com/kotori-y/Scopy
# 7 ---> https://github.com/gsantoni/ccCluster
# 7 ---> https://github.com/iancze/MPoL
# 7 ---> https://github.com/jacobo-diaz/aneupy
# 0 ---> https://github.com/j-stone/cog-tasks
# 7 ---> https://github.com/broyson/Locust-streaming
# 7 ---> https://github.com/rougier/numpy-100
# 7 ---> https://github.com/castelao/supportdata
# 7 ---> https://github.com/napsternxg/TwitterNER
# 7 ---> https://github.com/DomBennett/TaxonNamesResolver
# 7 ---> https://github.com/lucaspuvis/SAM
# 7 ---> https://github.com/caltechlibrary/handprint
# 17 ---> https://github.com/unipept/unipept-cli
# 7 ---> https://github.com/griffithlab/pVACtools
# 7 ---> https://github.com/MAGIC-nexus/nis-python-client
# 7 ---> https://github.com/spacetelescope/jwst-fgs-countrate
# 0 ---> https://github.com/skp703/RainInterpolator
# 7 ---> https://github.com/pysal/spvcm
# 7 ---> https://github.com/CKrawczyk/densityplot
# 7 ---> https://github.com/Abe404/root_painter
# 10 ---> https://github.com/freeknijweide/autoencoder-pdb-cleaning
# 7 ---> https://github.com/reegis/deflex
# 7 ---> https://github.com/DCAN-Labs/nhp-abcd-bids-pipeline
# 7 ---> https://github.com/MechMicroMan/DefDAP
# 7 ---> https://github.com/Climdyn/qgs
# 7 ---> https://github.com/anil88/population-origin-calculator
# 8 ---> https://github.com/AlgolLLC/phonetop
# 7 ---> https://github.com/jdmoorman/kaczmarz-algorithms
# 7 ---> https://github.com/qzhu2017/PyXtal_FF
# 8 ---> https://github.com/rodighiero/DH2019
# 7 ---> https://github.com/ioos/erddapy
# 7 ---> https://github.com/bjorntsv/tempmom
# 7 ---> https://github.com/ARM-DOE/ACT
# 7 ---> https://github.com/tvwenger/millennium-tap-query
# 0 ---> https://github.com/3D-e-Chem/knime-klifs
# 7 ---> https://github.com/harnesscloud/nova-docker
# 7 ---> https://github.com/Clinical-Genomics/chanjo
# 0 ---> https://github.com/globalbioticinteractions/elton
# 0 ---> https://github.com/felicitia/TestBenchmark-Java-client
# 10 ---> https://github.com/butcer0/found-diagnosis-network
# 7 ---> https://github.com/radtorch/radtorch
# 7 ---> https://github.com/UT-CHG/PolyADCIRC
# 7 ---> https://github.com/parsa-epfl/qflex
# 16 ---> https://github.com/MJOLNIRPackage/MJOLNIR-GUI
# 7 ---> https://github.com/martibosch/detectree
# 8 ---> https://github.com/nawrs/nawrs
# 17 ---> https://github.com/arfon/metamatter
# 7 ---> https://github.com/linsalrob/PPPF
# 7 ---> https://github.com/peckhams/topoflow
# 7 ---> https://github.com/mekman/recon
# 7 ---> https://github.com/petl-developers/petl
# 0 ---> https://github.com/piyush82/expression-evaluator
# 7 ---> https://github.com/MAVENSDC/cdflib
# 7 ---> https://github.com/acocac/MTLCC-MODIS-GCP
# 0 ---> https://github.com/nomencurator/taxonaut
# 7 ---> https://github.com/jw156605/MATCHER
# 7 ---> https://github.com/vprusso/toqito
# 7 ---> https://github.com/abhi1693/yii2-config
# 7 ---> https://github.com/scikit-hep/uproot-methods
# 10 ---> https://github.com/JustinGOSSES/predictatops
# 7 ---> https://github.com/ThomasRieutord/kabl
# 7 ---> https://github.com/pastas/pastas
# 7 ---> https://github.com/lingpy/workflow-paper
# 7 ---> https://github.com/tomwallis/PsyUtils
# 7 ---> https://github.com/adrn/gala
# 7 ---> https://github.com/kinnala/scikit-fem
# 7 ---> https://github.com/yatiml/yatiml
# 7 ---> https://github.com/ZFTurbo/Weighted-Boxes-Fusion
# 17 ---> https://github.com/willpearse/data_frame
# 0 ---> https://github.com/jameshowison/softcite
# 15 ---> https://github.com/clauswilke/PeptideBuilder
# 10 ---> https://github.com/GatorSense/HyperspectralAnalysisIntroduction
# 7 ---> https://github.com/MultithreadCorner/Hydra
# 0 ---> https://github.com/mgiorgio/comet-utilities
# 7 ---> https://github.com/specpose/stopeight
# 7 ---> https://github.com/MIC-DKFZ/cmdint
# 7 ---> https://github.com/pysat/pysatMadrigal
# 14 ---> https://github.com/berenslab/pr_bc_connectivity
# 7 ---> https://github.com/helioforecast/Predstorm
# 8 ---> https://github.com/datproject/dat
# 7 ---> https://github.com/TUW-GEO/ease_grid
# 7 ---> https://github.com/hrtlacek/faustTools
# 7 ---> https://github.com/Abe404/segmentation_of_roots_in_soil_with_unet
# 7 ---> https://github.com/ctreffe/alfred
# 17 ---> https://github.com/myGrid/ruby-zip-container
# 7 ---> https://github.com/ECSIM/pem-dataset1
# 7 ---> https://github.com/perryuu/managpu
# 7 ---> https://github.com/IceCubeOpenSource/ASTERIA
# 17 ---> https://github.com/jeremyf/orcid_album_cover
# 7 ---> https://github.com/josemiotto/pylevy
# 7 ---> https://github.com/JolleJolles/pirecorder
# 7 ---> https://github.com/mdolab/pygeo
# 7 ---> https://github.com/TUW-GEO/rt1
# 7 ---> https://github.com/AnyBody-Research-Group/AnyPyTools
# 7 ---> https://github.com/Yefee/xMCA
# 7 ---> https://github.com/rlworkgroup/garage
# 0 ---> https://github.com/theblackunknown/creative-ecosystems
# 7 ---> https://github.com/simpeg/discretize
# 10 ---> https://github.com/tactcomplabs/xbgas-tools
# 7 ---> https://github.com/LRCFS/GSR_Paper
# 7 ---> https://github.com/soft-matter/trackpy
# 7 ---> https://github.com/jrleeman/biaxtools
# 7 ---> https://github.com/JaGeo/PaulingPublication
# 13 ---> https://github.com/tobysmith568/License-Sorter
# 7 ---> https://github.com/navanchauhan/VaporwaveGenerator
# 10 ---> https://github.com/samik1986/ML_Semantic_Segmenation_NMI
# 7 ---> https://github.com/multiscale/ymmsl-python
# 7 ---> https://github.com/anitagraser/movingpandas
# 1 ---> https://github.com/fls-bioinformatics-core/RnaChipIntegrator
# 7 ---> https://github.com/bionet/ted.python
# 0 ---> https://github.com/thorstenwagner/ij-trackmate-findmaxima
# 7 ---> https://github.com/NHERI-SimCenter/pelicun
# 7 ---> https://github.com/hibernator11/AprendiendoPython
# 7 ---> https://github.com/danieljfarrell/pvtrace
# 7 ---> https://github.com/neuroscout/neuroscout-cli
# 7 ---> https://github.com/MichaelMauderer/Gazer
# 0 ---> https://github.com/FedUni/caliko
# 7 ---> https://github.com/vcutrona/elasticpedia
# 0 ---> https://github.com/aleksandarsibincic/ExcelAudit
# 7 ---> https://github.com/aldnav/abempy
# 7 ---> https://github.com/spectrochempy/spectrochempy
# 7 ---> https://github.com/isi-nmr/bruker2bart
# 7 ---> https://github.com/HobnobMancer/PhD_Project_Scripts
# 7 ---> https://github.com/drcassar/glasspy
# 14 ---> https://github.com/rieder/MASC
# 15 ---> https://github.com/oblassers/tuw-servicebroker
# 7 ---> https://github.com/Nelson-Gon/pyautocv
# 7 ---> https://github.com/jajcayn/pygpso
# 15 ---> https://github.com/Craig-Robson/postgres_spatial_join_areas
# 8 ---> https://github.com/MAGIC-nexus/nis-graph-diagrams
# 0 ---> https://github.com/silviodc/Gazetteer
# 7 ---> https://github.com/alchemistry/alchemlyb
# 0 ---> https://github.com/timtroendle/energy-agents
# 7 ---> https://github.com/xgcm/xgcm
# 7 ---> https://github.com/mheikenfeld/wrfcube
# 0 ---> https://github.com/sojamo/midimapper
# 7 ---> https://github.com/datreant/MDSynthesis
# 7 ---> https://github.com/UNSW-CEEM/NEMOSIS
# 7 ---> https://github.com/KeplerGO/K2fov
# 7 ---> https://github.com/atorras1618/PerMaViss
# 7 ---> https://github.com/tubiana/TTClust
# 7 ---> https://github.com/matt-long/xpersist
# 7 ---> https://github.com/bast/smeshing
# 10 ---> https://github.com/Scifabric/pybossa
# 7 ---> https://github.com/ds-wizard/docs
# 7 ---> https://github.com/abelcarreras/phonolammps
# 7 ---> https://github.com/jason-zl190/sisr_medical
# 7 ---> https://github.com/mdshw5/pyfaidx
# 7 ---> https://github.com/wiebket/delprocess
# 7 ---> https://github.com/holoviz/datashader
# 7 ---> https://github.com/ISA-tools/mzml2isa
# 7 ---> https://github.com/ajefweiss/HelioSat
# 7 ---> https://github.com/houghb/savvy
# 5 ---> https://github.com/fnl/gnamed
# 7 ---> https://github.com/jjgomera/iapws
# 17 ---> https://github.com/dicom/rtp-connect
# 7 ---> https://github.com/moonso/genmod
# 7 ---> https://github.com/zafarali/emdp
# 7 ---> https://github.com/phydev/trajpy
# 7 ---> https://github.com/IMMM-SFA/im3py
# 7 ---> https://github.com/yadage/yadage-schemas
# 7 ---> https://github.com/karenadam/Mixed-Bandlimited-Time-Encoding
# 7 ---> https://github.com/spacetelescope/gwcs
# 7 ---> https://github.com/mkjung99/pyc3dserver
# 7 ---> https://github.com/reegis/reegis
# 7 ---> https://github.com/kimlab/GPyM
# 7 ---> https://github.com/woutergins/satlas
# 7 ---> https://github.com/lachhebo/pyclustertend
# 7 ---> https://github.com/wiebket/delretrieve
# 3 ---> https://github.com/digitallinguistics/transliterate
# 7 ---> https://github.com/nlesc-nano/Nano-Utils
# 7 ---> https://github.com/oemof/oemof-thermal

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
pyLDAvis.save_html(vis, 'lda.html')
