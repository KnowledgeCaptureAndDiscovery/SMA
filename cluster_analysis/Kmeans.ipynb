# %%
import json
import numpy
import re
import os
import numpy as np
import gensim
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from gensim.models import Doc2Vec

# %% [markdown]
# ## Load data

# %%
input_file ='../data/result_13k.json'
with open(input_file) as f:
    data = json.load(f)
print(f'repos nums: {len(data)}')

need_to_remove = []
for k,v in data.items():
    if 'No dependency' in v:
        need_to_remove.append(k)
print(f'repos which have no dependency files: {len(need_to_remove)}')

for k in need_to_remove:
    del data[k]
print(f'repos with dependency files: {len(data)}')

rep_list,dep_list = [],[]
for k,v in data.items():
    rep_list.append(k)
    dep_list.append(v)
    
dep_dict = {}
for deps in data.values():
    for i in deps:
        dep_dict[i] = dep_dict.get(i,0)+1

print(f'Distinct dependency file: {len(dep_dict)}',end='\n\n')
# Out:
# repos nums: 3012
# repos which have no dependency files: 0
# repos with dependency files: 3012
# Distinct dependency file: 15663

# %%
dep_list,len(dep_list)
# Out:
# ([['ipython',
#    'jupyter-sphinx',
#    'nbformat',
#    'nbsphinx',
#    'path-py',
#    'six',
#    'sphinx',
#    'sphinx-hoverxref',
#    'sphinx-rtd-theme'],
#   ['pypng', 'requests'],
#   ['bleach',
#    'click',
#    'docutils',
#    'joblib',
#    'keras',
#    'matplotlib',
#    'numpy',
#    'opencv-python',
#    'pandas',
#    'pillow',
#    'pkginfo',
#    'plotly',
#    'pygments',
#    'scikit-image',
#    'scipy',
#    'seaborn',
#    'setuptools',
#    'tensorboard',
#    'tensorflow',
#    'tqdm'],
#   ['numpy'],
#   ['biopython'],
#   ['libconfig',
#    'matplotlib',
#    'numpy',
#    'pandas',
#    'rstoolbox',
#    'scipy',
#    'seaborn',
#    'transforms3d'],
#   ['argparse',
#    'astropy',
#    'matplotlib',
#    'mwa-pb',
#    'mwa-voltage',
#    'numpy',
#    'psrqpy',
#    'pytest'],
#   ['coverage',
#    'mkdocs',
#    'mkdocs-material',
#    'tox',
#    'loguru',
#    'mypy',
#    'pyrallel-lib',
#    'rdflib',
#    'redis',
#    'rltk',
#    'seaborn',
#    'sentence-transformers',
#    'simplejson',
#    'sklearn',
#    'sparqlwrapper',
#    'tqdm',
#    'attrs',
#    'etk',
#    'iso-639',
#    'lz4',
#    'plac',
#    'pycountry',
#    'rfc3986',
#    'sh',
#    'shortuuid',
#    'thinc'],
#   ['numpy', 'pytest'],
#   ['pyrabbit', 'pyvirtualdisplay', 'selenium', 'splinter'],
#   ['biz.aQute.bnd:bnd-maven-plugin',
#    'com.google.guava:guava',
#    'com.helger.maven:ph-javacc-maven-plugin',
#    'javax.xml.bind:jaxb-api',
#    'junit:junit',
#    'org.apache.maven.plugins:maven-clean-plugin',
#    'org.apache.maven.plugins:maven-compiler-plugin',
#    'org.apache.maven.plugins:maven-dependency-plugin',
#    'org.apache.maven.plugins:maven-deploy-plugin',
#    'org.apache.maven.plugins:maven-install-plugin',
#    'org.apache.maven.plugins:maven-jar-plugin',
#    'org.apache.maven.plugins:maven-javadoc-plugin',
#    'org.apache.maven.plugins:maven-release-plugin',
#    'org.apache.maven.plugins:maven-resources-plugin',
#    'org.apache.maven.plugins:maven-site-plugin',
#    'org.apache.maven.plugins:maven-source-plugin',
#    'org.apache.maven.plugins:maven-surefire-plugin',
#    'org.codehaus.mojo:build-helper-maven-plugin',
#    'org.codehaus.mojo:exec-maven-plugin',
#    'org.codehaus.mojo:templating-maven-plugin',
#    'org.codehaus.mojo:versions-maven-plugin',
#    'org.eluder.coveralls:coveralls-maven-plugin',
#    'org.hamcrest:hamcrest-library',
#    'org.jacoco:jacoco-maven-plugin',
#    'org.javassist:javassist',
#    'org.junit-pioneer:junit-pioneer',
#    'org.junit.jupiter:junit-jupiter-engine',
#    'org.junit.jupiter:junit-jupiter-params',
#    'org.junit.vintage:junit-vintage-engine',
#    'org.mockito:mockito-core',
#    'com.github.javaparser:javaparser-core',
#    'com.squareup.okhttp3:okhttp',
#    'org.assertj:assertj-core',
#    'com.github.valfirst:jbehave-junit-runner',
#    'org.jbehave:jbehave-core',
#    'javax.json:javax.json-api',
#    'org.glassfish:javax.json',
#    'com.github.javaparser:javaparser-symbol-solver-core'],
#   ['matplotlib',
#    'numpy',
#    'pandas',
#    'scipy',
#    'astropy',
#    'fastkde',
#    'getdist',
#    'pytest',
#    'cython',
#    'numpydoc',
#    'sphinx',
#    'sphinx-rtd-theme'],
#   ['torch', 'vak'],
#   ['numpy', 'python-sat'],
#   ['logomaker',
#    'matplotlib',
#    'numpy',
#    'numpydoc',
#    'pandas',
#    'seaborn',
#    'sklearn',
#    'sphinx-rtd-theme',
#    'suftware',
#    'tensorflow',
#    'scipy'],
#   ['hdf5storage', 'matplotlib', 'scipy', 'segyio', 'seiscl', 'tensorflow-gpu'],
#   ['ipython',
#    'nbsphinx',
#    'pydata-sphinx-theme',
#    'setuptools-scm',
#    'sphinx',
#    'cython',
#    'pytest',
#    'pytest-cov',
#    'cvxopt',
#    'cvxpy',
#    'joblib',
#    'numexpr',
#    'numpy',
#    'osqp',
#    'pandas',
#    'scikit-learn',
#    'scipy'],
#   ['pyhamcrest'],
#   ['actionpack',
#    'activerecord',
#    'byebug',
#    'pg',
#    'rake',
#    'sinatra-activerecord',
#    'actionview',
#    'activemodel',
#    'activesupport',
#    'arel',
#    'builder',
#    'erubis',
#    'i18n',
#    'json',
#    'loofah',
#    'minitest',
#    'mini_portile2',
#    'nokogiri',
#    'pkg-config',
#    'rack',
#    'rack-protection',
#    'rack-test',
#    'rails-deprecated_sanitizer',
#    'rails-dom-testing',
#    'rails-html-sanitizer',
#    'sinatra',
#    'thread_safe',
#    'tilt',
#    'tzinfo'],
#   ['express',
#    'grunt',
#    'grunt-autoprefixer',
#    'grunt-cli',
#    'grunt-contrib-connect',
#    'grunt-contrib-cssmin',
#    'grunt-contrib-jshint',
#    'grunt-contrib-qunit',
#    'grunt-contrib-uglify',
#    'grunt-contrib-watch',
#    'grunt-sass',
#    'grunt-zip',
#    'mustache',
#    'node-sass',
#    'socket.io'],
#   ['-',
#    'h5py',
#    'matplotlib',
#    'numpy',
#    'pandas',
#    'pillow',
#    'pooch',
#    'scipy',
#    'sdtfile',
#    'tqdm'],
#   ['h5py', 'healpy', 'matplotlib', 'numba', 'numpy', 'scipy', 'six'],
#   ['coverage',
#    'flake8',
#    'pytest',
#    'pytest-cov',
#    'pytest-env',
#    '@babel/code-frame',
#    '@babel/helper-validator-identifier',
#    '@babel/highlight',
#    '@types/color-name',
#    'acorn',
#    'acorn-jsx',
#    'ajv',
#    'ansi-colors',
#    'ansi-regex',
#    'ansi-styles',
#    'argparse',
#    'astral-regex',
#    'balanced-match',
#    'brace-expansion',
#    'callsites',
#    'chalk',
#    'color-convert',
#    'color-name',
#    'concat-map',
#    'cross-spawn',
#    'debug',
#    'deep-is',
#    'doctrine',
#    'emoji-regex',
#    'enquirer',
#    'escape-string-regexp',
#    'eslint',
#    'eslint-scope',
#    'eslint-utils',
#    'eslint-visitor-keys',
#    'espree',
#    'esprima',
#    'esquery',
#    'esrecurse',
#    'estraverse',
#    'esutils',
#    'fast-deep-equal',
#    'fast-json-stable-stringify',
#    'fast-levenshtein',
#    'file-entry-cache',
#    'flat-cache',
#    'flatted',
#    'fs.realpath',
#    'functional-red-black-tree',
#    'glob',
#    'glob-parent',
#    'globals',
#    'has-flag',
#    'ignore',
#    'import-fresh',
#    'imurmurhash',
#    'inflight',
#    'inherits',
#    'is-extglob',
#    'is-fullwidth-code-point',
#    'is-glob',
#    'isexe',
#    'js-tokens',
#    'js-yaml',
#    'json-schema-traverse',
#    'json-stable-stringify-without-jsonify',
#    'levn',
#    'lodash',
#    'minimatch',
#    'minimist',
#    'mkdirp',
#    'ms',
#    'natural-compare',
#    'once',
#    'optionator',
#    'parent-module',
#    'path-is-absolute',
#    'path-key',
#    'prelude-ls',
#    'progress',
#    'punycode',
#    'regexpp',
#    'resolve-from',
#    'rimraf',
#    'semver',
#    'shebang-command',
#    'shebang-regex',
#    'slice-ansi',
#    'sprintf-js',
#    'string-width',
#    'strip-ansi',
#    'strip-json-comments',
#    'supports-color',
#    'table',
#    'text-table',
#    'type-check',
#    'type-fest',
#    'uri-js',
#    'v8-compile-cache',
#    'which',
#    'word-wrap',
#    'wrappy',
#    'write'],
#   ['lxml', 'requests', 'tqdm'],
#   ['@fnndsc/chrisapi',
#    '@fortawesome/fontawesome-svg-core',
#    '@fortawesome/free-regular-svg-icons',
#    '@fortawesome/free-solid-svg-icons',
#    '@fortawesome/react-fontawesome',
#    '@material-ui/core',
#    '@patternfly/patternfly',
#    '@patternfly/react-core',
#    '@patternfly/react-table',
#    '@testing-library/jest-dom',
#    '@testing-library/react',
#    '@types/c3',
#    '@types/classnames',
#    '@types/d3',
#    '@types/dat.gui',
#    '@types/enzyme',
#    '@types/hammerjs',
#    '@types/history',
#    '@types/jest',
#    '@types/keymirror',
#    '@types/lodash',
#    '@types/material-ui',
#    '@types/node',
#    '@types/react',
#    '@types/react-bootstrap-typeahead',
#    '@types/react-dom',
#    '@types/react-redux',
#    '@types/react-router-dom',
#    '@types/redux-logger',
#    '@types/three',
#    '@types/uuid',
#    'antd',
#    'axios',
#    'bootstrap',
#    'c3',
#    'classnames',
#    'cornerstone-core',
#    'cornerstone-file-image-loader',
#    'cornerstone-math',
#    'cornerstone-tools',
#    'cornerstone-wado-image-loader',
#    'cornerstone-web-image-loader',
#    'd3',
#    'd3v4',
#    'dicom-parser',
#    'enzyme',
#    'enzyme-adapter-react-16',
#    'hammerjs',
#    'history',
#    'jest-enzyme',
#    'jszip',
#    'keymirror',
#    'lodash',
#    'moment',
#    'node-sass',
#    'pako',
#    'rc-tree',
#    'react',
#    'react-bootstrap-typeahead',
#    'react-cornerstone-viewport',
#    'react-dom',
#    'react-json-view',
#    'react-moment',
#    'react-redux',
#    'react-router',
#    'react-router-dom',
#    'react-scripts',
#    'react-ui-tree',
#    'redux-logger',
#    'redux-mock-store',
#    'redux-saga',
#    'reselect',
#    'three',
#    'tslint',
#    'typesafe-actions',
#    'typescript',
#    'uuid',
#    'webcola'],
#   ['activerecord-import',
#    'bootstrap-sass',
#    'coffee-rails',
#    'daemons',
#    'delayed_job_active_record',
#    'execjs',
#    'font-awesome-rails',
#    'handlebars_assets',
#    'quiet_assets',
#    'qunit-rails',
#    'rack-cache',
#    'rails',
#    'rake',
#    'sass',
#    'sass-rails',
#    'sqlite3',
#    'uglifier',
#    'uuidtools',
#    'handlebars',
#    'karma',
#    'karma-chrome-launcher',
#    'karma-ember-preprocessor',
#    'karma-firefox-launcher',
#    'karma-phantomjs-launcher',
#    'karma-qunit',
#    'qunitjs'],
#   ['numba', 'numpy', 'scipy', 'pytest', 'nbsphinx', 'sphinx-rtd-theme'],
#   ['matplotlib',
#    'matplotlib-scalebar',
#    'numpy',
#    'openpyxl',
#    'pandas',
#    'scipy',
#    'seaborn',
#    'statsmodels',
#    'xlrd'],
#   ['jupyter', 'matplotlib', 'pandas', 'seaborn'],
#   ['github-pages',
#    'jekyll',
#    'activesupport',
#    'addressable',
#    'coffee-script',
#    'coffee-script-source',
#    'colorator',
#    'commonmarker',
#    'concurrent-ruby',
#    'dnsruby',
#    'em-websocket',
#    'ethon',
#    'eventmachine',
#    'execjs',
#    'faraday',
#    'ffi',
#    'forwardable-extended',
#    'gemoji',
#    'github-pages-health-check',
#    'html-pipeline',
#    'http_parser.rb',
#    'i18n',
#    'jekyll-avatar',
#    'jekyll-coffeescript',
#    'jekyll-commonmark',
#    'jekyll-commonmark-ghpages',
#    'jekyll-default-layout',
#    'jekyll-feed',
#    'jekyll-gist',
#    'jekyll-github-metadata',
#    'jekyll-mentions',
#    'jekyll-optional-front-matter',
#    'jekyll-paginate',
#    'jekyll-readme-index',
#    'jekyll-redirect-from',
#    'jekyll-relative-links',
#    'jekyll-remote-theme',
#    'jekyll-sass-converter',
#    'jekyll-seo-tag',
#    'jekyll-sitemap',
#    'jekyll-swiss',
#    'jekyll-theme-architect',
#    'jekyll-theme-cayman',
#    'jekyll-theme-dinky',
#    'jekyll-theme-hacker',
#    'jekyll-theme-leap-day',
#    'jekyll-theme-merlot',
#    'jekyll-theme-midnight',
#    'jekyll-theme-minimal',
#    'jekyll-theme-modernist',
#    'jekyll-theme-primer',
#    'jekyll-theme-slate',
#    'jekyll-theme-tactile',
#    'jekyll-theme-time-machine',
#    'jekyll-titles-from-headings',
#    'jekyll-watch',
#    'jemoji',
#    'liquid',
#    'listen',
#    'mercenary',
#    'minima',
#    'minitest',
#    'mini_portile2',
#    'multipart-post',
#    'nokogiri',
#    'octokit',
#    'pathutil',
#    'public_suffix',
#    'rb-fsevent',
#    'rb-inotify',
#    'rouge',
#    'ruby-enum',
#    'rubyzip',
#    'ruby_dep',
#    'safe_yaml',
#    'sass',
#    'sass-listen',
#    'sawyer',
#    'terminal-table',
#    'thread_safe',
#    'typhoeus',
#    'tzinfo',
#    'unicode-display_width'],
#   ['pyaml',
#    'pyld',
#    'pythonql3',
#    'rdflib',
#    'rdflib-jsonld',
#    'requests',
#    'simplejson',
#    'six',
#    'sparqltransformer',
#    'urllib3',
#    'validators',
#    'webencodings',
#    'werkzeug',
#    'sparqlwrappermosorio',
#    'codecov',
#    'coverage',
#    'pytest',
#    'pytest-cov'],
#   ['h5py', 'numba', 'numpy', 'pybind11', 'pytest', 'scipy', 'breathe'],
#   ['biopython', 'matplotlib', 'networkx', 'numpy'],
#   ['com.aliasi:lingpipe',
#    'com.beust:jcommander',
#    'com.codahale.metrics:metrics-core',
#    'com.google.code.gson:gson',
#    'com.google.guava:guava',
#    'com.hmsonline:storm-cassandra',
#    'com.maxmind.geoip2:geoip2',
#    'commons-collections:commons-collections',
#    'joda-time:joda-time',
#    'junit:junit',
#    'log4j:log4j',
#    'org.apache.commons:commons-lang3',
#    'org.apache.hadoop:hadoop-core',
#    'org.apache.httpcomponents:httpclient',
#    'org.apache.httpcomponents:httpcore',
#    'org.apache.maven.plugins:maven-assembly-plugin',
#    'org.apache.maven.plugins:maven-compiler-plugin',
#    'org.apache.storm:storm-core',
#    'org.apache.storm:storm-kafka',
#    'org.codehaus.jackson:jackson-mapper-asl',
#    'org.geotools:gt-shapefile',
#    'org.geotools:gt-xml',
#    'org.postgis:postgis-jdbc',
#    'org.slf4j:slf4j-api',
#    'org.slf4j:slf4j-log4j12',
#    'org.twitter4j:twitter4j-core',
#    'org.twitter4j:twitter4j-stream',
#    'redis.clients:jedis',
#    'tabulate'],
#   ['cartopy', 'matplotlib', 'numpy', 'scipy', 'pyproj'],
#   ['altair', 'folium', 'jupyterlab', 'pandas', 'requests', 'tqdm', 'vega'],
#   ['cglib:cglib',
#    'com.thoughtworks.xstream:xstream',
#    'commons-dbcp:commons-dbcp',
#    'commons-fileupload:commons-fileupload',
#    'commons-lang:commons-lang',
#    'javax.servlet.jsp:jsp-api',
#    'javax.servlet:jstl',
#    'javax.servlet:servlet-api',
#    'javax.transaction:jta',
#    'junit:junit',
#    'log4j:log4j',
#    'net.sf.ehcache:ehcache-core',
#    'ognl:ognl',
#    'org.apache.derby:derby',
#    'org.apache.lucene:lucene-fast-vector-highlighter',
#    'org.apache.maven.plugins:maven-compiler-plugin',
#    'org.apache.maven.plugins:maven-dependency-plugin',
#    'org.apache.maven.plugins:maven-javadoc-plugin',
#    'org.apache.maven.plugins:maven-war-plugin',
#    'org.codehaus.jackson:jackson-mapper-asl',
#    'org.hibernate:hibernate-annotations',
#    'org.hibernate:hibernate-search',
#    'org.hibernate:hibernate-validator',
#    'org.javassist:javassist',
#    'org.mortbay.jetty:jetty',
#    'org.mortbay.jetty:jsp-2.1-jetty',
#    'org.opensymphony.quartz:quartz',
#    'org.slf4j:slf4j-api',
#    'org.slf4j:slf4j-log4j12',
#    'org.springframework.security:spring-security-config',
#    'org.springframework.security:spring-security-core',
#    'org.springframework.security:spring-security-taglibs',
#    'org.springframework.security:spring-security-web',
#    'org.springframework:spring-beans',
#    'org.springframework:spring-context',
#    'org.springframework:spring-core',
#    'org.springframework:spring-orm',
#    'org.springframework:spring-web',
#    'org.springframework:spring-webmvc',
#    'org.tuckey:urlrewritefilter',
#    'postgresql:postgresql',
#    'shap-extra:commons-cli',
#    'shap-extra:sun-drmaa'],
#   ['ipydatawidgets',
#    'ipywidgets',
#    'numpy',
#    'six',
#    'traitlets',
#    'traittypes',
#    '@jupyter-widgets/base',
#    'chai',
#    'components-webfontloader',
#    'compression',
#    'compression-webpack-plugin',
#    'connect-livereload',
#    'copy-webpack-plugin',
#    'cors',
#    'css-loader',
#    'dom-to-image',
#    'es6-promise',
#    'express',
#    'file-loader',
#    'file-saver',
#    'grunt',
#    'grunt-contrib-clean',
#    'grunt-contrib-connect',
#    'grunt-contrib-jshint',
#    'grunt-contrib-watch',
#    'grunt-curl',
#    'grunt-express-server',
#    'grunt-jscs',
#    'grunt-jsdoc',
#    'grunt-karma',
#    'grunt-open',
#    'grunt-webpack',
#    'jasmine-core',
#    'jshint-stylish',
#    'json-loader',
#    'jupyter-dataserializers',
#    'karma',
#    'karma-firefox-launcher',
#    'karma-jasmine',
#    'karma-requirejs',
#    'karma-spec-reporter',
#    'katex',
#    'load-grunt-tasks',
#    'lodash',
#    'msgpack-lite',
#    'pako',
#    'rasterizehtml',
#    'raw-loader',
#    'requirejs',
#    'resemblejs',
#    'screenfull',
#    'stats.js',
#    'style-loader',
#    'three',
#    'three-mesh-bvh',
#    'time-grunt',
#    'url-loader',
#    'webpack',
#    'webpack-cli',
#    'webpack-combine-loaders',
#    'webpack-node-externals',
#    'webpack-visualizer-plugin',
#    'worker-loader',
#    'jupyter-sphinx',
#    'nbsphinx',
#    'nbsphinx-link',
#    'sphinx-rtd-theme'],
#   ['chai',
#    'chai-as-promised',
#    'command-line-args',
#    'handlebars',
#    'istanbul',
#    'json-format',
#    'lodash',
#    'mkdirp',
#    'mocha',
#    'mock-fs',
#    'q',
#    'remap-istanbul',
#    'tv4',
#    'typescript',
#    'typings',
#    'xml2js'],
#   ['chardet',
#    'html5lib',
#    'iso8601',
#    'isodate',
#    'networkx',
#    'nltk',
#    'numpy',
#    'pdfdocument',
#    'pdfminer-six',
#    'python-magic',
#    'rdflib',
#    'requests',
#    'unidecode',
#    'bsh:bsh',
#    'jgrapht:jgrapht',
#    'junit:junit',
#    'jwnl:jwnl',
#    'mtj:mtj',
#    'org.jdom:jdom',
#    'trove:trove'],
#   ['numpy', 'pytest', 'scipy'],
#   ['ipython',
#    'openpyxl',
#    'pandas',
#    'pymysql',
#    'pyomo',
#    'pypyodbc',
#    'pyro4',
#    'pyyaml',
#    'sympy',
#    'tabulate',
#    'xlrd',
#    'oatspower'],
#   ['org.apache.felix:maven-bundle-plugin',
#    'org.apache.maven.plugins:maven-javadoc-plugin',
#    'systems.dmx:dmx-accesscontrol',
#    'systems.dmx:dmx-workspaces'],
#   ['jsmin',
#    'jsonschema',
#    'matplotlib',
#    'netcdf4',
#    'numpy',
#    'opencv-python',
#    'pillow',
#    'pyproj',
#    'scipy',
#    'cartopy',
#    'dask',
#    'h5py',
#    'pyfftw',
#    'pytest',
#    'python',
#    'numpydoc',
#    'sphinx',
#    'sphinx-gallery',
#    'sphinx-rtd-theme',
#    'sphinxcontrib-bibtex'],
#   ['cython', 'numpy', 'scipy', 'setuptools', 'vtk'],
#   ['coverage',
#    'flask',
#    'mock',
#    'pep8',
#    'pytest',
#    'pytest-cov',
#    'pytest-pep8',
#    'python-coveralls',
#    'requests',
#    'six',
#    'jinja2',
#    'numpydoc',
#    'sphinx',
#    'sphinx-rtd-theme',
#    'nltk',
#    'numpy',
#    'scikit-learn',
#    'scipy'],
#   ['@babel/preset-env',
#    '@vue/cli-plugin-babel',
#    '@vue/cli-plugin-eslint',
#    '@vue/cli-service',
#    '@vue/test-utils',
#    'axios',
#    'babel-core',
#    'babel-eslint',
#    'babel-jest',
#    'core-js',
#    'eslint',
#    'eslint-plugin-vue',
#    'jest',
#    'vue',
#    'vue-async-computed',
#    'vue-cli-plugin-axios',
#    'vue-cli-plugin-i18n',
#    'vue-cookie-law',
#    'vue-date-filters',
#    'vue-i18n',
#    'vue-jest',
#    'vue-js-modal',
#    'vue-router',
#    'vue-simple-markdown',
#    'vue-template-compiler',
#    'vuex',
#    'zotero-api-client',
#    '@babel/code-frame',
#    '@babel/core',
#    '@babel/generator',
#    '@babel/helper-annotate-as-pure',
#    '@babel/helper-builder-binary-assignment-operator-visitor',
#    '@babel/helper-call-delegate',
#    '@babel/helper-create-class-features-plugin',
#    '@babel/helper-define-map',
#    '@babel/helper-explode-assignable-expression',
#    '@babel/helper-function-name',
#    '@babel/helper-get-function-arity',
#    '@babel/helper-hoist-variables',
#    '@babel/helper-member-expression-to-functions',
#    '@babel/helper-module-imports',
#    '@babel/helper-module-transforms',
#    '@babel/helper-optimise-call-expression',
#    '@babel/helper-plugin-utils',
#    '@babel/helper-regex',
#    '@babel/helper-remap-async-to-generator',
#    '@babel/helper-replace-supers',
#    '@babel/helper-simple-access',
#    '@babel/helper-split-export-declaration',
#    '@babel/helper-wrap-function',
#    '@babel/helpers',
#    '@babel/highlight',
#    '@babel/parser',
#    '@babel/plugin-proposal-async-generator-functions',
#    '@babel/plugin-proposal-class-properties',
#    '@babel/plugin-proposal-decorators',
#    '@babel/plugin-proposal-dynamic-import',
#    '@babel/plugin-proposal-json-strings',
#    '@babel/plugin-proposal-object-rest-spread',
#    '@babel/plugin-proposal-optional-catch-binding',
#    '@babel/plugin-proposal-unicode-property-regex',
#    '@babel/plugin-syntax-async-generators',
#    '@babel/plugin-syntax-decorators',
#    '@babel/plugin-syntax-dynamic-import',
#    '@babel/plugin-syntax-json-strings',
#    '@babel/plugin-syntax-jsx',
#    '@babel/plugin-syntax-object-rest-spread',
#    '@babel/plugin-syntax-optional-catch-binding',
#    '@babel/plugin-transform-arrow-functions',
#    '@babel/plugin-transform-async-to-generator',
#    '@babel/plugin-transform-block-scoped-functions',
#    '@babel/plugin-transform-block-scoping',
#    '@babel/plugin-transform-classes',
#    '@babel/plugin-transform-computed-properties',
#    '@babel/plugin-transform-destructuring',
#    '@babel/plugin-transform-dotall-regex',
#    '@babel/plugin-transform-duplicate-keys',
#    '@babel/plugin-transform-exponentiation-operator',
#    '@babel/plugin-transform-for-of',
#    '@babel/plugin-transform-function-name',
#    '@babel/plugin-transform-literals',
#    '@babel/plugin-transform-member-expression-literals',
#    '@babel/plugin-transform-modules-amd',
#    '@babel/plugin-transform-modules-commonjs',
#    '@babel/plugin-transform-modules-systemjs',
#    '@babel/plugin-transform-modules-umd',
#    '@babel/plugin-transform-named-capturing-groups-regex',
#    '@babel/plugin-transform-new-target',
#    '@babel/plugin-transform-object-super',
#    '@babel/plugin-transform-parameters',
#    '@babel/plugin-transform-property-literals',
#    '@babel/plugin-transform-regenerator',
#    '@babel/plugin-transform-reserved-words',
#    '@babel/plugin-transform-runtime',
#    '@babel/plugin-transform-shorthand-properties',
#    '@babel/plugin-transform-spread',
#    '@babel/plugin-transform-sticky-regex',
#    '@babel/plugin-transform-template-literals',
#    '@babel/plugin-transform-typeof-symbol',
#    '@babel/plugin-transform-unicode-regex',
#    '@babel/runtime',
#    '@babel/runtime-corejs2',
#    '@babel/template',
#    '@babel/traverse',
#    '@babel/types',
#    '@cnakazawa/watch',
#    '@hapi/address',
#    '@hapi/bourne',
#    '@hapi/hoek',
#    '@hapi/joi',
#    '@hapi/topo',
#    '@intervolga/optimize-cssnano-plugin',
#    '@jest/console',
#    '@jest/core',
#    '@jest/environment',
#    '@jest/fake-timers',
#    '@jest/reporters',
#    '@jest/source-map',
#    '@jest/test-result',
#    '@jest/test-sequencer',
#    '@jest/transform',
#    '@jest/types',
#    '@mrmlnc/readdir-enhanced',
#    '@nodelib/fs.stat',
#    '@soda/friendly-errors-webpack-plugin',
#    '@types/babel__core',
#    '@types/babel__generator',
#    '@types/babel__template',
#    '@types/babel__traverse',
#    '@types/events',
#    '@types/glob',
#    '@types/istanbul-lib-coverage',
#    '@types/istanbul-lib-report',
#    '@types/istanbul-reports',
#    '@types/minimatch',
#    '@types/node',
#    '@types/normalize-package-data',
#    '@types/q',
#    '@types/stack-utils',
#    '@types/strip-bom',
#    '@types/strip-json-comments',
#    '@types/yargs',
#    '@types/yargs-parser',
#    '@vue/babel-helper-vue-jsx-merge-props',
#    '@vue/babel-plugin-transform-vue-jsx',
#    '@vue/babel-preset-app',
#    '@vue/babel-preset-jsx',
#    '@vue/babel-sugar-functional-vue',
#    '@vue/babel-sugar-inject-h',
#    '@vue/babel-sugar-v-model',
#    '@vue/babel-sugar-v-on',
#    '@vue/cli-overlay',
#    '@vue/cli-shared-utils',
#    '@vue/component-compiler-utils',
#    '@vue/preload-webpack-plugin',
#    '@vue/web-component-wrapper',
#    '@webassemblyjs/ast',
#    '@webassemblyjs/floating-point-hex-parser',
#    '@webassemblyjs/helper-api-error',
#    '@webassemblyjs/helper-buffer',
#    '@webassemblyjs/helper-code-frame',
#    '@webassemblyjs/helper-fsm',
#    '@webassemblyjs/helper-module-context',
#    '@webassemblyjs/helper-wasm-bytecode',
#    '@webassemblyjs/helper-wasm-section',
#    '@webassemblyjs/ieee754',
#    '@webassemblyjs/leb128',
#    '@webassemblyjs/utf8',
#    '@webassemblyjs/wasm-edit',
#    '@webassemblyjs/wasm-gen',
#    '@webassemblyjs/wasm-opt',
#    '@webassemblyjs/wasm-parser',
#    '@webassemblyjs/wast-parser',
#    '@webassemblyjs/wast-printer',
#    '@xtuc/ieee754',
#    '@xtuc/long',
#    'abab',
#    'abbrev',
#    'accepts',
#    'acorn',
#    'acorn-globals',
#    'acorn-jsx',
#    'acorn-walk',
#    'address',
#    'ajv',
#    'ajv-errors',
#    'ajv-keywords',
#    'alphanum-sort',
#    'ansi-colors',
#    'ansi-escapes',
#    'ansi-html',
#    'ansi-regex',
#    'ansi-styles',
#    'any-promise',
#    'anymatch',
#    'aproba',
#    'arch',
#    'are-we-there-yet',
#    'argparse',
#    'arr-diff',
#    'arr-flatten',
#    'arr-union',
#    'array-equal',
#    'array-flatten',
#    'array-union',
#    'array-uniq',
#    'array-unique',
#    'asn1',
#    'asn1.js',
#    'assert',
#    'assert-plus',
#    'assign-symbols',
#    'astral-regex',
#    'async',
#    'async-each',
#    'async-limiter',
#    'asynckit',
#    'atob',
#    'autoprefixer',
#    'aws-sign2',
#    'aws4',
#    'babel-code-frame',
#    'babel-generator',
#    'babel-helpers',
#    'babel-loader',
#    'babel-messages',
#    'babel-plugin-dynamic-import-node',
#    'babel-plugin-istanbul',
#    'babel-plugin-jest-hoist',
#    'babel-plugin-module-resolver',
#    'babel-plugin-transform-es2015-modules-commonjs',
#    'babel-plugin-transform-strict-mode',
#    'babel-preset-jest',
#    'babel-register',
#    'babel-runtime',
#    'babel-template',
#    'babel-traverse',
#    'babel-types',
#    'babylon',
#    'balanced-match',
#    'base',
#    'base64-js',
#    'batch',
#    'bcrypt-pbkdf',
#    'bfj',
#    'big.js',
#    'binary-extensions',
#    'bluebird',
#    'bn.js',
#    'body-parser',
#    'bonjour',
#    'boolbase',
#    'brace-expansion',
#    'braces',
#    'brorand',
#    'browser-process-hrtime',
#    'browser-resolve',
#    'browserify-aes',
#    'browserify-cipher',
#    'browserify-des',
#    'browserify-rsa',
#    'browserify-sign',
#    'browserify-zlib',
#    'browserslist',
#    'bser',
#    'buffer',
#    'buffer-from',
#    'buffer-indexof'],
#   ['angular-animate',
#    'connect-livereload',
#    'delayed-stream',
#    'eventemitter3',
#    'grunt',
#    'grunt-autoprefixer',
#    'grunt-bower-install',
#    'grunt-concurrent',
#    'grunt-connect-proxy',
#    'grunt-contrib-clean',
#    'grunt-contrib-compass',
#    'grunt-contrib-concat',
#    'grunt-contrib-connect',
#    'grunt-contrib-copy',
#    'grunt-contrib-cssmin',
#    'grunt-contrib-htmlmin',
#    'grunt-contrib-imagemin',
#    'grunt-contrib-jshint',
#    'grunt-contrib-uglify',
#    'grunt-contrib-watch',
#    'grunt-google-cdn',
#    'grunt-karma',
#    'grunt-newer',
#    'grunt-ngmin',
#    'grunt-rev',
#    'grunt-svgmin',
#    'grunt-usemin',
#    'jshint-stylish',
#    'karma',
#    'karma-chrome-launcher',
#    'karma-jasmine',
#    'karma-ng-html2js-preprocessor',
#    'karma-ng-scenario',
#    'karma-phantomjs-launcher',
#    'load-grunt-tasks',
#    'phantomjs',
#    'time-grunt'],
#   ['fairseq',
#    'fastbpe',
#    'sacremoses',
#    'torch',
#    'nltk',
#    'regex',
#    'scipy',
#    'pytest',
#    'pytest-cov',
#    'pandas',
#    'torchtext'],
#   ['allennlp', 'jsonlines', 'scikit-learn', 'fasttext'],
#   ['flask',
#    'librosa',
#    'matplotlib',
#    'python-levenshtein',
#    'torch',
#    'tqdm',
#    'visdom',
#    'wget'],
#   ['argparse', 'jsonschema', 'requests'],
#   ['com.opencsv:opencsv',
#    'de.biomedical-imaging.TraJ:traj',
#    'junit:junit',
#    'net.imagej:ij',
#    'org.apache.commons:commons-lang3',
#    'org.apache.commons:commons-math3',
#    'org.apache.maven.plugins:maven-compiler-plugin',
#    'org.apache.maven.plugins:maven-jar-plugin',
#    'org.apache.maven.plugins:maven-surefire-plugin',
#    'org.knowm.xchart:xchart',
#    'org.renjin.cran:plyr',
#    'org.renjin.cran:randomForest',
#    'org.renjin:renjin-script-engine'],
#   ['astropy', 'matplotlib', 'numpy', 'pytest', 'scipy', 'tqdm'],
#   ['braceexpand',
#    'click',
#    'colorama',
#    'dendropy',
#    'deprecation',
#    'networkx',
#    'numpy',
#    'pandas',
#    'psutil',
#    'pyfastx',
#    'pysam',
#    'pytest',
#    'python-dateutil',
#    'seaborn',
#    'tqdm',
#    'watchdog'],
#   ['anybadge',
#    'atari-py',
#    'box2d',
#    'box2d-kengz',
#    'certifi',
#    'chardet',
#    'coverage',
#    'future',
#    'gym',
#    'idna',
#    'm2r',
#    'matplotlib',
#    'mne',
#    'numba',
#    'numpy',
#    'pandas',
#    'parameterized',
#    'pillow',
#    'protobuf',
#    'pyglet',
#    'pyriemann',
#    'python-dateutil',
#    'pytz',
#    'recommonmark',
#    'requests',
#    'scikit-learn',
#    'scipy',
#    'six',
#    'sklearn',
#    'sphinx',
#    'sphinx-autodoc-typehints',
#    'sphinx-rtd-theme',
#    'sphinxcontrib-apidoc',
#    'tensorboardx',
#    'torch',
#    'torchvision',
#    'urllib3'],
#   ['keras',
#    'scikit-learn',
#    'tensorflow',
#    '@types/antd',
#    '@types/dagre',
#    '@types/enzyme-adapter-react-16',
#    '@types/jest',
#    '@types/node',
#    '@types/react',
#    '@types/react-dom',
#    '@types/react-redux',
#    'antd',
#    'dagre',
#    'enzyme',
#    'enzyme-adapter-react-16',
#    'react',
#    'react-dom',
#    'react-redux',
#    'react-scripts-ts',
#    'redux',
#    'express',
#    'pm2'],
#   ['cython',
#    'h5py',
#    'matplotlib',
#    'meautility',
#    'mpi4py',
#    'neuron',
#    'numpy',
#    'scipy',
#    'setuptools',
#    'numpydoc',
#    'sphinx'],
#   ['Newtonsoft.Json'],
#   ['gym', 'numpy'],
#   ['tensorflow',
#    'astropy',
#    'colorama',
#    'imageio',
#    'matplotlib',
#    'numpy',
#    'scikit-image',
#    'scipy',
#    'tqdm'],
#   ['cached-property',
#    'cachetools',
#    'ipython',
#    'matplotlib',
#    'pkgconfig',
#    'pylint',
#    'pytest',
#    'pytest-xdist',
#    'randomgen',
#    'requests',
#    'sympy',
#    'vtk'],
#   ['numpy'],
#   ['ase',
#    'biopython',
#    'coverage',
#    'coveralls',
#    'imageio',
#    'ipywidgets',
#    'matplotlib',
#    'mock',
#    'moviepy',
#    'nose',
#    'pandas',
#    'parmed',
#    'pillow',
#    'pymatgen',
#    'pytest',
#    'pytest-cov',
#    'pytraj',
#    'simpletraj',
#    'traitlets',
#    'numpy',
#    '@jupyter-widgets/base',
#    '@types/chai',
#    '@types/expect.js',
#    '@types/mocha',
#    '@types/node',
#    '@types/requirejs',
#    'babel-eslint',
#    'babel-register',
#    'css-loader',
#    'eslint',
#    'eslint-config-google',
#    'file-loader',
#    'jquery',
#    'jquery-ui',
#    'json-loader',
#    'lodash',
#    'ngl',
#    'rimraf',
#    'style-loader',
#    'typescript',
#    'underscore',
#    'webpack'],
#   ['readthedocs-sphinx-ext',
#    'sphinx',
#    'sphinx-rtd-theme',
#    'sphinxcontrib-programoutput',
#    'ipython',
#    'ipywidgets',
#    'coveralls',
#    'nose',
#    'ephyviewer',
#    'neo',
#    'numpy',
#    'packaging',
#    'pandas',
#    'pyqt5',
#    'pyyaml',
#    'quantities',
#    'requests',
#    'scipy',
#    'setuptools',
#    'tqdm'],
#   ['beautifulsoup4',
#    'bleach',
#    'bokeh',
#    'boto3',
#    'botocore',
#    'click',
#    'cloudpickle',
#    'conda',
#    'cycler',
#    'cython',
#    'dask',
#    'decorator',
#    'dill',
#    'distributed',
#    'docutils',
#    'entrypoints',
#    'enum34',
#    'fastcache',
#    'h5py',
#    'heapdict',
#    'html5lib',
#    'ipykernel',
#    'ipython',
#    'ipython-genutils',
#    'ipywidgets',
#    'jedi',
#    'jinja2',
#    'jmespath',
#    'jsonschema',
#    'jupyter-client',
#    'jupyter-core',
#    'jupyterhub',
#    'jupyterlab',
#    'llvmlite',
#    'locket',
#    'markdown',
#    'markupsafe',
#    'matplotlib',
#    'mistune',
#    'mpmath',
#    'msgpack-python',
#    'nbconvert',
#    'nbformat',
#    'networkx',
#    'notebook',
#    'numba',
#    'numexpr',
#    'numpy',
#    'olefile',
#    'pamela',
#    'pandas',
#    'pandocfilters',
#    'partd',
#    'patsy',
#    'pexpect',
#    'pickleshare',
#    'pillow',
#    'prompt-toolkit',
#    'protobuf',
#    'psutil',
#    'ptyprocess',
#    'pycosat',
#    'pycrypto',
#    'pygments',
#    'pyparsing',
#    'python-dateutil',
#    'pytorch-pretrained-bert',
#    'pytz',
#    'pyyaml',
#    'pyzmq',
#    'regex',
#    'requests',
#    'rpy2',
#    's3fs',
#    's3transfer',
#    'scikit-image',
#    'scikit-learn',
#    'scipy',
#    'seaborn',
#    'simplegeneric',
#    'six',
#    'sortedcontainers',
#    'sqlalchemy',
#    'statsmodels',
#    'sympy',
#    'tblib',
#    'tensorflow',
#    'tensorflow-tensorboard',
#    'terminado',
#    'testpath',
#    'timeout-decorator',
#    'toolz',
#    'torch',
#    'tornado',
#    'tqdm',
#    'traitlets',
#    'vincent',
#    'wcwidth',
#    'webencodings',
#    'werkzeug',
#    'widgetsnbextension',
#    'xlrd',
#    'zict'],
#   ['matplotlib',
#    'netcdf4',
#    'numpy',
#    'pandas',
#    'pytest',
#    'scipy',
#    'seaborn',
#    'pyproj',
#    'pyshp'],
#   ['ipython',
#    'pre-commit',
#    'releases',
#    'sphinx',
#    'future',
#    'pytest',
#    'pytest-capturelog',
#    'pytest-cov',
#    'pytest-mock',
#    'pytest-pep8',
#    'gridmap',
#    'jug'],
#   ['colorama',
#    'emd-signal',
#    'matplotlib',
#    'multiprocess',
#    'nibabel',
#    'numba',
#    'numpy',
#    'pandas',
#    'progressbar33',
#    'pyod',
#    'pytest',
#    'scikit-learn',
#    'scipy',
#    'seaborn',
#    'statsmodels',
#    'typing-extensions'],
#   ['black',
#    'isort',
#    'pylint',
#    'readme-renderer',
#    'setuptools',
#    'sphinx',
#    'twine',
#    'watchdog',
#    'wheel',
#    'decorator',
#    'joblib',
#    'numpy',
#    'psutil',
#    'pyemd',
#    'pymongo',
#    'pyyaml',
#    'redis',
#    'scipy',
#    'tblib',
#    'toolz',
#    'tqdm',
#    'asv',
#    'coverage',
#    'pytest',
#    'pytest-lazy-fixture',
#    'virtualenv'],
#   ['3d-view',
#    '7zip-bin',
#    '@babel/code-frame',
#    '@babel/core',
#    '@babel/generator',
#    '@babel/helper-annotate-as-pure',
#    '@babel/helper-builder-binary-assignment-operator-visitor',
#    '@babel/helper-builder-react-jsx',
#    '@babel/helper-call-delegate',
#    '@babel/helper-create-class-features-plugin',
#    '@babel/helper-define-map',
#    '@babel/helper-explode-assignable-expression',
#    '@babel/helper-function-name',
#    '@babel/helper-get-function-arity',
#    '@babel/helper-hoist-variables',
#    '@babel/helper-member-expression-to-functions',
#    '@babel/helper-module-imports',
#    '@babel/helper-module-transforms',
#    '@babel/helper-optimise-call-expression',
#    '@babel/helper-plugin-utils',
#    '@babel/helper-regex',
#    '@babel/helper-remap-async-to-generator',
#    '@babel/helper-replace-supers',
#    '@babel/helper-simple-access',
#    '@babel/helper-split-export-declaration',
#    '@babel/helper-wrap-function',
#    '@babel/helpers',
#    '@babel/highlight',
#    '@babel/parser',
#    '@babel/plugin-proposal-async-generator-functions',
#    '@babel/plugin-proposal-class-properties',
#    '@babel/plugin-proposal-dynamic-import',
#    '@babel/plugin-proposal-export-default-from',
#    '@babel/plugin-proposal-json-strings',
#    '@babel/plugin-proposal-object-rest-spread',
#    '@babel/plugin-proposal-optional-catch-binding',
#    '@babel/plugin-proposal-unicode-property-regex',
#    '@babel/plugin-syntax-async-generators',
#    '@babel/plugin-syntax-dynamic-import',
#    '@babel/plugin-syntax-export-default-from',
#    '@babel/plugin-syntax-json-strings',
#    '@babel/plugin-syntax-jsx',
#    '@babel/plugin-syntax-object-rest-spread',
#    '@babel/plugin-syntax-optional-catch-binding',
#    '@babel/plugin-transform-arrow-functions',
#    '@babel/plugin-transform-async-to-generator',
#    '@babel/plugin-transform-block-scoped-functions',
#    '@babel/plugin-transform-block-scoping',
#    '@babel/plugin-transform-classes',
#    '@babel/plugin-transform-computed-properties',
#    '@babel/plugin-transform-destructuring',
#    '@babel/plugin-transform-dotall-regex',
#    '@babel/plugin-transform-duplicate-keys',
#    '@babel/plugin-transform-exponentiation-operator',
#    '@babel/plugin-transform-for-of',
#    '@babel/plugin-transform-function-name',
#    '@babel/plugin-transform-literals',
#    '@babel/plugin-transform-member-expression-literals',
#    '@babel/plugin-transform-modules-amd',
#    '@babel/plugin-transform-modules-commonjs',
#    '@babel/plugin-transform-modules-systemjs',
#    '@babel/plugin-transform-modules-umd',
#    '@babel/plugin-transform-named-capturing-groups-regex',
#    '@babel/plugin-transform-new-target',
#    '@babel/plugin-transform-object-super',
#    '@babel/plugin-transform-parameters',
#    '@babel/plugin-transform-property-literals',
#    '@babel/plugin-transform-react-constant-elements',
#    '@babel/plugin-transform-react-display-name',
#    '@babel/plugin-transform-react-inline-elements',
#    '@babel/plugin-transform-react-jsx',
#    '@babel/plugin-transform-react-jsx-self',
#    '@babel/plugin-transform-react-jsx-source',
#    '@babel/plugin-transform-regenerator',
#    '@babel/plugin-transform-reserved-words',
#    '@babel/plugin-transform-runtime',
#    '@babel/plugin-transform-shorthand-properties',
#    '@babel/plugin-transform-spread',
#    '@babel/plugin-transform-sticky-regex',
#    '@babel/plugin-transform-template-literals',
#    '@babel/plugin-transform-typeof-symbol',
#    '@babel/plugin-transform-unicode-regex',
#    '@babel/preset-env',
#    '@babel/preset-react',
#    '@babel/register',
#    '@babel/runtime',
#    '@babel/template',
#    '@babel/traverse',
#    '@babel/types',
#    '@choojs/findup',
#    '@cnakazawa/watch',
#    '@develar/schema-utils',
#    '@emotion/cache',
#    '@emotion/core',
#    '@emotion/css',
#    '@emotion/hash',
#    '@emotion/memoize',
#    '@emotion/serialize',
#    '@emotion/sheet',
#    '@emotion/stylis',
#    '@emotion/unitless',
#    '@emotion/utils',
#    '@emotion/weak-memoize',
#    '@icons/material',
#    '@iktakahiro/markdown-it-katex',
#    '@jest/console',
#    '@jest/core',
#    '@jest/environment',
#    '@jest/fake-timers',
#    '@jest/reporters',
#    '@jest/source-map',
#    '@jest/test-result',
#    '@jest/test-sequencer',
#    '@jest/transform',
#    '@jest/types',
#    '@mapbox/geojson-area',
#    '@mapbox/geojson-rewind',
#    '@mapbox/geojson-types',
#    '@mapbox/jsonlint-lines-primitives',
#    '@mapbox/mapbox-gl-supported',
#    '@mapbox/point-geometry',
#    '@mapbox/tiny-sdf',
#    '@mapbox/unitbezier',
#    '@mapbox/vector-tile',
#    '@mapbox/whoots-js',
#    '@mrmlnc/readdir-enhanced',
#    '@nodelib/fs.stat',
#    '@plotly/d3-sankey',
#    '@plotly/d3-sankey-circular',
#    '@react-bootstrap/react-popper',
#    '@restart/context',
#    '@restart/hooks',
#    '@sindresorhus/is',
#    '@stdlib/stdlib',
#    '@szmarczak/http-timer',
#    '@turf/area',
#    '@turf/centroid',
#    '@turf/helpers',
#    '@turf/meta',
#    '@types/anymatch',
#    '@types/asap',
#    '@types/babel__core',
#    '@types/babel__generator',
#    '@types/babel__template',
#    '@types/babel__traverse',
#    '@types/debug',
#    '@types/events',
#    '@types/glob',
#    '@types/hoist-non-react-statics',
#    '@types/invariant',
#    '@types/istanbul-lib-coverage',
#    '@types/istanbul-lib-report',
#    '@types/istanbul-reports',
#    '@types/json-schema',
#    '@types/minimatch',
#    '@types/node',
#    '@types/prop-types',
#    '@types/q',
#    '@types/react',
#    '@types/semver',
#    '@types/shallowequal',
#    '@types/source-list-map',
#    '@types/stack-utils',
#    '@types/tapable',
#    '@types/uglify-js',
#    '@types/unist',
#    '@types/vfile',
#    '@types/vfile-message',
#    '@types/webpack',
#    '@types/webpack-sources',
#    '@types/yargs',
#    '@types/yargs-parser',
#    '@typescript-eslint/experimental-utils',
#    '@typescript-eslint/typescript-estree',
#    '@webassemblyjs/ast',
#    '@webassemblyjs/floating-point-hex-parser',
#    '@webassemblyjs/helper-api-error',
#    '@webassemblyjs/helper-buffer',
#    '@webassemblyjs/helper-code-frame',
#    '@webassemblyjs/helper-fsm',
#    '@webassemblyjs/helper-module-context',
#    '@webassemblyjs/helper-wasm-bytecode',
#    '@webassemblyjs/helper-wasm-section',
#    '@webassemblyjs/ieee754',
#    '@webassemblyjs/leb128',
#    '@webassemblyjs/utf8',
#    '@webassemblyjs/wasm-edit',
#    '@webassemblyjs/wasm-gen',
#    '@webassemblyjs/wasm-opt',
#    '@webassemblyjs/wasm-parser',
#    '@webassemblyjs/wast-parser',
#    '@webassemblyjs/wast-printer',
#    '@xtuc/ieee754',
#    '@xtuc/long',
#    'a-big-triangle',
#    'abab',
#    'abbrev',
#    'abs-svg-path',
#    'accepts',
#    'acorn',
#    'acorn-dynamic-import',
#    'acorn-globals',
#    'acorn-jsx',
#    'acorn-loose',
#    'acorn-node',
#    'acorn-walk',
#    'add-line-numbers',
#    'affine-hull',
#    'after',
#    'agent-base',
#    'airbnb-prop-types',
#    'ajv',
#    'ajv-errors',
#    'ajv-keywords',
#    'align-text',
#    'almost-equal',
#    'alpha-complex',
#    'alpha-shape',
#    'alphanum-sort',
#    'amdefine',
#    'anser',
#    'ansi-align',
#    'ansi-colors',
#    'ansi-escapes',
#    'ansi-html',
#    'ansi-regex',
#    'ansi-styles',
#    'ansi-to-react',
#    'ansicolors',
#    'anymatch',
#    'app-builder-bin',
#    'app-builder-lib',
#    'aproba',
#    'archiver',
#    'archiver-utils',
#    'are-we-there-yet',
#    'argparse',
#    'argv',
#    'aria-query',
#    'arr-diff',
#    'arr-flatten',
#    'arr-union',
#    'array-bounds',
#    'array-equal',
#    'array-filter',
#    'array-find-index',
#    'array-flatten',
#    'array-from',
#    'array-includes',
#    'array-normalize',
#    '@pmmmwh/react-refresh-webpack-plugin',
#    'autobind-decorator',
#    'axios',
#    'babel-eslint',
#    'babel-jest',
#    'babel-loader',
#    'babel-plugin-module-resolver',
#    'babel-plugin-transform-modern-regexp',
#    'babel-plugin-transform-react-remove-prop-types',
#    'codecov',
#    'codemirror',
#    'compute-argmax',
#    'compute-chebyshev-distance',
#    'compute-chunkify',
#    'compute-cosine-distance',
#    'compute-euclidean-distance',
#    'compute-hamming',
#    'compute-manhattan-distance',
#    'concurrently',
#    'core-js',
#    'cross-env',
#    'css',
#    'css-loader',
#    'css-modules-require-hook',
#    'csv-parse',
#    'csv-stringify',
#    'd3',
#    'd3-cloud',
#    'debug',
#    'deep-object-diff',
#    'detect-csv',
#    'doctrine',
#    'dompurify',
#    'electron',
#    'electron-builder',
#    'electron-devtools-installer',
#    'electron-prompt',
#    'electron-store',
#    'electron-updater',
#    'electron-window-state',
#    'element-resize-event',
#    'enzyme',
#    'enzyme-adapter-react-16',
#    'eslint',
#    'eslint-plugin-enforce-ids-in-jsx',
#    'eslint-plugin-import',
#    'eslint-plugin-jest',
#    'eslint-plugin-jsx-a11y',
#    'eslint-plugin-react',
#    'eslint-plugin-react-hooks',
#    'eslint-plugin-spellcheck',
#    'file-loader',
#    'form-data',
#    'gh-pages',
#    'happypack',
#    'hard-source-webpack-plugin',
#    'history',
#    'html-to-image',
#    'html-to-pdfmake',
#    'html-webpack-plugin',
#    'i18next',
#    'i18next-browser-languagedetector',
#    'ieee754',
#    'is-extendable',
#    'is-touch-device',
#    'jest',
#    'jest-cli',
#    'js-yaml',
#    'katex',
#    'localforage',
#    'lodash.debounce',
#    'markdown-it',
#    'mini-css-extract-plugin',
#    'minimist',
#    'ml-kmeans',
#    'ml-matrix',
#    'ml-pca',
#    'ml-regression-multivariate-linear',
#    'moment',
#    'monaco-editor',
#    'monaco-editor-webpack-plugin',
#    'murmurhash3js',
#    'node',
#    'node-libs-browser',
#    'node-pty',
#    'npm',
#    'null-loader',
#    'optimize-css-assets-webpack-plugin',
#    'pdfjs-dist',
#    'pdfmake',
#    'plotly.js',
#    'preload-webpack-plugin',
#    'pressure',
#    'profanities',
#    'prop-types',
#    'prosemirror-collab',
#    'prosemirror-commands',
#    'prosemirror-dropcursor',
#    'prosemirror-gapcursor',
#    'prosemirror-history',
#    'prosemirror-inputrules',
#    'prosemirror-markdown',
#    'prosemirror-schema-list',
#    'prosemirror-state',
#    'prosemirror-tables',
#    'prosemirror-utils',
#    'prosemirror-view',
#    'qrcode',
#    'raf',
#    'raw-loader',
#    'react',
#    'react-bootstrap',
#    'react-color',
#    'react-contextmenu',
#    'react-copy-to-clipboard',
#    'react-dates',
#    'react-dnd',
#    'react-dnd-html5-backend',
#    'react-dnd-touch-backend',
#    'react-dom',
#    'react-draggable',
#    'react-floater',
#    'react-grid-layout',
#    'react-highlight-words',
#    'react-i18next',
#    'react-innertext',
#    'react-input-range',
#    'react-joyride',
#    'react-json-tree',
#    'react-json-view',
#    'react-list',
#    'react-live',
#    'react-monaco-editor',
#    'react-notification-system',
#    'react-player',
#    'react-plotly.js',
#    'react-portal',
#    'react-redux',
#    'react-refresh',
#    'react-rnd',
#    'react-router',
#    'react-router-dom',
#    'react-select',
#    'react-slick',
#    'react-sortable-tree',
#    'react-split-pane',
#    'react-table',
#    'react-test-renderer',
#    'react-transition-group',
#    'react-viewer',
#    'react-virtualized',
#    'recordrtc',
#    'redux',
#    'redux-devtools',
#    'redux-devtools-dock-monitor',
#    'redux-devtools-log-monitor',
#    'redux-logger',
#    'redux-thunk',
#    'resolve-from',
#    'smooth-scroll-into-view-if-needed',
#    'socket.io-client',
#    'source-map-explorer',
#    'source-map-support',
#    'speed-measure-webpack-plugin',
#    'stemmer',
#    'style-loader',
#    'stylelint',
#    'stylelint-config-standard',
#    'svg-react-loader',
#    'terser-webpack-plugin',
#    'text-miner',
#    'typo-js',
#    'unicode-match-property-value-ecmascript',
#    'uniq',
#    'v8-compile-cache',
#    'venn.js',
#    'vex-js',
#    'victory',
#    'webpack',
#    'webpack-cli',
#    'webpack-dev-server',
#    'webpack-manifest-plugin',
#    'whatwg-fetch',
#    'workbox-webpack-plugin',
#    'worker-loader',
#    'xterm',
#    'xterm-addon-fit',
#    'xterm-addon-search',
#    'xterm-addon-web-links',
#    '@babel/helper-create-regexp-features-plugin',
#    '@babel/plugin-syntax-top-level-await',
#    '@babel/polyfill',
#    '@types/cheerio',
#    '@types/color-name',
#    'address',
#    'ansi-red',
#    'ansi-wrap',
#    'arch',
#    'archive-type',
#    'array-union',
#    'array-uniq',
#    'array-unique',
#    'arrify',
#    'asn1',
#    'assert-plus',
#    'assign-symbols',
#    'async',
#    'async-each',
#    'asynckit',
#    'atob',
#    'autolinker',
#    'autoprefixer',
#    'aws-sign2',
#    'aws4',
#    'babel-code-frame',
#    'babel-plugin-dynamic-import-node',
#    'babylon',
#    'balanced-match',
#    'base',
#    'base64-js',
#    'bcrypt-pbkdf',
#    'big.js',
#    'bin-build',
#    'bin-check',
#    'bin-version',
#    'bin-version-check',
#    'bin-wrapper',
#    'binary-extensions',
#    'bl',
#    'body',
#    'body-parser',
#    'boolbase',
#    'brace-expansion',
#    'braces',
#    'browserslist',
#    'buffer',
#    'buffer-alloc',
#    'buffer-alloc-unsafe',
#    'buffer-crc32',
#    'buffer-fill',
#    'buffer-from',
#    'bytes',
#    'cache-base',
#    'cacheable-request',
#    'call-me-maybe',
#    'caller-callsite',
#    'caller-path',
#    'callsites',
#    'camelcase',
#    'camelcase-keys',
#    'caniuse-api',
#    'caniuse-lite',
#    'caseless',
#    'caw',
#    'chalk',
#    'chardet',
#    'cheerio',
#    'chokidar',
#    'class-utils',
#    'classnames',
#    'cli-cursor',
#    'cli-width',
#    'clipboard',
#    'clone-response',
#    'coa',
#    'coffee-script',
#    'collection-visit',
#    'color',
#    'color-convert',
#    'color-name',
#    'color-string',
#    'combined-stream',
#    'commander',
#    'commondir',
#    'component-emitter',
#    'concat-map',
#    'concat-stream',
#    'concat-with-sourcemaps',
#    'config-chain',
#    'console-stream',
#    'content-disposition',
#    'content-type',
#    'continuable-cache',
#    'convert-source-map',
#    'cookie',
#    'cookie-signature',
#    'copy-descriptor',
#    'core-js-compat',
#    'core-util-is',
#    'cosmiconfig',
#    'cross-spawn',
#    'crowdin-cli',
#    'css-color-names',
#    'css-declaration-sorter',
#    'css-select',
#    'css-select-base-adapter',
#    'css-tree',
#    'css-unit-converter',
#    'css-what',
#    'cssesc',
#    'cssnano',
#    'cssnano-preset-default',
#    'cssnano-util-get-arguments',
#    'cssnano-util-get-match',
#    'cssnano-util-raw-cache',
#    'cssnano-util-same-parent',
#    'csso',
#    'currently-unhandled',
#    'dashdash',
#    'decamelize',
#    'decode-uri-component',
#    'decompress',
#    'decompress-response',
#    'decompress-tar',
#    'decompress-tarbz2',
#    'decompress-targz',
#    'decompress-unzip',
#    'deep-is',
#    'define-properties',
#    'define-property',
#    'delayed-stream',
#    'delegate',
#    'depd',
#    'destroy',
#    'detect-port-alt',
#    'diacritics-map',
#    'dir-glob',
#    'docusaurus',
#    'dom-serializer',
#    'domelementtype',
#    'domhandler',
#    'domutils',
#    'dot-prop',
#    'download',
#    'duplexer',
#    'duplexer3',
#    'ecc-jsbn',
#    'ee-first',
#    '@docusaurus/core',
#    '@docusaurus/preset-classic',
#    '@docusaurus/theme-live-codeblock'],
#   ['@babel/code-frame',
#    '@babel/core',
#    '@babel/generator',
#    '@babel/helper-annotate-as-pure',
#    '@babel/helper-builder-binary-assignment-operator-visitor',
#    '@babel/helper-call-delegate',
#    '@babel/helper-define-map',
#    '@babel/helper-explode-assignable-expression',
#    '@babel/helper-function-name',
#    '@babel/helper-get-function-arity',
#    '@babel/helper-hoist-variables',
#    '@babel/helper-member-expression-to-functions',
#    '@babel/helper-module-imports',
#    '@babel/helper-module-transforms',
#    '@babel/helper-optimise-call-expression',
#    '@babel/helper-plugin-utils',
#    '@babel/helper-regex',
#    '@babel/helper-remap-async-to-generator',
#    '@babel/helper-replace-supers',
#    '@babel/helper-simple-access',
#    '@babel/helper-split-export-declaration',
#    '@babel/helper-validator-identifier',
#    '@babel/helper-wrap-function',
#    '@babel/helpers',
#    '@babel/highlight',
#    '@babel/parser',
#    '@babel/plugin-proposal-async-generator-functions',
#    '@babel/plugin-proposal-dynamic-import',
#    '@babel/plugin-proposal-json-strings',
#    '@babel/plugin-proposal-object-rest-spread',
#    '@babel/plugin-proposal-optional-catch-binding',
#    '@babel/plugin-proposal-unicode-property-regex',
#    '@babel/plugin-syntax-async-generators',
#    '@babel/plugin-syntax-dynamic-import',
#    '@babel/plugin-syntax-json-strings',
#    '@babel/plugin-syntax-object-rest-spread',
#    '@babel/plugin-syntax-optional-catch-binding',
#    '@babel/plugin-transform-arrow-functions',
#    '@babel/plugin-transform-async-to-generator',
#    '@babel/plugin-transform-block-scoped-functions',
#    '@babel/plugin-transform-block-scoping',
#    '@babel/plugin-transform-classes',
#    '@babel/plugin-transform-computed-properties',
#    '@babel/plugin-transform-destructuring',
#    '@babel/plugin-transform-dotall-regex',
#    '@babel/plugin-transform-duplicate-keys',
#    '@babel/plugin-transform-exponentiation-operator',
#    '@babel/plugin-transform-for-of',
#    '@babel/plugin-transform-function-name',
#    '@babel/plugin-transform-literals',
#    '@babel/plugin-transform-member-expression-literals',
#    '@babel/plugin-transform-modules-amd',
#    '@babel/plugin-transform-modules-commonjs',
#    '@babel/plugin-transform-modules-systemjs',
#    '@babel/plugin-transform-modules-umd',
#    '@babel/plugin-transform-named-capturing-groups-regex',
#    '@babel/plugin-transform-new-target',
#    '@babel/plugin-transform-object-super',
#    '@babel/plugin-transform-parameters',
#    '@babel/plugin-transform-property-literals',
#    '@babel/plugin-transform-regenerator',
#    '@babel/plugin-transform-reserved-words',
#    '@babel/plugin-transform-shorthand-properties',
#    '@babel/plugin-transform-spread',
#    '@babel/plugin-transform-sticky-regex',
# ...
#    '@babel/plugin-syntax-typescript',
#    '@babel/plugin-transform-arrow-functions',
#    '@babel/plugin-transform-async-to-generator',
#    '@babel/plugin-transform-block-scoped-functions',
#    '@babel/plugin-transform-block-scoping',
#    '@babel/plugin-transform-classes',
#    '@babel/plugin-transform-computed-properties',
#    '@babel/plugin-transform-destructuring',
#    '@babel/plugin-transform-dotall-regex',
#    '@babel/plugin-transform-duplicate-keys',
#    '@babel/plugin-transform-exponentiation-operator',
#    '@babel/plugin-transform-for-of',
#    '@babel/plugin-transform-function-name',
#    '@babel/plugin-transform-literals',
#    '@babel/plugin-transform-member-expression-literals',
#    '@babel/plugin-transform-modules-amd',
#    '@babel/plugin-transform-modules-commonjs',
#    '@babel/plugin-transform-modules-systemjs',
#    '@babel/plugin-transform-modules-umd',
#    '@babel/plugin-transform-named-capturing-groups-regex',
#    '@babel/plugin-transform-new-target',
#    '@babel/plugin-transform-object-super',
#    '@babel/plugin-transform-parameters',
#    '@babel/plugin-transform-property-literals',
#    '@babel/plugin-transform-regenerator',
#    '@babel/plugin-transform-reserved-words',
#    '@babel/plugin-transform-shorthand-properties',
#    '@babel/plugin-transform-spread',
#    '@babel/plugin-transform-sticky-regex',
#    '@babel/plugin-transform-template-literals',
#    '@babel/plugin-transform-typeof-symbol',
#    '@babel/plugin-transform-typescript',
#    '@babel/plugin-transform-unicode-regex',
#    '@babel/preset-env',
#    '@babel/preset-modules',
#    '@babel/preset-typescript',
#    '@babel/runtime',
#    '@babel/template',
#    '@babel/traverse',
#    '@babel/types',
#    '@pika/babel-plugin-esm-import-rewrite',
#    '@samverschueren/stream-to-observable',
#    '@sindresorhus/is',
#    '@szmarczak/http-timer',
#    '@types/color-name',
#    '@types/estree',
#    '@types/events',
#    '@types/glob',
#    '@types/minimatch',
#    '@types/minimist',
#    '@types/node',
#    '@types/normalize-package-data',
#    'acorn',
#    'acorn-jsx',
#    'ajv',
#    'ansi-align',
#    'ansi-escapes',
#    'ansi-regex',
#    'ansi-styles',
#    'any-observable',
#    'argparse',
#    'array-find-index',
#    'array-includes',
#    'array-union',
#    'array-uniq',
#    'arrify',
#    'astral-regex',
#    'async-exit-hook',
#    'babel-plugin-dynamic-import-node',
#    'babel-plugin-dynamic-import-node-babel-7',
#    'balanced-match',
#    'bluebird',
#    'boxen',
#    'brace-expansion',
#    'browserslist',
#    'builtin-modules',
#    'builtins',
#    'cacheable-request',
#    'caller-callsite',
#    'caller-path',
#    'callsites',
#    'camelcase',
#    'camelcase-keys',
#    'caniuse-lite',
#    'catharsis',
#    'chalk',
#    'chardet',
#    'ci-info',
#    'cli-boxes',
#    'cli-cursor',
#    'cli-truncate',
#    'cli-width',
#    'clone-response',
#    'code-point-at',
#    'color-convert',
#    'color-name',
#    'commander',
#    'concat-map',
#    'configstore',
#    'contains-path',
#    'convert-source-map',
#    'core-js-compat',
#    'cosmiconfig',
#    'cross-spawn',
#    'crypto-random-string',
#    'currently-unhandled',
#    'date-fns',
#    'debug',
#    'debug-log',
#    'decamelize',
#    'decamelize-keys',
#    'decompress-response',
#    'deep-extend',
#    'deep-is',
#    'defer-to-connect',
#    'define-properties',
#    'deglob',
#    'del',
#    'detect-indent',
#    'doctrine',
#    'dom-serializer',
#    'domelementtype',
#    'domhandler',
#    'domutils',
#    'dot-prop',
#    'duplexer3',
#    'electron-to-chromium',
#    'elegant-spinner',
#    'emoji-regex',
#    'end-of-stream',
#    'entities',
#    'error-ex',
#    'es-abstract',
#    'es-to-primitive',
#    'escape-string-regexp',
#    'eslint',
#    'eslint-config-standard',
#    'eslint-config-standard-jsx',
#    'eslint-import-resolver-node',
#    'eslint-module-utils',
#    'eslint-plugin-es',
#    'eslint-plugin-import',
#    'eslint-plugin-node',
#    'eslint-plugin-promise',
#    'eslint-plugin-react',
#    'eslint-plugin-standard',
#    'eslint-scope',
#    'eslint-utils',
#    'eslint-visitor-keys',
#    'espree',
#    'esprima',
#    'esquery',
#    'esrecurse',
#    'estraverse',
#    'estree-walker',
#    'esutils',
#    'execa',
#    'external-editor',
#    'fast-deep-equal',
#    'fast-json-stable-stringify',
#    'fast-levenshtein',
#    'figures',
#    'file-entry-cache',
#    'file-uri-to-path',
#    'find-root',
#    'find-up',
#    'flat-cache',
#    'flatted',
#    'fs.realpath',
#    'function-bind',
#    'functional-red-black-tree',
#    'gensync',
#    'get-stdin',
#    'get-stream',
#    'github-url-from-git',
#    'glob',
#    'glob-parent',
#    'global-dirs',
#    'globals',
#    'globby',
#    'got',
#    'graceful-fs',
#    'has',
#    'has-ansi',
#    'has-flag',
#    'has-symbols',
#    'has-yarn',
#    'hosted-git-info',
#    'htmlparser2',
#    'http-cache-semantics',
#    'human-signals',
#    'iconv-lite',
#    'ignore',
#    'import-fresh',
#    'import-from'],
#   ['de.congrace:exp4j',
#    'junit:junit',
#    'org.apache.maven.plugins:maven-compiler-plugin',
#    'org.apache.maven.plugins:maven-surefire-plugin'],
#   ['sphinx',
#    'sphinxcontrib-applehelp',
#    'sphinxcontrib-devhelp',
#    'sphinxcontrib-htmlhelp',
#    'sphinxcontrib-jsmath',
#    'sphinxcontrib-qthelp',
#    'sphinxcontrib-serializinghtml'],
#   ['numpy', 'setuptools'],
#   ['codecov',
#    'matplotlib',
#    'numpy',
#    'numpydoc',
#    'pandas',
#    'pillow',
#    'pytest',
#    'pytest-cov',
#    'scipy',
#    'sphinx',
#    'sphinx-gallery',
#    'sphinx-rtd-theme',
#    'statsmodels'],
#   ['joblib',
#    'lightgbm',
#    'nltk',
#    'numpy',
#    'pandas',
#    'scikit-learn',
#    'scikit-multilearn',
#    'scipy',
#    'spacy'],
#   ['cython', 'numpy'],
#   ['numpy', 'quantities', 'scipy', 'sciunit'],
#   ['colorlover',
#    'hydro-python-api',
#    'lmoments3',
#    'pandas',
#    'plotly',
#    'pytz',
#    'pyzmq',
#    'scipy',
#    'six',
#    'statsmodels'],
#   ['de.jutzig:github-release-plugin',
#    'org.apache.maven.plugins:maven-antrun-plugin',
#    'org.apache.maven.plugins:maven-release-plugin',
#    'org.apache.maven.scm:maven-scm-provider-gitexe',
#    'org.codehaus.mojo:build-helper-maven-plugin',
#    'org.codehaus.mojo:rpm-maven-plugin'],
#   ['glasspy',
#    'matplotlib',
#    'mendeleev',
#    'python-ternary',
#    'pytorch-lightning',
#    'sklearn',
#    'torch'],
#   ['bokeh',
#    'cdflib',
#    'matplotlib',
#    'numpy',
#    'pandas',
#    'pyqt5',
#    'pyqtgraph',
#    'pyqtwebengine',
#    'scipy',
#    'xarray'],
#   ['absl-py',
#    'astor',
#    'backcall',
#    'biopython',
#    'certifi',
#    'chardet',
#    'colorama',
#    'cycler',
#    'decorator',
#    'defusedxml',
#    'docopt',
#    'entrypoints',
#    'gast',
#    'griddataformats',
#    'grpcio',
#    'h5py',
#    'idna',
#    'ipykernel',
#    'ipython',
#    'ipython-genutils',
#    'ipywidgets',
#    'jedi',
#    'jinja2',
#    'joblib',
#    'jsonschema',
#    'jupyter',
#    'jupyter-client',
#    'jupyter-console',
#    'jupyter-core',
#    'jupyterlab',
#    'jupyterlab-server',
#    'keras',
#    'keras-applications',
#    'keras-preprocessing',
#    'keras-resnet',
#    'kiwisolver',
#    'markdown',
#    'markupsafe',
#    'matplotlib',
#    'mdanalysis',
#    'mistune',
#    'mmtf-python',
#    'mock',
#    'msgpack',
#    'nbconvert',
#    'nbformat',
#    'networkx',
#    'notebook',
#    'numpy',
#    'pandas',
#    'pandocfilters',
#    'parso',
#    'pbr',
#    'pickleshare',
#    'pillow',
#    'pipreqs',
#    'prometheus-client',
#    'prompt-toolkit',
#    'protobuf',
#    'pyautogui',
#    'pygments',
#    'pymsgbox',
#    'pyparsing',
#    'pyperclip',
#    'pyscreeze',
#    'python-dateutil',
#    'pytweening',
#    'pytz',
#    'pywinpty',
#    'pyyaml',
#    'pyzmq',
#    'qtconsole',
#    'requests',
#    'rosetta',
#    'scikit-learn',
#    'scipy',
#    'send2trash',
#    'singledispatch',
#    'six',
#    'sklearn',
#    'tensorboard',
#    'tensorflow-gpu',
#    'termcolor',
#    'terminado',
#    'testpath',
#    'torch',
#    'tornado',
#    'traitlets',
#    'urllib3',
#    'wcwidth',
#    'webencodings',
#    'werkzeug',
#    'widgetsnbextension',
#    'yarg'],
#   ['numpy', 'pandas'],
#   ['param', 'pyct'],
#   ['coverage',
#    'numpy',
#    'obspy',
#    'pandas',
#    'scipy',
#    'shapely',
#    'termcolor',
#    'sigpropy',
#    'sphinx',
#    'sphinx-rtd-theme'],
#   ['chai',
#    'grunt',
#    'grunt-contrib-clean',
#    'grunt-contrib-connect',
#    'grunt-contrib-copy',
#    'grunt-contrib-jshint',
#    'grunt-contrib-uglify',
#    'grunt-jsdoc',
#    'grunt-mocha-phantomjs',
#    'grunt-mocha-test',
#    'jshint-stylish',
#    'mocha',
#    'promise',
#    'sinon',
#    'underscore',
#    'underscore-query'],
#   ['tensorflow'],
#   ['numpy', 'pandas', 'scikit-learn', 'scipy'],
#   ['numpy'],
#   ['statonlab/tripal-test-suite',
#    'doctrine/instantiator',
#    'fzaninotto/faker',
#    'guzzlehttp/guzzle',
#    'guzzlehttp/promises',
#    'guzzlehttp/psr7',
#    'myclabs/deep-copy',
#    'phar-io/manifest',
#    'phar-io/version',
#    'phpdocumentor/reflection-common',
#    'phpdocumentor/reflection-docblock',
#    'phpdocumentor/type-resolver',
#    'phpspec/prophecy',
#    'phpunit/php-code-coverage',
#    'phpunit/php-file-iterator',
#    'phpunit/php-text-template',
#    'phpunit/php-timer',
#    'phpunit/php-token-stream',
#    'phpunit/phpunit',
#    'psr/container',
#    'psr/http-message',
#    'ralouphie/getallheaders',
#    'sebastian/code-unit-reverse-lookup',
#    'sebastian/comparator',
#    'sebastian/diff',
#    'sebastian/environment',
#    'sebastian/exporter',
#    'sebastian/global-state',
#    'sebastian/object-enumerator',
#    'sebastian/object-reflector',
#    'sebastian/recursion-context',
#    'sebastian/resource-operations',
#    'sebastian/version',
#    'symfony/console',
#    'symfony/polyfill-ctype',
#    'symfony/polyfill-mbstring',
#    'symfony/polyfill-php73',
#    'symfony/service-contracts',
#    'theseer/tokenizer',
#    'webmozart/assert'],
#   ['coveralls',
#    'matplotlib',
#    'numpy',
#    'pandas',
#    'pytest',
#    'scikit-image',
#    'astropy',
#    'holoviews',
#    'hvplot',
#    'planetpy',
#    'pysis',
#    'seaborn',
#    'tables',
#    'xarray',
#    'jupyter-client',
#    'nbsphinx',
#    'pillow',
#    'sphinxcontrib-bibtex'],
#   ['setuptools'],
#   ['numpy',
#    'scipy',
#    'codacy-coverage',
#    'cryptography',
#    'flake8',
#    'jinja2',
#    'pre-commit',
#    'pytest-cov',
#    'pytest-flake8',
#    'pytest-runner',
#    'watchdog',
#    'wheel',
#    'yapf',
#    'matplotlib',
#    'sphinx',
#    'sphinx-rtd-theme',
#    'sphinxcontrib-bibtex',
#    'pytest',
#    'six'],
#   ['jake', 'jshint', 'karma', 'leaflet', 'magic-string', 'mocha', 'uglify-js'],
#   ['aplayer', 'balloon-css', 'promise-polyfill', 'smoothscroll'],
#   ['matplotlib', 'numpy', 'pathos', 'pyqt5', 'scipy'],
#   ['numpy', 'scipy', 'torch', 'torchvision'],
#   ['numpy', 'sympy'],
#   ['ch.tatool:tatool-app',
#    'ch.tatool:tatool-core',
#    'ch.tatool:tatool-test',
#    'com.jolira:onejar-maven-plugin',
#    'org.apache.maven.plugins:maven-compiler-plugin',
#    'org.apache.maven.plugins:maven-jar-plugin'],
#   ['locustio', 'm3u8', 'mpegdash', 'requests'],
#   ['jupyter', 'jupyterthemes', 'mdutils', 'numpy', 'pandas'],
#   ['filelock', 'six'],
#   ['future',
#    'gensim',
#    'joblib',
#    'jupyter',
#    'matplotlib',
#    'regex',
#    'scikit-learn',
#    'seaborn',
#    'six',
#    'sklearn-crfsuite'],
#   ['setuptools', 'six'],
#   ['joblib',
#    'keras',
#    'matplotlib',
#    'numpy',
#    'sklearn',
#    'tensorflow',
#    'CommandLineParser',
#    'CsvHelper',
#    'Microsoft.ML',
#    'System.Text.Encoding.CodePages',
#    'Microsoft.NET.Test.Sdk',
#    'MSTest.TestAdapter',
#    'MSTest.TestFramework'],
#   ['appdirs',
#    'boto3',
#    'colorful',
#    'google-api-core',
#    'google-api-python-client',
#    'google-auth',
#    'google-auth-httplib2',
#    'google-cloud',
#    'google-cloud-vision',
#    'googleapis-common-protos',
#    'grpcio',
#    'halo',
#    'humanize',
#    'imagesize',
#    'matplotlib',
#    'numpy',
#    'pillow',
#    'plac',
#    'psutil',
#    'pymupdf',
#    'requests',
#    'setuptools',
#    'stringdist',
#    'termcolor',
#    'textdistance',
#    'urllib3',
#    'wheel'],
#   ['cri',
#    'jeweler',
#    'minitest',
#    'rake',
#    'rubocop',
#    'typhoeus',
#    'addressable',
#    'ast',
#    'builder',
#    'descendants_tracker',
#    'ethon',
#    'faraday',
#    'ffi',
#    'git',
#    'github_api',
#    'hashie',
#    'highline',
#    'jaro_winkler',
#    'jwt',
#    'mime-types',
#    'mini_portile2',
#    'multipart-post',
#    'multi_json',
#    'multi_xml',
#    'nokogiri',
#    'oauth2',
#    'parallel',
#    'parser',
#    'psych',
#    'rack',
#    'rainbow',
#    'rdoc',
#    'ruby-progressbar',
#    'semver2',
#    'thread_safe',
#    'unicode-display_width'],
#   ['biopython',
#    'bokeh',
#    'connexion',
#    'flask-cors',
#    'jsonschema',
#    'mhcflurry',
#    'mhcnuggets',
#    'mock',
#    'networkx',
#    'pandas',
#    'pillow',
#    'py-postgresql',
#    'pymp-pypi',
#    'pysam',
#    'pyvcf',
#    'pyyaml',
#    'requests',
#    'simanneal',
#    'swagger-spec-validator',
#    'tornado',
#    'vaxrank',
#    'watchdog',
#    'wget',
#    'pvactools',
#    'sphinx',
#    'sphinxcontrib-programoutput',
#    'sphinxjp-themes-basicstrap'],
#   ['pandas', 'requests', 'webdavclient'],
#   ['astropy', 'numpy', 'pandas', 'pytest', 'requests'],
#   ['com.h2database:h2',
#    'junit:junit',
#    'org.apache.maven.plugins:maven-dependency-plugin',
#    'org.apache.maven.plugins:maven-jar-plugin',
#    'org.apache.poi:ooxml-schemas',
#    'org.apache.poi:poi',
#    'org.apache.poi:poi-ooxml',
#    'org.geotools:gt-epsg-hsql',
#    'org.geotools:gt-grid',
#    'org.geotools:gt-shapefile',
#    'org.geotools:gt-swing'],
#   ['libpysal', 'numpy', 'pandas', 'scipy', 'seaborn', 'spreg'],
#   ['matplotlib', 'numpy', 'scipy'],
#   ['fbs',
#    'natsort',
#    'numpy',
#    'pillow',
#    'pyqt5',
#    'pywavelets',
#    'scikit-image',
#    'scipy',
#    'setuptools',
#    'torch',
#    'torchvision'],
#   ['absl-py',
#    'appdirs',
#    'astunparse',
#    'attrs',
#    'backcall',
#    'bleach',
#    'cachetools',
#    'certifi',
#    'chardet',
#    'colorama',
#    'configparser',
#    'cycler',
#    'decorator',
#    'defusedxml',
#    'distlib',
#    'entrypoints',
#    'filelock',
#    'gast',
#    'google-auth',
#    'google-auth-oauthlib',
#    'google-pasta',
#    'graphviz',
#    'grpcio',
#    'h5py',
#    'idna',
#    'importlib-metadata',
#    'ipykernel',
#    'ipython',
#    'ipython-genutils',
#    'ipywidgets',
#    'jedi',
#    'jinja2',
#    'joblib',
#    'jsonschema',
#    'jupyter',
#    'jupyter-client',
#    'jupyter-console',
#    'jupyter-core',
#    'jupyter-tabnine',
#    'keras',
#    'keras-applications',
#    'keras-preprocessing',
#    'kiwisolver',
#    'markdown',
#    'markupsafe',
#    'matplotlib',
#    'mistune',
#    'nbconvert',
#    'nbformat',
#    'neural-structured-learning',
#    'notebook',
#    'numpy',
#    'oauthlib',
#    'opt-einsum',
#    'packaging',
#    'pandas',
#    'pandocfilters',
#    'parso',
#    'pickleshare',
#    'pillow',
#    'plotly',
#    'pluggy',
#    'prometheus-client',
#    'prompt-toolkit',
#    'protobuf',
#    'pyagrum',
#    'pyasn1',
#    'pyasn1-modules',
#    'pydotplus',
#    'pygments',
#    'pyparsing',
#    'pyrsistent',
#    'python-dateutil',
#    'python-jsonrpc-server',
#    'python-language-server',
#    'pytz',
#    'pywin32',
#    'pywinpty',
#    'pyyaml',
#    'pyzmq',
#    'qtconsole',
#    'qtpy',
#    'requests',
#    'requests-oauthlib',
#    'retrying',
#    'rsa',
#    'scikit-learn',
#    'scipy',
#    'send2trash',
#    'six',
#    'tensorboard',
#    'tensorboard-plugin-wit',
#    'tensorflow',
#    'tensorflow-estimator',
#    'termcolor',
#    'terminado',
#    'testpath',
#    'threadpoolctl',
#    'tornado',
#    'traitlets',
#    'urllib3',
#    'virtualenv',
#    'wcwidth',
#    'webencodings',
#    'werkzeug',
#    'widgetsnbextension',
#    'wrapt',
#    'zipp'],
#   ['demandlib',
#    'dill',
#    'matplotlib',
#    'networkx',
#    'numpy',
#    'oemof',
#    'pandas',
#    'reegis',
#    'rtree',
#    'shapely',
#    'workalendar',
#    'xlrd',
#    'xlwt'],
#   ['duecredit', 'pybids'],
#   ['ipython',
#    'jupyter',
#    'matplotlib',
#    'matplotlib-scalebar',
#    'networkx',
#    'numpy',
#    'pandas',
#    'peakutils',
#    'scikit-image',
#    'scikit-learn',
#    'scipy'],
#   ['diffeqpy',
#    'ipython',
#    'julia',
#    'jupyter',
#    'matplotlib',
#    'numba',
#    'numpy',
#    'python',
#    'scipy',
#    'sparse',
#    'sphinx',
#    'sphinx-rtd-theme',
#    'sphinxcontrib-bibtex'],
#   ['org.jfree:jfreechart', 'org.mongodb:mongo-java-driver'],
#   ['body-parser', 'dotenv', 'express', 'os-monitor', 'twilio'],
#   ['numpy',
#    'pytest',
#    'pytest-allclose',
#    'pytest-cov',
#    'pytest-raises',
#    'pytest-timeout',
#    'scipy'],
#   ['ase',
#    'matplotlib',
#    'monty',
#    'numba',
#    'numpy',
#    'phonopy',
#    'scipy',
#    'seekpath',
#    'spglib',
#    'torch'],
#   ...],
#  3012)

# %% [markdown]
# ## Doc Embedding

# %%
LabeledSentence1 = gensim.models.doc2vec.TaggedDocument
all_content_train = []
j=0
for em in dep_list:
    all_content_train.append(LabeledSentence1(em,[j]))
    j+=1
print('Number of repos processed: ', j)
# Out:
# Number of repos processed:  3012

# %%
d2v_model = Doc2Vec(all_content_train, 
                    size = 100, 
                    window = 10, 
                    min_count = 1, 
                    workers=7, 
                    dm = 1,
                    alpha=0.025, 
                    min_alpha=0.001)
d2v_model.train(all_content_train, 
                total_examples=d2v_model.corpus_count, 
                epochs=10, 
                start_alpha=0.002, 
                end_alpha=-0.016)

d2v_model[0]
# Out:
# /opt/anaconda3/envs/Knowledge_Graph/lib/python3.6/site-packages/gensim/models/doc2vec.py:319: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# array([ 0.00458806,  0.03768101,  0.01253925, -0.04197038, -0.02798572,
#         0.02302323, -0.03229389, -0.0131154 , -0.06217861, -0.00044862,
#         0.0476163 , -0.0166369 ,  0.00543086,  0.01682888,  0.01729672,
#         0.00422281,  0.03290429,  0.00039571,  0.02714512, -0.00975056,
#        -0.0057607 ,  0.04694798,  0.0007891 , -0.00273268,  0.04533802,
#         0.05385239, -0.02966216,  0.01982142, -0.00948914,  0.00283305,
#        -0.02114621, -0.00951162, -0.00365996, -0.0178862 ,  0.05752014,
#        -0.01462043, -0.02994952,  0.0020511 ,  0.03393682, -0.00038157,
#         0.01067804,  0.01912075,  0.01222714,  0.0031634 , -0.00867806,
#        -0.04176655, -0.01957559, -0.02376308, -0.01774316,  0.03373904,
#        -0.0553568 , -0.00011773,  0.03944528,  0.0190468 ,  0.00881731,
#        -0.00263658, -0.0203399 ,  0.00198226, -0.0179656 ,  0.00077303,
#         0.0376535 , -0.0106577 ,  0.03003998,  0.00855911, -0.02845825,
#         0.00961545,  0.03849403,  0.0047895 ,  0.01076723,  0.04982728,
#         0.02013407,  0.00175381, -0.01091955,  0.02449808,  0.01646436,
#         0.03527712, -0.04837387,  0.01561082,  0.00892898, -0.04985464,
#        -0.04019606,  0.05415427, -0.01215793,  0.01751248,  0.01662073,
#         0.03775551,  0.02277621,  0.01625231, -0.00143798,  0.00371753,
#         0.00142202,  0.00703247, -0.02315709, -0.0230434 ,  0.00435901,
#         0.03550468, -0.01325826, -0.02257816,  0.01954854,  0.03312115],
#       dtype=float32)

# %% [markdown]
# ## Clustering - Kmeans

# %%
kmeans_model = KMeans(n_clusters=10, init='k-means++', max_iter=500) 
X = kmeans_model.fit(d2v_model.docvecs.doctag_syn0)
labels=kmeans_model.labels_
# Out:
# /opt/anaconda3/envs/Knowledge_Graph/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `doctag_syn0` (Attribute will be removed in 4.0.0, use docvecs.vectors_docs instead).

# %%
topic_dict = {}
for index,label in enumerate(labels):
    topic_id = label
    print(topic_id, '--->', rep_list[index])
    
    topic_dict[label] = topic_dict.get(label,[])
    topic_dict[label].append(rep_list[index])
# Out:
# 1 ---> https://github.com/AgriculturalModelExchangeInitiative/Crop2ML
# 1 ---> https://github.com/natcap/natgeo-dams
# 1 ---> https://github.com/hlgirard/CrystalML
# 1 ---> https://github.com/houghb/ligpy
# 1 ---> https://github.com/oschwengers/referenceseeker
# 1 ---> https://github.com/LPDI-EPFL/trivalent_cocktail
# 1 ---> https://github.com/CIRA-Pulsars-and-Transients-Group/vcstools
# 5 ---> https://github.com/usc-isi-i2/kgtk
# 1 ---> https://github.com/garciagenrique/template_project_escape
# 8 ---> https://github.com/gwu-libraries/sfm-docker
# 5 ---> https://github.com/javaparser/javaparser
# 1 ---> https://github.com/williamjameshandley/anesthetic
# 1 ---> https://github.com/yardencsGitHub/tweetynet
# 1 ---> https://github.com/jagalindo/A-Python-QX-implementation
# 1 ---> https://github.com/jbkinney/mavenn
# 1 ---> https://github.com/GeoCode-polymtl/Seis_float16
# 1 ---> https://github.com/sebp/scikit-survival
# 1 ---> https://github.com/similitude/sumo-simmer
# 8 ---> https://github.com/GlobalNamesArchitecture/gnresolver
# 8 ---> https://github.com/nevenjovanovic/treebank-polybius
# 1 ---> https://github.com/Biophotonics-COMI/flimview
# 1 ---> https://github.com/joshspeagle/brutus
# 5 ---> https://github.com/metomi/isodatetime
# 1 ---> https://github.com/indralab/pybiopax
# 4 ---> https://github.com/FNNDSC/ChRIS_ui
# 5 ---> https://github.com/openphacts/explorer2
# 1 ---> https://github.com/TDAmeritrade/stumpy
# 1 ---> https://github.com/habi/acinar-analysis
# 1 ---> https://github.com/mbernste/hypothesis-driven-SRA-queries
# 0 ---> https://github.com/JiaxiangBU/dynamic_topic_modeling
# 8 ---> https://github.com/KnowledgeCaptureAndDiscovery/OBA_sparql
# 1 ---> https://github.com/maxscheurer/cppe
# 1 ---> https://github.com/Sung-Huan/ANNOgesic
# 5 ---> https://github.com/mayconbordin/storm-applications
# 1 ---> https://github.com/gauteh/ibcao_py
# 1 ---> https://github.com/GLAM-Workbench/te-papa-api
# 5 ---> https://github.com/cerebis/shap
# 0 ---> https://github.com/K3D-tools/K3D-jupyter
# 8 ---> https://github.com/CCMi-FIT/ontouml-code-generator
# 8 ---> https://github.com/diging/tethne
# 1 ---> https://github.com/mmhs013/pyHomogeneity
# 1 ---> https://github.com/bukhsh/oats
# 8 ---> https://github.com/mukil/pmic
# 1 ---> https://github.com/pySTEPS/pysteps
# 1 ---> https://github.com/groupeLIAMG/ttcr
# 1 ---> https://github.com/oujago/NumpyDL
# 4 ---> https://github.com/xldrkp/zocurelia
# 5 ---> https://github.com/encompasslabs/encompass-aquiferium
# 1 ---> https://github.com/deniederhut/niacin
# 1 ---> https://github.com/ZurichNLP/xstance
# 1 ---> https://github.com/raotnameh/End-to-end-E2E-Named-Entity-Recognition-from-English-Speech
# 1 ---> https://github.com/clincolnoz/maDMP-rocrates-maDMP
# 1 ---> https://github.com/thorstenwagner/ij-trajectory-classifier
# 1 ---> https://github.com/danielrd6/ifscube
# 1 ---> https://github.com/esteinig/sketchy
# 8 ---> https://github.com/opium-sh/prl
# 8 ---> https://github.com/maikherbig/AIDeveloper
# 1 ---> https://github.com/LFPy/LFPy
# 1 ---> https://github.com/aalzubidy/ssrt
# 1 ---> https://github.com/1QB-Information-Technologies/COOL
# 1 ---> https://github.com/morpheus-project/morpheus
# 1 ---> https://github.com/firedrakeproject/firedrake
# 1 ---> https://github.com/leal26/AeroPy
# 8 ---> https://github.com/arose/nglview
# 1 ---> https://github.com/jpgill86/neurotic
# 5 ---> https://github.com/MegaAttitude/frequency-acceptability-selection
# 1 ---> https://github.com/bertrandcz/CrocO_toolbox
# 1 ---> https://github.com/andsor/gridjug
# 1 ---> https://github.com/stfxecutables/empyricalRMT
# 8 ---> https://github.com/wmayner/pyphi
# 3 ---> https://github.com/isle-project/isle-editor
# 4 ---> https://github.com/cytoscape/cytoscape.js
# 8 ---> https://github.com/dejac001/MCFlow
# 8 ---> https://github.com/dragoon/kilogram
# 8 ---> https://github.com/pysal/spaghetti
# 8 ---> https://github.com/brisskit-uol/i2b2-install-procedures
# 1 ---> https://github.com/bast/runtest
# 8 ---> https://github.com/VarIr/scikit-hubness
# 8 ---> https://github.com/qbicsoftware/omero-client-portlet
# 5 ---> https://github.com/jyrkioraskari/IFCtoLBD_OpenAPI
# 1 ---> https://github.com/wright-group/WrightTools
# 8 ---> https://github.com/CamDavidsonPilon/lifelines
# 1 ---> https://github.com/tpall/pynodo
# 1 ---> https://github.com/rmkoesterer/uga
# 1 ---> https://github.com/proycon/clam
# 1 ---> https://github.com/GoekeLab/xpore
# 8 ---> https://github.com/ml-evs/matador
# 1 ---> https://github.com/stefsmeets/instamatic
# 1 ---> https://github.com/danxhuber/isoclassify
# 1 ---> https://github.com/proycon/colibri-core
# 0 ---> https://github.com/Yi-ran/Omnetpp
# 1 ---> https://github.com/alielhassouni/rl-multi-agent-simulation-for-e-health
# 5 ---> https://github.com/PTB-PSt1/time-series-metadata
# 1 ---> https://github.com/amueller/patsylearn
# 0 ---> https://github.com/globalbioticinteractions/globalbioticinteractions
# 0 ---> https://github.com/jiemakel/snapper
# 0 ---> https://github.com/digitallinguistics/scription2dlx
# 1 ---> https://github.com/lacava/few
# 1 ---> https://github.com/mheikenfeld/ramscube
# 1 ---> https://github.com/python-pillow/Pillow
# 1 ---> https://github.com/Silmathoron/NNGT
# 9 ---> https://github.com/RubenVerborgh/WebFundamentals
# 1 ---> https://github.com/ariercole/Cambridge_COVID-19_ICU
# 1 ---> https://github.com/JDRomano2/smdb_search
# 1 ---> https://github.com/matthiasweiss/dsue1-2020s
# 1 ---> https://github.com/jenojp/negspacy
# 1 ---> https://github.com/MartinPdS/OCT_calibration
# 1 ---> https://github.com/cmsopendata-finland/kurssimateriaali
# 5 ---> https://github.com/africanmathsinitiative/R-Instat
# 1 ---> https://github.com/SDM-TIB/SDM-RDFizer
# 1 ---> https://github.com/HERA-Team/librarian
# 8 ---> https://github.com/tkralphs/CuPPy
# 1 ---> https://github.com/r9y9/pylibfreenect2
# 4 ---> https://github.com/dmj/PicaRecord
# 8 ---> https://github.com/smartbugs/smartbugs
# 1 ---> https://github.com/Andros-Spica/EAA2018_ceramics
# 1 ---> https://github.com/arm61/uravu
# 8 ---> https://github.com/casmlab/facebook_group_collector
# 0 ---> https://github.com/vboyce/Maze
# 1 ---> https://github.com/acoular/acoular
# 5 ---> https://github.com/smarie/python-autoclass
# 1 ---> https://github.com/underworldcode/UWGeodynamics
# 1 ---> https://github.com/clij/clij2
# 1 ---> https://github.com/sherbold/autorank
# 1 ---> https://github.com/saschneider/VMV
# 1 ---> https://github.com/CENER-EPR/OWAbench
# 1 ---> https://github.com/tempdata73/tic-tac-toe
# 4 ---> https://github.com/molbiodiv/biojs-io-biom
# 1 ---> https://github.com/olivettigroup/article-downloader
# 4 ---> https://github.com/leilaicruz/Experimental-journal-deploy
# 4 ---> https://github.com/ltrr-arizona-edu/tellervo
# 1 ---> https://github.com/egonw/jqudt
# 8 ---> https://github.com/catalyst-cooperative/pudl
# 1 ---> https://github.com/TUDelft-CITG/OpenTISim
# 1 ---> https://github.com/hipster-philology/nlp-pie-taggers
# 1 ---> https://github.com/martinlackner/abcvoting
# 1 ---> https://github.com/pv/fimport
# 1 ---> https://github.com/nextgenusfs/funannotate
# 1 ---> https://github.com/cmccoy/ighutil
# 1 ---> https://github.com/kylemede/ExoSOFT
# 1 ---> https://github.com/AOtools/aotools
# 1 ---> https://github.com/weecology/retriever
# 1 ---> https://github.com/mdolab/idwarp
# 1 ---> https://github.com/paberlo/FastFeatureSelection
# 1 ---> https://github.com/davidrpugh/pyAM
# 8 ---> https://github.com/wateraccounting/IHEWAcollect
# 1 ---> https://github.com/N3PDF/yadism
# 1 ---> https://github.com/JohannesBuchner/snowline
# 1 ---> https://github.com/pychebfun/pychebfun
# 1 ---> https://github.com/mmadsen/ctmixtures
# 1 ---> https://github.com/coin-or/GiMPy
# 1 ---> https://github.com/hibernator11/notebook-lod-libraries
# 1 ---> https://github.com/GlobalNamesArchitecture/gn_uuid
# 1 ---> https://github.com/muammar/heisenberg
# 1 ---> https://github.com/spex-xray/pyspextools
# 1 ---> https://github.com/csdms/pymt
# 1 ---> https://github.com/santiago1234/MZT-rna-stability
# 8 ---> https://github.com/sehero/lua
# 1 ---> https://github.com/sepandhaghighi/qpage
# 1 ---> https://github.com/qmlcode/qml
# 1 ---> https://github.com/dmyersturnbull/tyrannosaurus
# 5 ---> https://github.com/wild-fire/twitter-graph-segmenter
# 1 ---> https://github.com/alcantarar/dryft
# 8 ---> https://github.com/DaniloZZZ/Qensor
# 8 ---> https://github.com/jfsantos/mushra-ruby-server
# 1 ---> https://github.com/MaayanLab/Zika-RNAseq-Pipeline
# 1 ---> https://github.com/pyReef-model/RADWave
# 1 ---> https://github.com/src-d/kmcuda
# 1 ---> https://github.com/perrygeo/pyimpute
# 1 ---> https://github.com/toshas/torch-fidelity
# 1 ---> https://github.com/intermine/intermine
# 1 ---> https://github.com/SasView/sasview
# 8 ---> https://github.com/SommerEngineering/NoiseEngine
# 4 ---> https://github.com/mathjax/MathJax-src
# 5 ---> https://github.com/IFCA/keystone-voms
# 1 ---> https://github.com/zfit/zfit-physics
# 1 ---> https://github.com/abhi1693/yii2-system-info
# 1 ---> https://github.com/harmslab/pytc
# 1 ---> https://github.com/biosustain/pyrcos
# 1 ---> https://github.com/CNRGH/contatester
# 1 ---> https://github.com/pcko1/Deep-Drug-Coder
# 1 ---> https://github.com/gree-gorey/rusclasp
# 1 ---> https://github.com/chartes/deucalion-model-lasla
# 1 ---> https://github.com/zero323/developing-data-products-shiny
# 1 ---> https://github.com/etnbrd/flx-example
# 0 ---> https://github.com/dalmia/siren
# 8 ---> https://github.com/sanshu/protaeljs
# 1 ---> https://github.com/dev-cafe/autocmake
# 5 ---> https://github.com/whitemech/LTLf2DFA
# 1 ---> https://github.com/SanneHoeken/HEEM-Data-Extractions
# 1 ---> https://github.com/cayolopesbc/eco-data-toolkit
# 1 ---> https://github.com/fliem/cpr
# 1 ---> https://github.com/Capitains/Hook-Worker
# 1 ---> https://github.com/OSSOS/liborbfit
# 1 ---> https://github.com/r9y9/nnmnkwii
# 5 ---> https://github.com/rdmorganiser/rdmo
# 4 ---> https://github.com/karimamufidah/karimamufidah.github.io
# 1 ---> https://github.com/assafZaritskyLab/IRM-Spreading-Dynamics
# 1 ---> https://github.com/paudetseis/PlateCurie
# 1 ---> https://github.com/cyclops-community/tensorbackends
# 1 ---> https://github.com/astrofle/CRRLpy
# 1 ---> https://github.com/stanford-futuredata/Willump
# 0 ---> https://github.com/petebrew/fhaes
# 8 ---> https://github.com/tferr/hIPNAT
# 1 ---> https://github.com/cescalara/minieuso_cpu
# 1 ---> https://github.com/phiweger/zoo
# 1 ---> https://github.com/shenlab-sinai/region_analysis
# 1 ---> https://github.com/duncanmmacleod/requests-ecp
# 1 ---> https://github.com/biasmv/pv
# 1 ---> https://github.com/podondra/bt-spectraldl
# 1 ---> https://github.com/ubermag/micromagnetictests
# 1 ---> https://github.com/amunozj/magnetograph_2HMI_converter
# 1 ---> https://github.com/r9y9/pysptk
# 1 ---> https://github.com/michaelaye/venim
# 1 ---> https://github.com/justinnk/bss-simulation-study
# 4 ---> https://github.com/LDflex/LDflex
# 5 ---> https://github.com/FAST-HEP/fast-carpenter
# 1 ---> https://github.com/lpwgroup/torsiondrive
# 8 ---> https://github.com/CCS-Lab/easyml
# 1 ---> https://github.com/datajoint/datajoint-python
# 1 ---> https://github.com/hallamlab/mlLGPR
# 1 ---> https://github.com/cmbant/CosmoMC
# 8 ---> https://github.com/lukasValentin/OBIA4RTM
# 1 ---> https://github.com/bowsersenior/itu_codes
# 1 ---> https://github.com/loostrum/darc
# 8 ---> https://github.com/sdorkenw/MeshParty
# 1 ---> https://github.com/RadioAstronomySoftwareGroup/pyuvsim
# 3 ---> https://github.com/cggh/panoptes
# 8 ---> https://github.com/experimaestro/datamaestro
# 0 ---> https://github.com/ruby-rdf/rdf
# 1 ---> https://github.com/ARGOeu/argo-api-authn
# 1 ---> https://github.com/NBISweden/workshop_omics_integration
# 1 ---> https://github.com/PyThaiNLP/Thai-Text-Generator
# 1 ---> https://github.com/aditya95sriram/td-slim
# 1 ---> https://github.com/geoopt/geoopt
# 1 ---> https://github.com/jswoboda/ISRSpectrum
# 1 ---> https://github.com/jonschwenk/RivGraph
# 1 ---> https://github.com/thoppe/Encyclopedia-of-Finite-Graphs
# 1 ---> https://github.com/Ry-C123/LazyPSF
# 9 ---> https://github.com/bionode/bionode-sra
# 1 ---> https://github.com/tjof2/ctrwfractal
# 1 ---> https://github.com/MatthewBCooke/Pathfinder
# 8 ---> https://github.com/connectomicslab/connectomemapper3
# 1 ---> https://github.com/rpep/fmmgen
# 8 ---> https://github.com/bionode/bionode-bbi
# 1 ---> https://github.com/griffin-h/superphot
# 2 ---> https://github.com/neuroscout/neuroscout
# 1 ---> https://github.com/tsamsonov/generalize-dem
# 1 ---> https://github.com/comodide/CoModIDE
# 1 ---> https://github.com/cscully-allison/Materia
# 4 ---> https://github.com/dnet-team/dnet-basic-aggregator
# 1 ---> https://github.com/tschaume/ccsgp_get_started
# 1 ---> https://github.com/discos/discos-backend
# 1 ---> https://github.com/wmayner/pyemd
# 1 ---> https://github.com/drsteve/PyForecastTools
# 1 ---> https://github.com/nickk124/RCR
# 1 ---> https://github.com/rmsolgi/geneticalgorithm
# 1 ---> https://github.com/mmhs013/pyMannKendall
# 8 ---> https://github.com/fusion-jena/abecto
# 1 ---> https://github.com/TerrainBento/terrainbento
# 1 ---> https://github.com/mwaskom/seaborn
# 1 ---> https://github.com/florafauna/optimParallel-python
# 1 ---> https://github.com/pietrobarbiero/evofs
# 1 ---> https://github.com/IsaacCorley/pytorch-enhance
# 1 ---> https://github.com/ecell/ecell4
# 1 ---> https://github.com/mirnylab/bioframe
# 1 ---> https://github.com/dean0x7d/pybinding
# 1 ---> https://github.com/janmtl/pypsych
# 1 ---> https://github.com/lcharleux/abapy
# 0 ---> https://github.com/pyhf/neos
# 8 ---> https://github.com/CiTR/djland
# 1 ---> https://github.com/nuest/ten-simple-rules-dockerfiles
# 1 ---> https://github.com/OpenSourceEconomics/ruspy
# 0 ---> https://github.com/ameyaKetkar/TypeChangeMiner
# 1 ---> https://github.com/lingfeiwang/normalisr
# 1 ---> https://github.com/ShuhuaGao/geppy
# 1 ---> https://github.com/bgruening/galaxy_ie_helpers
# 1 ---> https://github.com/pyvideo/data
# 1 ---> https://github.com/azedarach/matrix-factorization-case-studies
# 1 ---> https://github.com/driplineorg/dripline-python
# 1 ---> https://github.com/LoLab-VU/Gleipnir
# 1 ---> https://github.com/uwmadison-chm/scorify
# 1 ---> https://github.com/NESCent/fcdb-api
# 1 ---> https://github.com/csu-hmc/GaitAnalysisToolKit
# 1 ---> https://github.com/bakery-cg2at/bakery
# 1 ---> https://github.com/radical-cybertools/radical.synapse
# 8 ---> https://github.com/MaineKuehn/usim
# 1 ---> https://github.com/ag-gipp/FormulaCloudData
# 1 ---> https://github.com/astrom-tom/dfitspy
# 1 ---> https://github.com/SP7-Ritmare/EDI-NG_client
# 9 ---> https://github.com/jona-sassenhagen/statfail
# 8 ---> https://github.com/spacetelescope/jwql
# 1 ---> https://github.com/ePSIC-DLS/ParticleSpy
# 1 ---> https://github.com/N3PDF/pineappl
# 8 ---> https://github.com/rinde/vanLon17-JAAMAS-code
# 1 ---> https://github.com/pitthsls/pycounter
# 1 ---> https://github.com/hippylib/hippylib
# 1 ---> https://github.com/felixriese/CNN-SoilTextureClassification
# 1 ---> https://github.com/IQuOD/wodpy
# 1 ---> https://github.com/ahendriksen/msd_pytorch
# 4 ---> https://github.com/tobysmith568/TestEnv
# 1 ---> https://github.com/lucasberent/ds
# 8 ---> https://github.com/sgoldenlab/simba
# 1 ---> https://github.com/jonathanmorgan/django_config
# 4 ---> https://github.com/IbrahimTanyalcin/RafX
# 1 ---> https://github.com/mdolab/adflow
# 8 ---> https://github.com/Phylu/csd
# 8 ---> https://github.com/ebmdatalab/trialstracker
# 0 ---> https://github.com/datapoet/hubminer
# 1 ---> https://github.com/midas-isg/PITT-SEIR-model
# 9 ---> https://github.com/zakandrewking/escher
# 8 ---> https://github.com/EMAPS/climaps-platform
# 1 ---> https://github.com/OpenChemistry/tomviz
# 8 ---> https://github.com/yeeking/evosynth
# 8 ---> https://github.com/rinde/vanLon16-EJOR-code
# 8 ---> https://github.com/biowdl/QC
# 0 ---> https://github.com/intelaligent/tctb
# 5 ---> https://github.com/rinde/RinLog
# 1 ---> https://github.com/sertansenturk/seyiranalyzer
# 1 ---> https://github.com/sertansenturk/alignednotemodel
# 1 ---> https://github.com/miklos1/dijitso
# 8 ---> https://github.com/smart-facility/cognicity-reports-twitter
# 2 ---> https://github.com/speckleworks/SpeckleServer
# 1 ---> https://github.com/schwemro/diag-eff
# 0 ---> https://github.com/jacobwindsor/MetabMaster
# 1 ---> https://github.com/NLeSC/mcfly
# 8 ---> https://github.com/hahnec/plenopticam
# 8 ---> https://github.com/ICB-DCM/AMICI
# 1 ---> https://github.com/kundajelab/abstention
# 5 ---> https://github.com/qPRC/qPRC
# 2 ---> https://github.com/ecds/readux
# 5 ---> https://github.com/cemac/COMET_VolcDB
# 1 ---> https://github.com/transientlunatic/otter
# 8 ---> https://github.com/dftlibs/xcfun
# 8 ---> https://github.com/IKNL/vantage6
# 5 ---> https://github.com/PhiliPdB/treedepth-exact
# 1 ---> https://github.com/deniederhut/weather_report
# 8 ---> https://github.com/biowdl/structural-variantcalling
# 1 ---> https://github.com/kikuchipy/kikuchipy
# 1 ---> https://github.com/LispTO/llthw
# 4 ---> https://github.com/cfe-lab/Kive
# 1 ---> https://github.com/gpauloski/kfac_pytorch
# 5 ---> https://github.com/materialsproject/pymatgen
# 1 ---> https://github.com/douglasdavis/pygram11
# 1 ---> https://github.com/jrkerns/pylinac
# 1 ---> https://github.com/dvasilen/Hive-XML-SerDe
# 0 ---> https://github.com/rubenarslan/formr.org
# 1 ---> https://github.com/yannforget/pylandsat
# 8 ---> https://github.com/gousiosg/pullreqs
# 8 ---> https://github.com/kantale/MutationInfo
# 1 ---> https://github.com/kdberends/coral
# 1 ---> https://github.com/llondon6/positive
# 1 ---> https://github.com/josecastillolema/mini-nfv
# 8 ---> https://github.com/driehle/emobility-search-engine
# 1 ---> https://github.com/LiyrAstroph/CDNest
# 8 ---> https://github.com/pysal/giddy
# 1 ---> https://github.com/LeeBergstrand/BackBLAST_Reciprocal_BLAST
# 1 ---> https://github.com/JanaLasser/salt-polygons-are-caused-by-convection
# 1 ---> https://github.com/mediawiki-utilities/python-mwreverts
# 1 ---> https://github.com/rbnvrw/semtracking
# 8 ---> https://github.com/coin-or/GrUMPy
# 1 ---> https://github.com/nist-ionstorage/pdq2
# 1 ---> https://github.com/TLCFEM/suanPan
# 1 ---> https://github.com/dlilien/ImpDAR
# 1 ---> https://github.com/ihrke/pypillometry
# 1 ---> https://github.com/willpearse/stalkless
# 1 ---> https://github.com/mmhss/sstrong-webhook
# 1 ---> https://github.com/RobotExMachina/Machina.NET
# 0 ---> https://github.com/tripal/private_biodata
# 5 ---> https://github.com/brown-ccv/neuro-task-starter
# 1 ---> https://github.com/FractalMedia/wheresmunna
# 1 ---> https://github.com/vivekbhr/scRIApipe
# 1 ---> https://github.com/coin-or/pulp
# 1 ---> https://github.com/Titan-C/slaveparticles
# 8 ---> https://github.com/GlobalNamesArchitecture/gn_crossmap
# 8 ---> https://github.com/indigo-dc/DEEPaaS
# 5 ---> https://github.com/densitymodelling/dsmextra
# 8 ---> https://github.com/SandstoneHPC/sandstone-spawner
# 4 ---> https://github.com/ENCODE-DCC/atac-seq-pipeline
# 1 ---> https://github.com/pnuehrenberg/multiviewtracks
# 1 ---> https://github.com/cerndb/dist-keras
# 8 ---> https://github.com/CESNET/proxystatistics-simplesamlphp-module
# 1 ---> https://github.com/MatterMiners/cobald
# 8 ---> https://github.com/asherpasha/Araport_GeneSlider
# 1 ---> https://github.com/matthewfeickert/IRIS-HEP-2020-Poster-Session
# 1 ---> https://github.com/r4ecology/nctoolkit
# 8 ---> https://github.com/transientlunatic/heron
# 1 ---> https://github.com/capaulson/pyKriging
# 1 ---> https://github.com/VlachosGroup/jl_spectra_2_structure
# 8 ---> https://github.com/NCBI-Hackathons/Structural_Variant_Comparison
# 1 ---> https://github.com/wradlib/wradlib
# 1 ---> https://github.com/CICE-Consortium/CICE
# 1 ---> https://github.com/sherpa/sherpa
# 1 ---> https://github.com/toros-astro/astroalign
# 1 ---> https://github.com/bootphon/ABXpy
# 4 ---> https://github.com/HuckleyLab/phyto-mhw
# 1 ---> https://github.com/pdxgx/neoepiscope
# 1 ---> https://github.com/danforthcenter/plantcv
# 1 ---> https://github.com/jkitchin/pycse
# 1 ---> https://github.com/rraadd88/rohan
# 8 ---> https://github.com/compas-dev/compas_fea
# 8 ---> https://github.com/Remdeht/ia_detector
# 1 ---> https://github.com/justagist/panda_simulator
# 1 ---> https://github.com/stemtool/stemtool
# 1 ---> https://github.com/mkoeppe/sage-numerical-interactive-mip
# 1 ---> https://github.com/Nu-AI/Livid-About-COVID
# 1 ---> https://github.com/PyLorentz/PyLorentz
# 8 ---> https://github.com/firedrakeproject/loopy
# 1 ---> https://github.com/ctsit/dxster
# 8 ---> https://github.com/bodkan/archaic-ychr
# 1 ---> https://github.com/PhysicsOfMobility/ridesharing_topology_dependence
# 1 ---> https://github.com/SuperKam91/twentyoneflow
# 1 ---> https://github.com/gwpy/gwosc
# 1 ---> https://github.com/duartegroup/cgbind
# 8 ---> https://github.com/raphaelvallat/pingouin
# 1 ---> https://github.com/pnlbwh/dMRIharmonization
# 5 ---> https://github.com/choderalab/assaytools
# 1 ---> https://github.com/cryotools/cosipy
# 1 ---> https://github.com/N3PDF/vegasflow
# 1 ---> https://github.com/althonos/pronto
# 8 ---> https://github.com/nipy/nipype
# 1 ---> https://github.com/sgrieve/sinuosity
# 1 ---> https://github.com/boivinalex/permittivitycalc
# 1 ---> https://github.com/BlueBrain/NeuroR
# 1 ---> https://github.com/Curtin-Open-Knowledge-Initiative/institutional-oa-evaluation-2020
# 1 ---> https://github.com/dgasmith/opt_einsum
# 1 ---> https://github.com/knutankv/koma
# 1 ---> https://github.com/foerstner-lab/READemption
# 1 ---> https://github.com/matthiaskoenig/fbc_curation
# 9 ---> https://github.com/dmitriz/cpsfy
# 1 ---> https://github.com/sdey135/rtapylysis
# 1 ---> https://github.com/CICE-Consortium/Icepack
# 1 ---> https://github.com/Nikoleta-v3/blackbook
# 8 ---> https://github.com/daniel-dpk/distorted-motsfinder-public
# 1 ---> https://github.com/StevenGolovkine/FDApy
# 1 ---> https://github.com/Leinadj/CREAM
# 1 ---> https://github.com/wjlei1990/spaceweight
# 1 ---> https://github.com/genomematt/AmBiVErT
# 4 ---> https://github.com/InsightSoftwareConsortium/itk-js
# 1 ---> https://github.com/owlcollab/expression-materializing-reasoner
# 1 ---> https://github.com/PEtab-dev/PEtab
# 1 ---> https://github.com/ziatdinovmax/GPim
# 1 ---> https://github.com/gwappa/fitting2d
# 1 ---> https://github.com/aeonium/fakedatacite
# 1 ---> https://github.com/boolsi/boolsi
# 1 ---> https://github.com/TomMonks/forecast-tools
# 1 ---> https://github.com/biowdl/tasks
# 1 ---> https://github.com/holoviz/hvplot
# 1 ---> https://github.com/mathjax/MathJax
# 1 ---> https://github.com/gwu-libraries/sfm-utils
# 1 ---> https://github.com/ci-group/revolve
# 1 ---> https://github.com/matthiaskoenig/sbmlsim
# 1 ---> https://github.com/biobakery/phylophlan
# 9 ---> https://github.com/rodighiero/COVID-19
# 8 ---> https://github.com/qzhu2017/PyXtal
# 1 ---> https://github.com/pnlbwh/multi-shell-dMRIharmonization
# 1 ---> https://github.com/loostrum/arts_tools
# 1 ---> https://github.com/jboynyc/textnets
# 8 ---> https://github.com/python-adaptive/adaptive
# 1 ---> https://github.com/nfsi-canada/OBStools
# 0 ---> https://github.com/tikk3r/lofar-grid-hpccloud
# 0 ---> https://github.com/governit/GovernIT
# 1 ---> https://github.com/nestordemeure/tabularGP
# 1 ---> https://github.com/AstraZeneca-NGS/disambiguate
# 1 ---> https://github.com/dgilford/pyPI
# 1 ---> https://github.com/Jacob-yen/LEMON
# 8 ---> https://github.com/tasoc/photometry
# 8 ---> https://github.com/qbicsoftware/omero-client-lib
# 1 ---> https://github.com/ASaiM/group_humann2_uniref_abundances_to_GO
# 1 ---> https://github.com/natashabatalha/virga
# 0 ---> https://github.com/lightonphiri/etd_autoclassifier
# 0 ---> https://github.com/ncrncornell/ced2ar
# 5 ---> https://github.com/clij/clij
# 1 ---> https://github.com/castelao/oceansdb
# 1 ---> https://github.com/conorwalsh/doat
# 1 ---> https://github.com/lweasel/piquant
# 1 ---> https://github.com/marinang/SimProd
# 1 ---> https://github.com/ishahid/django-gdm
# 1 ---> https://github.com/darribas/gds16
# 1 ---> https://github.com/calliope-project/calliope
# 8 ---> https://github.com/rockt/SETH
# 1 ---> https://github.com/zih-a35/trinityvm
# 5 ---> https://github.com/MRChemSoft/mrchem
# 1 ---> https://github.com/ehthiede/EMUS
# 1 ---> https://github.com/caiostringari/pywavelearn
# 6 ---> https://github.com/GeriLife/wellbeing
# 1 ---> https://github.com/aboucaud/pypher
# 1 ---> https://github.com/niosh-mining/obsplus
# 5 ---> https://github.com/scienceai/neocortex
# 1 ---> https://github.com/MPAS-Dev/MPAS-Analysis
# 1 ---> https://github.com/ralna/ElementSchur
# 1 ---> https://github.com/bdestombe/flopymetascript
# 1 ---> https://github.com/scikit-hep/awkward-array
# 1 ---> https://github.com/jonathansick/padova
# 8 ---> https://github.com/gwpy/gwsumm
# 1 ---> https://github.com/saullocastro/panels
# 8 ---> https://github.com/EHadoux/aptimizer
# 5 ---> https://github.com/mchoji/wtg-seal
# 1 ---> https://github.com/apetros/pyeplan
# 1 ---> https://github.com/Molmed/checkQC
# 1 ---> https://github.com/similitude/netlogo-sample-simmer
# 1 ---> https://github.com/castelao/CoTeDe
# 1 ---> https://github.com/matt-graham/mici
# 1 ---> https://github.com/donia-lab/MetaBGC
# 8 ---> https://github.com/nschloe/accupy
# 8 ---> https://github.com/KitwareMedical/SlicerITKUltrasound
# 1 ---> https://github.com/scities/marble
# 1 ---> https://github.com/hshsl-training/outreach-toolkit
# 6 ---> https://github.com/hyperwell/gateway
# 1 ---> https://github.com/tjof2/pgure-svt
# 1 ---> https://github.com/dfm/python-fsps
# 8 ---> https://github.com/kevindoyle/geoscience-first-authorship
# 1 ---> https://github.com/amuslija/fbd-complexity-tool
# 1 ---> https://github.com/N3PDF/evolutionary_keras
# 1 ---> https://github.com/fabfab1/EnCAB
# 8 ---> https://github.com/muammar/ml4chem
# 1 ---> https://github.com/fepegar/unet
# 1 ---> https://github.com/rtidatascience/django-postgres-stats
# 1 ---> https://github.com/esm-tools/esm_tools
# 8 ---> https://github.com/cwi-swat/bacata
# 8 ---> https://github.com/Sentimentron/PRJ9081
# 1 ---> https://github.com/hema-ted/pyzfs
# 1 ---> https://github.com/vitkl/orthologsBioMART
# 1 ---> https://github.com/davidrpugh/pyCollocation
# 1 ---> https://github.com/sbaltes/dblp-retriever
# 1 ---> https://github.com/vsoch/gridtest
# 0 ---> https://github.com/meteoinfo/MeteoInfo
# 1 ---> https://github.com/tcompa/anneal
# 1 ---> https://github.com/pansism/downscale-satelliteLST
# 1 ---> https://github.com/pyspeckit/pyspeckit
# 8 ---> https://github.com/TAMU-CPT/PAUSE
# 1 ---> https://github.com/mosdef-hub/forcefield_perfluoroethers
# 8 ---> https://github.com/dimazest/fowler.corpora
# 4 ---> https://github.com/a-callahan/MechWolf_Pull
# 1 ---> https://github.com/sami2py/sami2py
# 1 ---> https://github.com/gwu-libraries/sfm-weibo-harvester
# 1 ---> https://github.com/sojamo/oscp5
# 8 ---> https://github.com/OllyButters/puma
# 8 ---> https://github.com/aplowman/atomistic
# 1 ---> https://github.com/guaix-ucm/pyemir
# 1 ---> https://github.com/biosustain/croissance
# 1 ---> https://github.com/linhd-postdata/averell
# 8 ---> https://github.com/gbif/gbif-api
# 1 ---> https://github.com/kalyanpi4/pySW
# 1 ---> https://github.com/pitmonticone/Torino-Lione
# 1 ---> https://github.com/dave-heslop74/vMF_Specimens
# 1 ---> https://github.com/hollenstein/maspy
# 1 ---> https://github.com/wiai/xcdskd
# 5 ---> https://github.com/Ayllonbe/gsan
# 8 ---> https://github.com/romoreira/EdgeComputingSlice
# 8 ---> https://github.com/pysal/segregation
# 0 ---> https://github.com/ALIADA/aliada-tool
# 1 ---> https://github.com/JordiBolibar/ALPGM
# 1 ---> https://github.com/keyinst/keypy
# 1 ---> https://github.com/has2k1/scikit-misc
# 5 ---> https://github.com/PedroMat8/micropy
# 8 ---> https://github.com/clld/glottolog3
# 1 ---> https://github.com/stain/ro-combine-archive
# 1 ---> https://github.com/BEAST-Fitting/beast
# 1 ---> https://github.com/fireshape/fireshape
# 1 ---> https://github.com/jsh9/python-plot-utilities
# 8 ---> https://github.com/hibernator11/AprediendoJava
# 1 ---> https://github.com/FlamTeam/flamedisx
# 1 ---> https://github.com/ihmeuw-msca/ODEOPT
# 1 ---> https://github.com/dmentipl/plonk
# 0 ---> https://github.com/HSF/phoenix
# 1 ---> https://github.com/haraldschilly/panobbgo
# 5 ---> https://github.com/mtinti/PIG-A
# 8 ---> https://github.com/TRACMASS/tracmass
# 1 ---> https://github.com/coneoproject/COFFEE
# 0 ---> https://github.com/oblassers/dmap-mockups
# 1 ---> https://github.com/bioFAM/MOFA2
# 1 ---> https://github.com/pytroll/pyresample
# 1 ---> https://github.com/FATSLiM/fatslim
# 1 ---> https://github.com/astropenguin/azely
# 1 ---> https://github.com/debsankha/flownetpy
# 1 ---> https://github.com/lyx12311/Astraea
# 1 ---> https://github.com/npielawski/pytorch_tiramisu
# 8 ---> https://github.com/clld/tsammalex
# 0 ---> https://github.com/postnathalie/WallTalk
# 1 ---> https://github.com/TUW-GEO/smecv-grid
# 5 ---> https://github.com/echevemaster/fedora-college
# 0 ---> https://github.com/ropensci/lingtypology
# 0 ---> https://github.com/vivo-project/VIVO
# 1 ---> https://github.com/deephdc/schema4deep
# 1 ---> https://github.com/nist-ionstorage/electrode
# 1 ---> https://github.com/opannekoucke/pdenetgen
# 1 ---> https://github.com/lingpy/word-tree-paper
# 0 ---> https://github.com/RBVI/CyAnimator
# 1 ---> https://github.com/fsenf/proj.nawdex_analysis
# 1 ---> https://github.com/RDFLib/pyrdfa3
# 1 ---> https://github.com/mwcraig/reducer
# 1 ---> https://github.com/lcharleux/hardness
# 1 ---> https://github.com/pisa-engine/pisa
# 1 ---> https://github.com/rjw57/starman
# 1 ---> https://github.com/dewiedem/calcopp
# 1 ---> https://github.com/rstoneback/OMMBV
# 1 ---> https://github.com/mfherbst/asedftk
# 0 ---> https://github.com/Colectica/ddiregistry
# 1 ---> https://github.com/CyberDataLab/AuthCode
# 1 ---> https://github.com/imageio/imageio
# 1 ---> https://github.com/masseyr/geosoupML
# 1 ---> https://github.com/r9y9/pyreaper
# 1 ---> https://github.com/JDRomano2/ASAP2
# 1 ---> https://github.com/josephhardinee/PyDSD
# 8 ---> https://github.com/filips123/MonologPHPMailer
# 1 ---> https://github.com/Spine-project/Spine-Database-API
# 1 ---> https://github.com/GeoStat-Framework/ogs5py
# 1 ---> https://github.com/Z-Zheng/SimpleCV
# 1 ---> https://github.com/angelmtenor/RL-ROBOT
# 5 ---> https://github.com/Sreyan88/Fatigue-Detection-using-Deep-Learning
# 1 ---> https://github.com/stefanch/sGDML
# 4 ---> https://github.com/machawk1/warcreate
# 1 ---> https://github.com/materialsvirtuallab/monty
# 1 ---> https://github.com/kgullikson88/Telluric-Fitter
# 1 ---> https://github.com/Urban-Meteorology-Reading/SUEWS
# 1 ---> https://github.com/serazing/xscale
# 1 ---> https://github.com/pauleve/mpbn
# 1 ---> https://github.com/ericmjl/flu-gibson
# 8 ---> https://github.com/MoritzStefaner/ach-ingen-zell
# 0 ---> https://github.com/MAGIC-nexus/nis-backend
# 1 ---> https://github.com/pycalphad/scheil
# 1 ---> https://github.com/vanheeringen-lab/genomepy
# 1 ---> https://github.com/deparkes/OOMMFTools
# 1 ---> https://github.com/sarisabban/RamaNet
# 1 ---> https://github.com/nano-sippe/dispersion
# 1 ---> https://github.com/hallamlab/pathway2vec
# 1 ---> https://github.com/SCM-NV/nano-qmflows
# 1 ---> https://github.com/bburan/NeuroBehavior
# 1 ---> https://github.com/PhenixCollaboration/web
# 1 ---> https://github.com/Bubblbu/crawling-framework
# 1 ---> https://github.com/smarr/ReBench
# 1 ---> https://github.com/Alerovere/Paleo-SL-utilities
# 1 ---> https://github.com/TUDelft-CITG/OpenCLSim
# 1 ---> https://github.com/RMeli/spyrmsd
# 8 ---> https://github.com/dejac001/RealGas
# 0 ---> https://github.com/SciCrunch/resource_disambiguator
# 1 ---> https://github.com/rraadd88/htsimaging
# 1 ---> https://github.com/etiennebresciani/wellradpy
# 1 ---> https://github.com/blsqr/paramspace
# 1 ---> https://github.com/FInAT/FInAT
# 1 ---> https://github.com/hovo1990/GROM
# 1 ---> https://github.com/scikit-learn/scikit-learn
# 8 ---> https://github.com/covid-lncc/pydemic
# 1 ---> https://github.com/pvlib/pvlib-python
# 1 ---> https://github.com/phenoscape/phenoday-reasoning-paper
# 1 ---> https://github.com/norawebbwilliams/images_as_data
# 1 ---> https://github.com/filips123/ZeroFramePy
# 5 ---> https://github.com/sisinflab-swot/ldp-coap-framework
# 1 ---> https://github.com/pablormier/yabox
# 0 ---> https://github.com/TomDemeranville/orcid-update-java
# 1 ---> https://github.com/pysal/region
# 2 ---> https://github.com/yogo/VOEIS
# 1 ---> https://github.com/krassowski/data-vault
# 8 ---> https://github.com/ENCODE-DCC/croo
# 1 ---> https://github.com/jaisenbe58r/MLearner
# 1 ---> https://github.com/dave-heslop74/vMF_Sites
# 1 ---> https://github.com/biomedia-mira/blast-ct
# 1 ---> https://github.com/NREL/bifacial_radiance
# 1 ---> https://github.com/kundajelab/deeplift
# 1 ---> https://github.com/embodied-computation-group/systole
# 8 ---> https://github.com/terraref/terraref.github.io
# 1 ---> https://github.com/astorfi/TensorFlow-World
# 1 ---> https://github.com/TheLartians/Expresso
# 8 ---> https://github.com/bionode/fasta-parser
# 1 ---> https://github.com/UCL/scikit-surgeryfred
# 1 ---> https://github.com/neurolib-dev/neurolib
# 6 ---> https://github.com/hyperwell/playground
# 8 ---> https://github.com/pnlbwh/SlicerDiffusionQC
# 1 ---> https://github.com/CORE-GATECH-GROUP/serpent-tools
# 1 ---> https://github.com/morganjwilliams/pyrolite-meltsutil
# 2 ---> https://github.com/rcfduarte/nmsat
# 1 ---> https://github.com/midas-isg/PITT-Anthrax-model
# 1 ---> https://github.com/gmiaslab/pyiomica
# 8 ---> https://github.com/MarcoMuellner/SMURFS
# 1 ---> https://github.com/MrLogarithm/pe-pc-datasets-interface
# 1 ---> https://github.com/raamana/neuropredict
# 1 ---> https://github.com/bartongroup/2passtools
# 1 ---> https://github.com/earthserver-eu/INSPIRE-notebooks
# 1 ---> https://github.com/aderidder/iCRFGenerator
# 1 ---> https://github.com/jfal027/Moodify
# 4 ---> https://github.com/jyrkioraskari/OnlineMvdXMLChecker
# 1 ---> https://github.com/rjleveque/ptha_rog
# 1 ---> https://github.com/GeoStat-Framework/pentapy
# 1 ---> https://github.com/GhostofGoes/ADLES
# 1 ---> https://github.com/castelao/pyWOA
# 1 ---> https://github.com/pynbody/pynbody
# 1 ---> https://github.com/MicroPasts/magicMountain
# 1 ---> https://github.com/intake/intake-esm
# 1 ---> https://github.com/harnesscloud/2015-07-15-feltham
# 1 ---> https://github.com/hfsf/sloth
# 5 ---> https://github.com/histogrammar/histogrammar-scala
# 2 ---> https://github.com/LandscapeGeoinformatics/EstSoil-EH_sw_supplement
# 8 ---> https://github.com/chienchi/amplicon_coverage_plot
# 1 ---> https://github.com/cmohl2013/permutation_test
# 1 ---> https://github.com/mrtommyb/ktransit
# 5 ---> https://github.com/midas-isg/digital-commons
# 1 ---> https://github.com/hipster-philology/greek-lemmatization-data
# 1 ---> https://github.com/soil-physics-okstate/automated_soil_moisture_mapping
# 1 ---> https://github.com/QInfer/python-qinfer
# 1 ---> https://github.com/inodb/sufam
# 8 ---> https://github.com/LiberalHD/gudagudaACG
# 5 ---> https://github.com/bihealth/scelvis
# 8 ---> https://github.com/SommerEngineering/Encrypter
# 1 ---> https://github.com/CellMigStandOrg/Tracks
# 1 ---> https://github.com/dr-rodriguez/AstrodbWeb
# 1 ---> https://github.com/iamdamion/grepCIRCLE
# 1 ---> https://github.com/Olllom/lettuce
# 1 ---> https://github.com/bjpop/lynch_gatk
# 1 ---> https://github.com/jGaboardi/pp2n
# 6 ---> https://github.com/atrisovic/weather-panel.github.io
# 0 ---> https://github.com/arXiv/arxiv-browse
# 9 ---> https://github.com/clarity-h2020/map-component
# 8 ---> https://github.com/samapriya/geeup
# 1 ---> https://github.com/fphammerle/freesurfer-stats
# 1 ---> https://github.com/Lagostra/exprimo
# 1 ---> https://github.com/kweis/acronym
# 4 ---> https://github.com/iomega/zenodo-upload
# 1 ---> https://github.com/mirca/maoud
# 1 ---> https://github.com/castelao/maud
# 1 ---> https://github.com/cwfparsonson/soa_driving
# 1 ---> https://github.com/luphysics/PyMODAlib
# 1 ---> https://github.com/piazentin/ksets
# 1 ---> https://github.com/tgbugs/inferno
# 1 ---> https://github.com/jGaboardi/non-duplicated-intersects
# 1 ---> https://github.com/rochefort-lab/fissa
# 1 ---> https://github.com/qutip/qutip
# 1 ---> https://github.com/RomainBey/stratified-cross-validation
# 1 ---> https://github.com/XENON1T/pax
# 1 ---> https://github.com/indralab/adeft
# 1 ---> https://github.com/polsys/ennemi
# 1 ---> https://github.com/gmierz/pupil-lib
# 1 ---> https://github.com/macs3-project/MACS
# 1 ---> https://github.com/NLeSC/lokum
# 1 ---> https://github.com/efirvida/python-gearbox
# 1 ---> https://github.com/SuLab/genewikiworld
# 1 ---> https://github.com/samapriya/Planet-Pipeline-Shell
# 8 ---> https://github.com/smd-faizan/CySpanningTree
# 1 ---> https://github.com/Unidata/cftime
# 8 ---> https://github.com/weecology/DeepForest
# 1 ---> https://github.com/datreant/datreant
# 8 ---> https://github.com/Svdvoort/PREDICTFastr
# 1 ---> https://github.com/qcscine/utilities
# 1 ---> https://github.com/martibosch/urban-footprinter
# 1 ---> https://github.com/fa-me/ratter
# 1 ---> https://github.com/impact27/WF_NTP
# 8 ---> https://github.com/Eomys/pyleecan
# 1 ---> https://github.com/oeg-upm/morph-csv
# 5 ---> https://github.com/javadch/quis
# 1 ---> https://github.com/pear2/Cache_SHM
# 1 ---> https://github.com/scijava/scijava-common
# 1 ---> https://github.com/USNavalResearchLaboratory/SNOPROP
# 1 ---> https://github.com/bbfrederick/picachooser
# 1 ---> https://github.com/GilesStrong/HiggsML_Lumin
# 1 ---> https://github.com/GooglingTheCancerGenome/sv-callers
# 1 ---> https://github.com/jgreener64/pdb-benchmarks
# 8 ---> https://github.com/shh-dlce/python-nexus
# 1 ---> https://github.com/NickleDave/searchstims
# 6 ---> https://github.com/opencv/cvat
# 9 ---> https://github.com/scholarslab/prism
# 1 ---> https://github.com/pyoceans/python-seawater
# 1 ---> https://github.com/olgabot/sj2psi
# 1 ---> https://github.com/malvikasharan/APRICOT
# 1 ---> https://github.com/raamana/confounds
# 1 ---> https://github.com/mrkrd/matlab_wrapper
# 1 ---> https://github.com/thorstenwagner/ij-blob
# 1 ---> https://github.com/michaelosthege/pyrff
# 5 ---> https://github.com/ODM2/ODM2DataSharingPortal
# 1 ---> https://github.com/hameye/MARCIA
# 1 ---> https://github.com/eyelovedata/sentimentemotionanalysis
# 1 ---> https://github.com/Swiss-Polar-Institute/pyantarctica
# 8 ---> https://github.com/cgre-aachen/gempy
# 1 ---> https://github.com/alexandrebarachant/pyRiemann
# 1 ---> https://github.com/yt-project/unyt
# 0 ---> https://github.com/bonej-org/BoneJ2
# 1 ---> https://github.com/ConorMacBride/mcalf
# 1 ---> https://github.com/widdowquinn/pyADHoRe
# 1 ---> https://github.com/valdergallo/data-importer
# 1 ---> https://github.com/saketkc/pysradb
# 1 ---> https://github.com/jeeberhardt/visualize
# 1 ---> https://github.com/hsharrison/experimentator
# 1 ---> https://github.com/nudomarinero/wquantiles
# 1 ---> https://github.com/davidbradway/Visualizing-Scholars-At-Duke-2017
# 5 ---> https://github.com/sepandhaghighi/findip
# 1 ---> https://github.com/md-lab-tools/lab-tools
# 8 ---> https://github.com/fiji/KymographBuilder
# 8 ---> https://github.com/YaserJaradeh/JarvisQA
# 0 ---> https://github.com/PBR/Marker2Sequence
# 1 ---> https://github.com/DesignEngrLab/fmdtools
# 1 ---> https://github.com/dkalisch/morgenstadtDB
# 1 ---> https://github.com/has2k1/mizani
# 1 ---> https://github.com/super-resolution/lineprofiler
# 1 ---> https://github.com/junaidmalik09/fastonn
# 1 ---> https://github.com/mzabrams/fars-cleaner
# 1 ---> https://github.com/fat-forensics/fat-forensics
# 1 ---> https://github.com/RPGroup-PBoC/chann_cap
# 1 ---> https://github.com/lascivaroma/forcellini-lemmas
# 1 ---> https://github.com/akxen/tps-parameterisation
# 1 ---> https://github.com/Davidelanz/quantum-robot
# 1 ---> https://github.com/SandstoneHPC/sandstone-slurm-assist
# 8 ---> https://github.com/applied-bioinformatics/An-Introduction-To-Applied-Bioinformatics
# 1 ---> https://github.com/aliFrancis/mars-crater-catalogue
# 1 ---> https://github.com/jcvasquezc/AEspeech
# 1 ---> https://github.com/oemof/oemof-solph
# 1 ---> https://github.com/kutaslab/fitgrid
# 5 ---> https://github.com/MCZbase/PreCapture
# 8 ---> https://github.com/tgwizard/sexymp-data
# 5 ---> https://github.com/semplea/characters-meta
# 8 ---> https://github.com/edwardcapriolo/filecrush
# 8 ---> https://github.com/smart-facility/cognicity-floodsensor
# 2 ---> https://github.com/lerkoah/ComplexBehaviorDetector
# 5 ---> https://github.com/evoldoers/wtfgenes
# 1 ---> https://github.com/nstarman/amuse_util
# 8 ---> https://github.com/yhaddad/Heppi
# 8 ---> https://github.com/janantala/speech-synthesis
# 1 ---> https://github.com/wjladams/pyanp
# 1 ---> https://github.com/seva100/optic-nerve-cnn
# 8 ---> https://github.com/vibbits/phyd3
# 4 ---> https://github.com/miledrousset/opentheso
# 5 ---> https://github.com/VDBWRAIR/ngs_mapper
# 8 ---> https://github.com/clij/clij-docs
# 1 ---> https://github.com/lpfann/fri
# 1 ---> https://github.com/seisman/HinetPy
# 1 ---> https://github.com/JonathanReeve/text-matcher
# 1 ---> https://github.com/csdms/bmi-python
# 1 ---> https://github.com/NaturalHistoryMuseum/revile
# 1 ---> https://github.com/ishahid/django-blogg
# 8 ---> https://github.com/SommerEngineering/Ed25519
# 1 ---> https://github.com/xuanxu/intergalactic
# 1 ---> https://github.com/PyPSA/PyPSA
# 1 ---> https://github.com/NickleDave/vak
# 8 ---> https://github.com/gtonkinhill/panaroo
# 1 ---> https://github.com/CMLPlatform/pycirk
# 8 ---> https://github.com/globalbioticinteractions/nomer
# 0 ---> https://github.com/dwhieb/Nuuchahnulth
# 1 ---> https://github.com/TUW-GEO/ecmwf_models
# 5 ---> https://github.com/urmi-21/MetaOmGraph
# 8 ---> https://github.com/bfieldtools/bfieldtools
# 1 ---> https://github.com/pedroernesto/HippoNetworkUnit
# 1 ---> https://github.com/zwicker-group/py-pde
# 1 ---> https://github.com/NeuralEnsemble/PyNN
# 1 ---> https://github.com/juliema/aTRAM
# 1 ---> https://github.com/GrzegorzMikaAGH/Towards-adaptivity-via-a-new-discrepancy-principle-for-Poisson-inverse-problems
# 1 ---> https://github.com/HTenkanen/pyrosm
# 8 ---> https://github.com/kjappelbaum/colorjeopardy
# 8 ---> https://github.com/OSUmageed/pyHeatTransfer
# 1 ---> https://github.com/olety/TIMLinUCB
# 0 ---> https://github.com/gcube-team/gcube-releases
# 1 ---> https://github.com/r9y9/pyopenjtalk
# 8 ---> https://github.com/altmetric/aho_corasick_matcher
# 1 ---> https://github.com/Edric-Matwiejew/QSW_MPI
# 1 ---> https://github.com/xieguigang/Data.GIS
# 1 ---> https://github.com/scikit-hep/hepstats
# 1 ---> https://github.com/elainehoml/GMM_Image_Quality
# 1 ---> https://github.com/mikahama/uralicNLP
# 4 ---> https://github.com/blobtoolkit/viewer
# 1 ---> https://github.com/e-VRO/frvcpy
# 1 ---> https://github.com/openeventdata/mordecai
# 1 ---> https://github.com/ssepulveda/RTGraph
# 8 ---> https://github.com/eWaterCycle/grpc4bmi
# 8 ---> https://github.com/msmexplorer/msmexplorer-d3
# 1 ---> https://github.com/bjodah/chempy
# 1 ---> https://github.com/chjacob-tubs/pyadf-releases
# 1 ---> https://github.com/Nikeshbajaj/spkit
# 1 ---> https://github.com/wright-group/WrightSim
# 1 ---> https://github.com/Curtin-Timescales-of-Mineral-Systems/UPb-Unmixer
# 1 ---> https://github.com/pietrobarbiero/dbgen
# 8 ---> https://github.com/larslau/DETECT
# 1 ---> https://github.com/edwardoughton/itmlogic
# 1 ---> https://github.com/tychotatitscheff/duc-sph
# 1 ---> https://github.com/impact27/diffusion_device
# 1 ---> https://github.com/williamjameshandley/fgivenx
# 1 ---> https://github.com/gregtucker/grain_hills
# 8 ---> https://github.com/holoviz/geoviews
# 1 ---> https://github.com/SoftwareDevEngResearch/CAML
# 1 ---> https://github.com/cyTVDN/cyTVDN
# 1 ---> https://github.com/birnstiel/two-pop-py
# 1 ---> https://github.com/DECLARE-Project/fastpan
# 1 ---> https://github.com/reneshbedre/bioinfokit
# 1 ---> https://github.com/INM-6/hybridLFPy
# 1 ---> https://github.com/caglorithm/mopet
# 8 ---> https://github.com/felicitia/EventExtractor
# 1 ---> https://github.com/molpopgen/fwdpy11
# 1 ---> https://github.com/jacobwindsor/pubchem-ranker
# 1 ---> https://github.com/ENCODE-DCC/caper
# 1 ---> https://github.com/colomoto/colomoto-jupyter
# 1 ---> https://github.com/nicolas-chaulet/torch-points-kernels
# 1 ---> https://github.com/MicroPasts/transcribing-WGS
# 8 ---> https://github.com/samapriya/Planet-GEE-Pipeline-GUI
# 1 ---> https://github.com/similitude/h2-world-simmer
# 1 ---> https://github.com/anthony-nouy/tensap
# 1 ---> https://github.com/ancklo/ChaosMagPy
# 1 ---> https://github.com/mvdh7/calkulate
# 8 ---> https://github.com/arviz-devs/arviz
# 8 ---> https://github.com/clij/clij-core
# 1 ---> https://github.com/saverymax/qdriven-chiqa-summarization
# 1 ---> https://github.com/jhidding/sustainability
# 1 ---> https://github.com/arif-zaman/network_probing
# 1 ---> https://github.com/janpipek/pydiq
# 1 ---> https://github.com/posterior/goftests
# 8 ---> https://github.com/zarr-developers/zarr-python
# 5 ---> https://github.com/marco-ka/semantic-annotation-writer
# 7 ---> https://github.com/medusa-project/databank
# 9 ---> https://github.com/schema-app/schema
# 1 ---> https://github.com/ulmo-dev/ulmo
# 8 ---> https://github.com/kuchaale/wcd_2020
# 1 ---> https://github.com/uwmadison-chm/masterfile
# 1 ---> https://github.com/jeeberhardt/unrolr
# 8 ---> https://github.com/Lane-Library/wiki-extract
# 1 ---> https://github.com/pydicom/pynetdicom
# 5 ---> https://github.com/NLeSC/fairdatapoint
# 1 ---> https://github.com/ilyasst/pydictoolkit
# 1 ---> https://github.com/NLESC-JCER/QMCTorch
# 8 ---> https://github.com/AthenaEPI/dmipy
# 1 ---> https://github.com/ISA-tools/nmrml2isa
# 8 ---> https://github.com/usethesource/capsule
# 1 ---> https://github.com/minzastro/unidam
# 1 ---> https://github.com/environmentalscience/essm
# 8 ---> https://github.com/afnogueira/datasetsaner2017
# 1 ---> https://github.com/raysect/source
# 5 ---> https://github.com/ivco19/brooks
# 1 ---> https://github.com/mattbv/lidartf
# 1 ---> https://github.com/ricoms/gpam_stats
# 8 ---> https://github.com/Capitains/Sparrow
# 1 ---> https://github.com/hpparvi/PyDE
# 1 ---> https://github.com/molbiodiv/Blackbird
# 8 ---> https://github.com/adrn/thejoker
# 1 ---> https://github.com/davidenunes/context-permeability
# 1 ---> https://github.com/akxen/rep-gep
# 1 ---> https://github.com/joergdietrich/NFW
# 5 ---> https://github.com/sandyherho/tutorial_xarray
# 1 ---> https://github.com/deniederhut/PyTeX
# 1 ---> https://github.com/interaction-lab/MoveToCode
# 1 ---> https://github.com/FilipeMaia/afnumpy
# 1 ---> https://github.com/nextgenusfs/amptk
# 8 ---> https://github.com/Qiskit/qiskit
# 1 ---> https://github.com/CU-Denver-UQ/LUQ
# 1 ---> https://github.com/casimp/lightct
# 1 ---> https://github.com/joostjor/random-graphs
# 1 ---> https://github.com/sbonaretti/pyKNEEr
# 1 ---> https://github.com/DataMedSci/pymchelper
# 1 ---> https://github.com/simonvh/pita
# 1 ---> https://github.com/Socrats/EGTTools
# 1 ---> https://github.com/ihmwg/python-ihm
# 8 ---> https://github.com/AlessioZanga/PyEEGLab
# 1 ---> https://github.com/samuelstjean/autodmri
# 4 ---> https://github.com/filips123/ZeroFrameJS
# 1 ---> https://github.com/Tyler-Yates/AestheticFractals
# 1 ---> https://github.com/fmalmeida/ngs-preprocess
# 1 ---> https://github.com/junhyeokahn/tf_rbdl
# 1 ---> https://github.com/Samreay/ChainConsumer
# 1 ---> https://github.com/JoshuaE1/supervised-classification-SSH-publications
# 1 ---> https://github.com/syhw/DTW_Cython
# 1 ---> https://github.com/cerebunit/cerebunit
# 1 ---> https://github.com/clebsonpy/HidroComp
# 8 ---> https://github.com/Terradue/dcs-insar-roipac
# 8 ---> https://github.com/drcassar/viscosity-graybox-nn
# 1 ---> https://github.com/MAVENSDC/PyTplot
# 5 ---> https://github.com/EricAlcaide/MiniFold
# 1 ---> https://github.com/CognitiveComputationLab/ccobra
# 1 ---> https://github.com/holoviz/colorcet
# 1 ---> https://github.com/jpvantassel/hvsrpy
# 8 ---> https://github.com/georgeOsdDev/longo
# 1 ---> https://github.com/unicus-skmk/test
# 1 ---> https://github.com/DTUComputeStatisticsAndDataAnalysis/MBPLS
# 1 ---> https://github.com/hyungjun/gtool
# 0 ---> https://github.com/UofS-Pulse-Binfo/nd_genotypes
# 1 ---> https://github.com/michaelaye/pyciss
# 1 ---> https://github.com/genomematt/pylazybam
# 1 ---> https://github.com/arkottke/pygmm
# 1 ---> https://github.com/evanodell/ukpolice
# 8 ---> https://github.com/kotori-y/Scopy
# 1 ---> https://github.com/gsantoni/ccCluster
# 1 ---> https://github.com/iancze/MPoL
# 1 ---> https://github.com/jacobo-diaz/aneupy
# 1 ---> https://github.com/j-stone/cog-tasks
# 1 ---> https://github.com/broyson/Locust-streaming
# 1 ---> https://github.com/rougier/numpy-100
# 1 ---> https://github.com/castelao/supportdata
# 1 ---> https://github.com/napsternxg/TwitterNER
# 1 ---> https://github.com/DomBennett/TaxonNamesResolver
# 8 ---> https://github.com/lucaspuvis/SAM
# 5 ---> https://github.com/caltechlibrary/handprint
# 5 ---> https://github.com/unipept/unipept-cli
# 8 ---> https://github.com/griffithlab/pVACtools
# 1 ---> https://github.com/MAGIC-nexus/nis-python-client
# 1 ---> https://github.com/spacetelescope/jwst-fgs-countrate
# 8 ---> https://github.com/skp703/RainInterpolator
# 1 ---> https://github.com/pysal/spvcm
# 1 ---> https://github.com/CKrawczyk/densityplot
# 1 ---> https://github.com/Abe404/root_painter
# 5 ---> https://github.com/freeknijweide/autoencoder-pdb-cleaning
# 8 ---> https://github.com/reegis/deflex
# 1 ---> https://github.com/DCAN-Labs/nhp-abcd-bids-pipeline
# 1 ---> https://github.com/MechMicroMan/DefDAP
# ...
# 8 ---> https://github.com/kashyapchhatbar/CLASHChimeras
# 8 ---> https://github.com/pzeidler89/MUSEpack
# 8 ---> https://github.com/tofaquih/imputation_of_untargeted_metabolites
# 8 ---> https://github.com/sebastientourbier/multiscalebrainparcellator
# 1 ---> https://github.com/hammurabi-dev/hammurabiX
# 2 ---> https://github.com/comses/comses.net
# 1 ---> https://github.com/ultralytics/yolov3
# 8 ---> https://github.com/clld/concepticon
# 1 ---> https://github.com/epigen/cll-chromatin
# 5 ---> https://github.com/sagemathinc/cocalc_tutorial
# 1 ---> https://github.com/paddy-seismic/retreat
# 1 ---> https://github.com/geoschem/gcpy
# 1 ---> https://github.com/NickSwainston/mwa_search
# 5 ---> https://github.com/dhimmel/gene-ontology
# 1 ---> https://github.com/lmarti/nsgaiii
# 0 ---> https://github.com/sbmlteam/jsbml
# 1 ---> https://github.com/ankahira/chainermnx
# 1 ---> https://github.com/CalebBell/fpi
# 1 ---> https://github.com/gplepage/corrfitter
# 0 ---> https://github.com/ADicksonLab/geomm
# 1 ---> https://github.com/pycroscopy/pycroscopy
# 1 ---> https://github.com/bioasp/iggy
# 1 ---> https://github.com/TUW-GEO/smos
# 1 ---> https://github.com/SynthSys/OMEROConnect
# 0 ---> https://github.com/jaclaes/SPMM2015
# 8 ---> https://github.com/FNNDSC/ChRIS_store
# 1 ---> https://github.com/hpparvi/KeplerJC
# 1 ---> https://github.com/neurodata/graspy
# 1 ---> https://github.com/bast/polygons
# 1 ---> https://github.com/MatthewReid854/reliability
# 1 ---> https://github.com/greenelab/DAPS
# 1 ---> https://github.com/merijn/Belewitte
# 0 ---> https://github.com/HexaPlant/pixeldragon
# 1 ---> https://github.com/sertansenturk/ahenkidentifier
# 1 ---> https://github.com/bss116/citygenerator
# 1 ---> https://github.com/jeffbass/imagezmq
# 0 ---> https://github.com/njss/Sense.me
# 1 ---> https://github.com/materialsvirtuallab/pyhull
# 1 ---> https://github.com/alexnaoki/LHC_Hidroweb
# 8 ---> https://github.com/UCATLAS/xAODAnaHelpers
# 1 ---> https://github.com/rhiever/MarkovNetwork
# 1 ---> https://github.com/dvalters/caesarplotlib
# 1 ---> https://github.com/pyproj4/pyproj
# 8 ---> https://github.com/clld/csd
# 1 ---> https://github.com/colbyj/bride-of-frankensystem
# 5 ---> https://github.com/SainsburyWellcomeCentre/cellfinder
# 8 ---> https://github.com/pySRURGS/pyGOURGS
# 8 ---> https://github.com/acdh-oeaw/4dpuzzle
# 1 ---> https://github.com/kinnala/kirchhoff-nitsche-ex2
# 1 ---> https://github.com/petl-developers/petlx
# 1 ---> https://github.com/mmcauliffe/Pyraat
# 5 ---> https://github.com/plt-tud/r43ples
# 1 ---> https://github.com/EducationalTestingService/skll
# 1 ---> https://github.com/RadioAstronomySoftwareGroup/pyuvdata
# 1 ---> https://github.com/jfnavarro/st_pipeline
# 1 ---> https://github.com/Neuroinflab/PyMICE
# 8 ---> https://github.com/pythoninchemistry/intro_python_chemists
# 1 ---> https://github.com/OpenPIV/openpiv-python
# 4 ---> https://github.com/mbari-media-management/vcr4j
# 8 ---> https://github.com/dpizetta/wavy
# 4 ---> https://github.com/arman2/equal_public
# 1 ---> https://github.com/gher-ulg/Diva-Workshops
# 1 ---> https://github.com/pydata/xarray
# 1 ---> https://github.com/transientlunatic/elk
# 1 ---> https://github.com/qcscine/readuct
# 1 ---> https://github.com/RDFLib/pymicrodata
# 1 ---> https://github.com/sbmlteam/libCombine
# 0 ---> https://github.com/encompasslabs/mcsdss-watermark
# 8 ---> https://github.com/OGGM/oggm
# 1 ---> https://github.com/tdwg/dwc
# 1 ---> https://github.com/NeuralEnsemble/elephant
# 1 ---> https://github.com/agporto/ml-morph
# 1 ---> https://github.com/SeismicSource/sourcespec
# 1 ---> https://github.com/tensorwerk/hangar-py
# 1 ---> https://github.com/virgesmith/humanleague
# 1 ---> https://github.com/lebedov/scikit-cuda
# 5 ---> https://github.com/mbari-media-management/vars-query
# 2 ---> https://github.com/jpdias/node-red-contrib-self-healing
# 1 ---> https://github.com/snastase/isc-tutorial
# 1 ---> https://github.com/smart-facility/cognicity-reports-qlue
# 1 ---> https://github.com/simpeg-research/kang-2019-3D-aem
# 8 ---> https://github.com/appetrosyan/LCDM-NS
# 1 ---> https://github.com/asergiobranco/ArchNet
# 1 ---> https://github.com/DistrictDataLabs/yellowbrick
# 1 ---> https://github.com/enolfc/d4science-galaxy-authn
# 1 ---> https://github.com/pyGSTio/pyGSTi
# 1 ---> https://github.com/smart-facility/cognicity-reports-floodgauge
# 1 ---> https://github.com/miguelfp/ibmos
# 1 ---> https://github.com/DanPorter/Dans_Diffraction
# 1 ---> https://github.com/CexyNature/Crabspy
# 1 ---> https://github.com/ismrmrd/ismrmrd-python
# 1 ---> https://github.com/kkmann/sample-size-calculation-under-uncertainty
# 1 ---> https://github.com/kingjr/ecoggui
# 1 ---> https://github.com/OP2/PyOP2
# 8 ---> https://github.com/cgat-developers/cgat-core
# 1 ---> https://github.com/pnlbwh/luigi-pnlpipe
# 3 ---> https://github.com/dzhw/metadatamanagement
# 8 ---> https://github.com/mastrogeppetto/OCCI4IOT
# 1 ---> https://github.com/scivision/fortran-submodule
# 1 ---> https://github.com/librosa/librosa
# 1 ---> https://github.com/morganjwilliams/pyrolite
# 1 ---> https://github.com/planetserver/ps2-www-client
# 1 ---> https://github.com/MDAnalysis/RotamerConvolveMD
# 1 ---> https://github.com/psu-inversion/atmospheric-inverse-methods-for-flux-optimization
# 1 ---> https://github.com/enolfc/d4scienceauth
# 1 ---> https://github.com/yoavram/Sid
# 8 ---> https://github.com/ISOBlue/isoblue-android
# 1 ---> https://github.com/bio2bel/bio2bel
# 1 ---> https://github.com/CDAT/ci-bots
# 8 ---> https://github.com/ropensci/stplanr
# 9 ---> https://github.com/digitallinguistics/app
# 1 ---> https://github.com/blokhin/genealogical-trees
# 1 ---> https://github.com/hannes-brt/hebel
# 1 ---> https://github.com/mcs07/CIRpy
# 0 ---> https://github.com/tobysmith568/Generate-License-File
# 4 ---> https://github.com/HBLL-Collection-Development/omeka-s-any-cloud
# 0 ---> https://github.com/dgnest/foottrial
# 8 ---> https://github.com/neuropsychology/NeuroKit
# 1 ---> https://github.com/makgyver/rectorch
# 1 ---> https://github.com/Continvvm/continuum
# 1 ---> https://github.com/mdolab/pyhyp
# 1 ---> https://github.com/timothydmorton/exosyspop
# 1 ---> https://github.com/WGUNDERWOOD/motifcluster
# 1 ---> https://github.com/egonw/ops4j
# 5 ---> https://github.com/SebBuchelt/georef_webcam
# 1 ---> https://github.com/dimazest/google-ngram-downloader
# 1 ---> https://github.com/mmadsen/seriationct
# 8 ---> https://github.com/thorstenwagner/ij-shape-smoothing
# 1 ---> https://github.com/prisae/pyfftlog
# 1 ---> https://github.com/koszullab/hicstuff
# 8 ---> https://github.com/TUW-GEO/gldas
# 1 ---> https://github.com/martinfleis/momepy
# 1 ---> https://github.com/alamar/microbe
# 1 ---> https://github.com/romain-jacob/TTW-Artifacts
# 2 ---> https://github.com/netsage-project/netsage-pipeline
# 1 ---> https://github.com/krischer/pyflex
# 1 ---> https://github.com/cheeseywhiz/cheeseywhiz
# 1 ---> https://github.com/NeuPhysics/neutrino
# 1 ---> https://github.com/astrojs/fitsjs
# 8 ---> https://github.com/arbox/shalmaneser
# 1 ---> https://github.com/keflavich/pyradex
# 1 ---> https://github.com/alphatwirl/mantichora
# 1 ---> https://github.com/pysal/spreg
# 1 ---> https://github.com/dmey/minimal-dx
# 1 ---> https://github.com/dftlibs/xcauto
# 0 ---> https://github.com/kizniche/Mycodo
# 1 ---> https://github.com/lmcinnes/umap
# 1 ---> https://github.com/flowersteam/explauto
# 1 ---> https://github.com/malkayo/AiRL
# 4 ---> https://github.com/liminoid/liminoid-js
# 1 ---> https://github.com/llambourne/isoenzymes_flux_balance
# 1 ---> https://github.com/davidhin/stringmatching
# 1 ---> https://github.com/maxplanck-ie/snakepipes
# 1 ---> https://github.com/titipata/pubmed_parser
# 1 ---> https://github.com/inodb/revmut
# 8 ---> https://github.com/LASER-UMASS/CausalTesting_ICSE20
# 1 ---> https://github.com/bcbio/bcbio-nextgen
# 1 ---> https://github.com/coin-or/CyLP
# 8 ---> https://github.com/SciTools/cartopy
# 6 ---> https://github.com/Jollyfant/PMAG2
# 1 ---> https://github.com/AlBi-HHU/homo-edit-distance
# 1 ---> https://github.com/atmtools/typhon
# 1 ---> https://github.com/benvanwerkhoven/kernel_tuner
# 1 ---> https://github.com/myGrid/ruby-ro-bundle
# 5 ---> https://github.com/juoceano/lecture_figures
# 1 ---> https://github.com/briandconnelly/nicheconstruct
# 5 ---> https://github.com/deeptools/HiCExplorer
# 5 ---> https://github.com/mmalekzadeh/privacy-preserving-bandits
# 8 ---> https://github.com/jjnp/dss-ue2
# 1 ---> https://github.com/jsh9/PySeismoSoil
# 1 ---> https://github.com/wiheto/teneto
# 1 ---> https://github.com/CamDavidsonPilon/lifetimes
# 1 ---> https://github.com/meelgroup/baital
# 1 ---> https://github.com/harnesscloud/bqwm
# 1 ---> https://github.com/apcamargo/tspex
# 1 ---> https://github.com/a-slide/pycoMeth
# 1 ---> https://github.com/RoberAgro/nurbspy
# 1 ---> https://github.com/ralph-group/pymeasure
# 8 ---> https://github.com/TrapperTeam/Trapper
# 8 ---> https://github.com/sertansenturk/tomato
# 1 ---> https://github.com/oscarbranson/carbspec
# 4 ---> https://github.com/rodighiero/AIUCD2020
# 1 ---> https://github.com/michaelaye/planet4
# 1 ---> https://github.com/mcs07/PubChemPy
# 1 ---> https://github.com/kyleniemeyer/mech_util
# 1 ---> https://github.com/nathandunn/galaxy-monarch-integration
# 8 ---> https://github.com/pyoceans/python-ctd
# 1 ---> https://github.com/sebhenri/HyWF
# 5 ---> https://github.com/MatthijsKaminski/AnalyzeTool
# 1 ---> https://github.com/mila-iqia/blocks
# 1 ---> https://github.com/vnmabus/dcor
# 1 ---> https://github.com/ejhumphrey/optimus
# 8 ---> https://github.com/Kaleidophon/token2index
# 1 ---> https://github.com/gchrupala/visually-grounded-speech
# 1 ---> https://github.com/dhhagan/opcsim
# 5 ---> https://github.com/kipoi/kipoiseq
# 1 ---> https://github.com/pnlbwh/freesurfer-analysis
# 1 ---> https://github.com/mpastell/CowLog
# 8 ---> https://github.com/TGAC/RAMPART
# 1 ---> https://github.com/repseqio/repseqio
# 4 ---> https://github.com/liminoid/liminoid
# 5 ---> https://github.com/SotosTsepe/invenio-madmp
# 9 ---> https://github.com/russianwordnet/yarn
# 1 ---> https://github.com/ihmeuw/vivarium_conic_lsff
# 1 ---> https://github.com/CMA-ES/pycma
# 1 ---> https://github.com/FAST-HEP/fast-curator
# 1 ---> https://github.com/erdc/AutoRoutePy
# 1 ---> https://github.com/kjappelbaum/oximachinetool
# 5 ---> https://github.com/ameyaKetkar/SimpleTypeChangeMiner
# 1 ---> https://github.com/rvhonorato/cazy-parser
# 1 ---> https://github.com/CrystalMei/ProvBuild
# 0 ---> https://github.com/stoqs/stoqs
# 1 ---> https://github.com/jamesrhester/PyFormatTransformer
# 1 ---> https://github.com/mirnylab/cooltools
# 1 ---> https://github.com/maxibor/adrsm
# 1 ---> https://github.com/thorstenwagner/ij-shape-filter
# 0 ---> https://github.com/cemac/SWIFTDB
# 1 ---> https://github.com/minimalparts/nonce2vec
# 1 ---> https://github.com/sepandhaghighi/pyrgg
# 5 ---> https://github.com/xBimTeam/XbimEssentials
# 8 ---> https://github.com/bionode/bionode-fasta
# 1 ---> https://github.com/chembl/FPSim2
# 5 ---> https://github.com/WIPACrepo/iceprod
# 1 ---> https://github.com/smarsland/AviaNZ
# 8 ---> https://github.com/chasemc/IDBacApp
# 1 ---> https://github.com/metomi/rose
# 1 ---> https://github.com/dune-community/dune-gdt
# 1 ---> https://github.com/LEAF-BoiseState/janus
# 1 ---> https://github.com/mmbajo/PROBA-V
# 1 ---> https://github.com/koszullab/instaGRAAL
# 1 ---> https://github.com/clincolnoz/WorldBank_WDI_Visulization
# 0 ---> https://github.com/lifs-tools/jmzTab-m-webapp
# 1 ---> https://github.com/thieunguyen5991/mealpy
# 1 ---> https://github.com/sepandhaghighi/pycm
# 9 ---> https://github.com/fruchtfolge/client
# 3 ---> https://github.com/newcastle-living-lab/living-lab
# 8 ---> https://github.com/waqasbhatti/astrobase
# 1 ---> https://github.com/TECH-UB-24-Programming-DS-Spring-2020/notebooks
# 1 ---> https://github.com/hidrokit/hidrokit
# 1 ---> https://github.com/biosustain/gnomic
# 1 ---> https://github.com/digicademy/AskMoreXtension
# 1 ---> https://github.com/jnicoleoliveira/SPECData
# 1 ---> https://github.com/glotzerlab/signac-flow
# 8 ---> https://github.com/erdc/spt_compute
# 1 ---> https://github.com/maayane/PhotoManip
# 5 ---> https://github.com/ufbmi/mdc_tree
# 1 ---> https://github.com/VlachosGroup/vunits
# 1 ---> https://github.com/rhshah/iCallSV
# 1 ---> https://github.com/widdowquinn/SI_Holmes_etal_2020
# 5 ---> https://github.com/vemomoto/vemomoto
# 1 ---> https://github.com/nschloe/tikzplotlib
# 1 ---> https://github.com/msmbuilder/msmbuilder
# 1 ---> https://github.com/dmolina/shadeils
# 5 ---> https://github.com/spacetelescope/mirage
# 8 ---> https://github.com/dpla/ingestion
# 5 ---> https://github.com/bigbadcrad/PUFFIN
# 8 ---> https://github.com/Ouranosinc/xclim
# 1 ---> https://github.com/erdc/spt_dataset_manager
# 1 ---> https://github.com/jhrmnn/pyberny
# 5 ---> https://github.com/scharom16/evolutionary-nas-with-performance-estimation
# 1 ---> https://github.com/timm/shape
# 1 ---> https://github.com/JulianKarlBauer/mechkit
# 1 ---> https://github.com/gher-ulg/DINCAE
# 6 ---> https://github.com/eweitz/ideogram
# 5 ---> https://github.com/rinde/vanLon17-GPEM-code
# 8 ---> https://github.com/NESCent/dplace
# 1 ---> https://github.com/kkmann/optimal-binary-two-stage-designs
# 8 ---> https://github.com/pyoceans/python-oceans
# 1 ---> https://github.com/DiamondLightSource/Opt-ID
# 1 ---> https://github.com/salvadorgarciamunoz/kipet
# 1 ---> https://github.com/JasperHG90/sleepsimR-api
# 1 ---> https://github.com/njsmith/zs
# 1 ---> https://github.com/cicirello/JavaPermutationTools
# 1 ---> https://github.com/AndrewAnnex/SpiceyPy
# 5 ---> https://github.com/CESNET/perun-mitreid
# 8 ---> https://github.com/choderalab/itctools
# 1 ---> https://github.com/vpasumarthi/PyCD
# 1 ---> https://github.com/jiemakel/seco-hfst
# 4 ---> https://github.com/digitallinguistics/spec
# 1 ---> https://github.com/philippkraft/cmf
# 8 ---> https://github.com/fo-am/mongoose-2000
# 1 ---> https://github.com/snowformatics/macrobot
# 2 ---> https://github.com/kach/nearley
# 6 ---> https://github.com/direwolf/direwolf-app
# 4 ---> https://github.com/infraling/atomic
# 1 ---> https://github.com/samapriya/plantpy
# 1 ---> https://github.com/KatyBrown/CIAlign
# 1 ---> https://github.com/iteal/wormpose
# 1 ---> https://github.com/felixriese/susi
# 1 ---> https://github.com/proycon/codemetapy
# 1 ---> https://github.com/eblur/dust
# 1 ---> https://github.com/BioMoDeL/aesop
# 1 ---> https://github.com/bashtage/randomgen
# 1 ---> https://github.com/UT-CHG/BET
# 6 ---> https://github.com/bids-standard/bids-validator
# 8 ---> https://github.com/concepticon/pynorare
# 1 ---> https://github.com/nipy/PySurfer
# 1 ---> https://github.com/jeffreyruffolo/lamprey_rs_neuron_parameter_exploration
# 1 ---> https://github.com/harnesscloud/irm-nova
# 1 ---> https://github.com/obachem/kmc2
# 8 ---> https://github.com/biowdl/gatk-preprocess
# 1 ---> https://github.com/beOn/cili
# 7 ---> https://github.com/trendscenter/coinstac
# 0 ---> https://github.com/kuechenrole/antarctic_melting
# 1 ---> https://github.com/saketkc/moca
# 1 ---> https://github.com/PBR/MQ2
# 1 ---> https://github.com/ijpb/MorphoLibJ
# 1 ---> https://github.com/tesera/pygypsy
# 1 ---> https://github.com/ml-evs/ilustrado
# 1 ---> https://github.com/DeepRank/iScore
# 1 ---> https://github.com/fastscape-lem/fastscape
# 9 ---> https://github.com/yogo/sapphire
# 1 ---> https://github.com/BlueBrain/MorphIO
# 1 ---> https://github.com/bashtage/arch
# 1 ---> https://github.com/vsoch/TtoZ
# 1 ---> https://github.com/miurahr/pykakasi
# 8 ---> https://github.com/dalejn/cleanBib
# 1 ---> https://github.com/fail2ban/fail2ban
# 1 ---> https://github.com/mih/gumpdata
# 8 ---> https://github.com/compas-dev/compas_fab
# 8 ---> https://github.com/steelelab-delft/stlab
# 1 ---> https://github.com/mozillazg/python-pinyin
# 1 ---> https://github.com/aestimosolver/aestimo
# 1 ---> https://github.com/PyMVPA/PyMVPA
# 1 ---> https://github.com/eljost/pysisyphus
# 1 ---> https://github.com/mikahama/murre
# 0 ---> https://github.com/sbalci/clinicopathological
# 1 ---> https://github.com/arselzer/HTQueryOptimizer
# 1 ---> https://github.com/phenomecentre/ISTOCSY
# 8 ---> https://github.com/BerkeleyPhotonicsGenerator/BPG
# 1 ---> https://github.com/shiny-data-scientist/webscrap_pract_1
# 8 ---> https://github.com/GeoscienceAustralia/tcrm
# 1 ---> https://github.com/dputhier/pygtftk
# 1 ---> https://github.com/michaelaye/iuvs
# 1 ---> https://github.com/discsim/frank
# 1 ---> https://github.com/dguijo/TSOC

# %%
for k in sorted(topic_dict.keys()):
    print(f'topic {k} : repos num: {len(topic_dict[k])}')
# Out:
# topic 0 : repos num: 2004
# topic 1 : repos num: 59
# topic 2 : repos num: 37
# topic 3 : repos num: 118
# topic 4 : repos num: 3
# topic 5 : repos num: 202
# topic 6 : repos num: 83
# topic 7 : repos num: 11
# topic 8 : repos num: 36
# topic 9 : repos num: 459

# %% [markdown]
# ## Clustering - GMM

# %%
GMM = GaussianMixture(n_components=10).fit(d2v_model.docvecs.doctag_syn0)
probs = GMM.predict_proba(d2v_model.docvecs.doctag_syn0)

probs.shape,probs
# Out:
# /opt/anaconda3/envs/Knowledge_Graph/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doctag_syn0` (Attribute will be removed in 4.0.0, use docvecs.vectors_docs instead).
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/envs/Knowledge_Graph/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `doctag_syn0` (Attribute will be removed in 4.0.0, use docvecs.vectors_docs instead).
# ((3012, 10),
#  array([[3.83853395e-005, 1.60064351e-253, 0.00000000e+000, ...,
#          5.89829455e-014, 0.00000000e+000, 9.99961615e-001],
#         [7.79539839e-006, 2.16666431e-252, 0.00000000e+000, ...,
#          1.78288693e-012, 0.00000000e+000, 9.99992205e-001],
#         [9.67671120e-006, 0.00000000e+000, 0.00000000e+000, ...,
#          4.93476052e-016, 0.00000000e+000, 9.99990323e-001],
#         ...,
#         [4.93449671e-005, 0.00000000e+000, 0.00000000e+000, ...,
#          1.54121993e-014, 0.00000000e+000, 9.99950655e-001],
#         [9.69154455e-007, 5.86529082e-279, 0.00000000e+000, ...,
#          1.22051508e-017, 0.00000000e+000, 9.99999031e-001],
#         [3.26109095e-007, 1.39024139e-312, 0.00000000e+000, ...,
#          2.73686617e-019, 0.00000000e+000, 9.99999674e-001]]))
